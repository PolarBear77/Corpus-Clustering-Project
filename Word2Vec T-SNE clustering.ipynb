# %% [markdown]
# # Workplace

# %%
import gensim
model = gensim.models.Word2Vec.load(r"C:\nlp\word2vec_1.bin")
model.wv.vocab
# Out:
# c:\nlp\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.
# {'section_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc572b0>,
#  'museum_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57438>,
#  'centenary_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57470>,
#  'birth_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc574a8>,
#  'margaret_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc574e0>,
#  'mead_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57550>,
#  'remember_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57588>,
#  'world_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc575c0>,
#  'influential_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc575f8>,
#  'anthropologist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57630>,
#  'arrive_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc57668>,
#  'american_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc576a0>,
#  'natural_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc576d8>,
#  'history_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57710>,
#  'complete_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57748>,
#  'first_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57780>,
#  'significant_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc577b8>,
#  'ethnographic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc577f0>,
#  'research_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57828>,
#  'samoa_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57860>,
#  'appoint_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57898>,
#  'assistant_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc578d0>,
#  'curator_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57908>,
#  'department_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57940>,
#  'anthropology_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57978>,
#  'year_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc579b0>,
#  'old_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57a20>,
#  'give_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57a58>,
#  'temporary_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57a90>,
#  'office_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57ac8>,
#  'attic_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57b00>,
#  'room_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57b70>,
#  'west_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57be0>,
#  'tower_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57c18>,
#  'out-of-the-way_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57c50>,
#  'view_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc57c88>,
#  'rooftop_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc57cc0>,
#  'new_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57d30>,
#  'york_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57da0>,
#  'city_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57e10>,
#  'stairway_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc57e48>,
#  'ideal_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc57e80>,
#  'say_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc57ef0>,
#  'creep_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc57f28>,
#  'stairway_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57f60>,
#  'someone_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57f98>,
#  'avoid_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc57fd0>,
#  'elderly_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc60048>,
#  'labor_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc60080>,
#  'stay_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc600b8>,
#  'rest_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60128>,
#  'life_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60198>,
#  'arrive_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc601d0>,
#  'interview_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60208>,
#  'position_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60240>,
#  'assistant_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60278>,
#  'undergraduate_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc602b0>,
#  'major_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc602e8>,
#  'barnard_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60320>,
#  'college_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60358>,
#  'felt_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc60390>,
#  'find_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc603c8>,
#  'way_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60438>,
#  'maze_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc604a8>,
#  'inner_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc604e0>,
#  'sanctum_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60518>,
#  'test_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60588>,
#  "'d_VBD": <gensim.models.keyedvectors.Vocab at 0x1a56dc605f8>,
#  'devise_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60630>,
#  'determine_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc60668>,
#  'suitability_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc606a0>,
#  'grow_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc606d8>,
#  'fond_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc60748>,
#  'remote_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc60780>,
#  'location_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc607b8>,
#  'bird_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60828>,
#  'eye_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60898>,
#  'view_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60908>,
#  'busy_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc60978>,
#  'street_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc609b0>,
#  'symbolize_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc609e8>,
#  'relationship_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60a20>,
#  'part_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60a90>,
#  'set_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60b00>,
#  'overall_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc60b38>,
#  'structure_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60b70>,
#  'institution_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60ba8>,
#  'discipline_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60be0>,
#  'repository_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60c18>,
#  'artifact_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc60c50>,
#  'engage_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc60c88>,
#  'solution_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc60cc0>,
#  'challenge_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc60cf8>,
#  'face_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc60d30>,
#  'society_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60d68>,
#  'course_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60da0>,
#  'association_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60dd8>,
#  'scientist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60e10>,
#  'teacher_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60e48>,
#  'author_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60e80>,
#  'social_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc60eb8>,
#  'activist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60ef0>,
#  'medium_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc60f28>,
#  'celebrity_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60f60>,
#  'success_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc60f98>,
#  'book_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69048>,
#  'come_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc69080>,
#  'age_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc690f0>,
#  'publish_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69128>,
#  'thrust_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69160>,
#  'spotlight_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69198>,
#  'comparison_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc691d0>,
#  'adolescence_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69208>,
#  'south_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69240>,
#  'sea_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc692b0>,
#  'time_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69320>,
#  'public_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69358>,
#  'concern_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69390>,
#  'transformation_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc693c8>,
#  'jazz_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69438>,
#  'youth_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69470>,
#  'early_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc694a8>,
#  'television_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc694e0>,
#  'become_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc69518>,
#  'widespread_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69550>,
#  'appear_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc69588>,
#  'cbs_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc695f8>,
#  'program_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69630>,
#  'adventure_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69668>,
#  'series_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc696a0>,
#  'produce_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc696d8>,
#  'live_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69748>,
#  'talk_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc697b8>,
#  'trance_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc697f0>,
#  'balinese_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69828>,
#  'impact_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69860>,
#  'war_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc698d0>,
#  'change_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69908>,
#  'society_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69940>,
#  'guinea_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69978>,
#  'flair_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc699b0>,
#  'write_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc699e8>,
#  'public_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69a20>,
#  'speaking_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69a58>,
#  'combine_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69a90>,
#  'belief_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69ac8>,
#  'anthropologist_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69b00>,
#  'museum_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69b38>,
#  'address_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc69b70>,
#  'contemporary_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69ba8>,
#  'issue_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69be0>,
#  'lead_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc69c18>,
#  'expert_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69c50>,
#  'human_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69c88>,
#  'unite_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69cc0>,
#  'nation_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69cf8>,
#  'conference_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69d30>,
#  'international_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69d68>,
#  'forum_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69da0>,
#  'consultant_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69dd8>,
#  'institution_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69e10>,
#  'organization_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc69e48>,
#  'discuss_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc69e80>,
#  'role_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69ef0>,
#  'change_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc69f28>,
#  'nature_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69f60>,
#  'family_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc69f98>,
#  'racial_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc69fd0>,
#  'inequality_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70048>,
#  'peaceful_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70080>,
#  'alternative_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc700b8>,
#  'population_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc700f0>,
#  'growth_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70128>,
#  'environmental_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70160>,
#  'degradation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70198>,
#  'creation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc701d0>,
#  'humane_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70208>,
#  'settlement_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70240>,
#  'wide-ranging_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70278>,
#  'concern_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc702b0>,
#  'humanity_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc702e8>,
#  'declare_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc70320>,
#  'mother_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70358>,
#  'surprising_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70390>,
#  'celebrate_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc703c8>,
#  'treasure_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70400>,
#  'margaret_NNP': <gensim.models.keyedvectors.Vocab at 0x1a56dc70438>,
#  'mead_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc70470>,
#  'list_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc704a8>,
#  'treasure_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc704e0>,
#  'no._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70550>,
#  'right_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70588>,
#  'folsom_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc705c0>,
#  'point_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc705f8>,
#  'peregrine_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70630>,
#  'falcon_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70668>,
#  'diorama_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc706a0>,
#  'guidebook_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc706d8>,
#  'state_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70710>,
#  'bring_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc70748>,
#  'serious_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70780>,
#  'work_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc707f0>,
#  'consciousness_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70828>,
#  'book_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70860>,
#  'course_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70898>,
#  'teach_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc708d0>,
#  'columbia_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70908>,
#  'university_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70940>,
#  'article_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70978>,
#  'write_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc709b0>,
#  'monthly_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc709e8>,
#  'column_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70a20>,
#  'frequent_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70a58>,
#  'interview_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70a90>,
#  'magazine_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70ac8>,
#  'newspaper_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70b00>,
#  'broadcast_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70b38>,
#  'radio_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70b70>,
#  'visit_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc70ba8>,
#  'last_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70c18>,
#  'spring_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70c50>,
#  'renovate_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70c88>,
#  'hall_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70cf8>,
#  'people_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70d30>,
#  'open_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70d68>,
#  'decade_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70da0>,
#  'begin_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc70dd8>,
#  'plan_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc70e10>,
#  'reopen_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc70e48>,
#  'please_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70e80>,
#  'see_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc70ef0>,
#  'incorporate_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70f28>,
#  'exhibition_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc70f60>,
#  'continuous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc70f98>,
#  'videotape_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc70fd0>,
#  'show_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a048>,
#  'photograph_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a080>,
#  'study_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a0b8>,
#  'quote_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a0f0>,
#  'note_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a128>,
#  'lecture_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a160>,
#  'collect_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a198>,
#  'give_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a208>,
#  'viewer_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a240>,
#  'insight_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a278>,
#  'process_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a2b0>,
#  'fieldwork_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a2e8>,
#  'add_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a358>,
#  'historical_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a390>,
#  'context_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a3c8>,
#  'presidential_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a400>,
#  'medal_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a438>,
#  'freedom_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a470>,
#  'receive_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a4a8>,
#  'president_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a4e0>,
#  'jimmy_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a518>,
#  'carter_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a550>,
#  'signature_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a588>,
#  'red_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a5f8>,
#  'cape_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a668>,
#  'stick_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a6a0>,
#  'label_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a6d8>,
#  'read_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a710>,
#  'late_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a780>,
#  'wear_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a7b8>,
#  'use_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a828>,
#  'style_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a860>,
#  'walk_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a898>,
#  'call_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a8d0>,
#  'thumbstick_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a908>,
#  'item_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a940>,
#  'familiar_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a978>,
#  'sight_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7a9b0>,
#  'dr._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7aa20>,
#  'travel_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc7aa58>,
#  'numerous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7aa90>,
#  'use_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ab00>,
#  'joke_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ab70>,
#  'want_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc7abe0>,
#  'recognize_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ac18>,
#  'leave_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ac50>,
#  'home_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7acc0>,
#  'fitting_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7acf8>,
#  'become_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ad30>,
#  'artifact_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ad68>,
#  'december_NNP': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ada0>,
#  'lecture_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7add8>,
#  'cosmic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ae10>,
#  'habitat_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ae48>,
#  'distinguish_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7ae80>,
#  'author_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7aeb8>,
#  'astronomy_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7aef0>,
#  'astronomer_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7af28>,
#  'royal_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7af60>,
#  'martin_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc7af98>,
#  'rees_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc7afd0>,
#  'royal_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82048>,
#  'professor_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82080>,
#  'cambridge_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc820b8>,
#  'p.m._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82128>,
#  'space_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82160>,
#  'theater_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82198>,
#  'hayden_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc821d0>,
#  'planetarium_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82208>,
#  'panel_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82240>,
#  'discussion_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82278>,
#  'use_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc822e8>,
#  'genome_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82320>,
#  'understand_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc82358>,
#  'ancestry_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82390>,
#  'moderate_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc823c8>,
#  'nicholas_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82400>,
#  'wade_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc82470>,
#  'york_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc824e0>,
#  'time_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82518>,
#  'biologist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82550>,
#  'andrew_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82588>,
#  'clark_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc825c0>,
#  'pennsylvania_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc825f8>,
#  'state_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82630>,
#  'douglas_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82668>,
#  'wallace_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc826a0>,
#  'center_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc826d8>,
#  'molecular_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82710>,
#  'medicine_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82748>,
#  'emory_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82780>,
#  'evolutionary_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc827b8>,
#  'joseph_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc827f0>,
#  'grave_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82828>,
#  'jr._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82898>,
#  'arizona_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc828d0>,
#  'kaufmann_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82908>,
#  'present_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82940>,
#  'conjunction_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82978>,
#  'genomic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc829b0>,
#  'revolution_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc829e8>,
#  'january_NNP': <gensim.models.keyedvectors.Vocab at 0x1a56dc82a20>,
#  'gallery_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82a58>,
#  'workshop_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82a90>,
#  'genetics_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82ac8>,
#  'a.m._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82b38>,
#  'follow-up_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82b70>,
#  'explanation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82ba8>,
#  'session_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82be0>,
#  'roundtable_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82c18>,
#  'presentation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82c50>,
#  'border_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82c88>,
#  'cross_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc82cc0>,
#  'cultural_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82cf8>,
#  'appropriation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82d30>,
#  'artistic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82d68>,
#  'art_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82dd8>,
#  'literature_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82e10>,
#  'indigenous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc82e48>,
#  'woman_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82e80>,
#  'identity_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82eb8>,
#  'border_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc82ef0>,
#  'writer_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82f28>,
#  'helena_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82f60>,
#  'maria_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc82f98>,
#  'cornell_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc82fd0>,
#  'artist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b048>,
#  'participant_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b080>,
#  'carol_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b0b8>,
#  'kind_JJR': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b0f0>,
#  'visit_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b128>,
#  'virgin_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b160>,
#  'guadalupe_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b198>,
#  '?_.': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b208>,
#  'artist_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b240>,
#  'henry_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b278>,
#  'street_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b2b0>,
#  'settlement_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b2e8>,
#  'art_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b358>,
#  'shuttle_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b390>,
#  'amnh_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b400>,
#  'lecture_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b438>,
#  'hubble_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b470>,
#  'machine_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b4a8>,
#  'frontier_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b4e0>,
#  'astrophysics_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b518>,
#  'james_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b550>,
#  'massachusetts_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b588>,
#  'amherst_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b5c0>,
#  'upcoming_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b5f8>,
#  'sky_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b668>,
#  'event_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b6a0>,
#  'celestial_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b6d8>,
#  'highlight_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b710>,
#  'lecturer_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b748>,
#  'amateur_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b780>,
#  'hank_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b7f0>,
#  'bartol_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b828>,
#  'kwanzaa_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b860>,
#  'celebration_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b898>,
#  'performance_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b8d0>,
#  'marketplace_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b908>,
#  'african_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b940>,
#  'holiday_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b978>,
#  'ocean_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b9b0>,
#  'schedule_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8b9e8>,
#  'call_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc8ba20>,
#  'visit_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc8ba58>,
#  'riddle_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8ba90>,
#  'compass_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bac8>,
#  'mathematician_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bb00>,
#  'amir_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bb70>,
#  'd._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bbe0>,
#  'weekend_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bc18>,
#  'program_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bc50>,
#  'america_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bc88>,
#  'arab_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bcf8>,
#  'american_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bd30>,
#  'asian_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bd68>,
#  'community-based_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bda0>,
#  'present_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bdd8>,
#  'film_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8be10>,
#  'talk_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8be48>,
#  'discussion_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8be80>,
#  'reading_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc8beb8>,
#  'leonhardt_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bef0>,
#  'frederick_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bf28>,
#  'p._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bf98>,
#  'rise_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dc8bfd0>,
#  'director_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95048>,
#  'charles_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95080>,
#  'follow_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc950b8>,
#  'beat_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95128>,
#  'base_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95160>,
#  'instrument_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95198>,
#  'neil_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95208>,
#  'clarke_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95240>,
#  'origin_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95278>,
#  'evolution_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc952b0>,
#  'sea_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95320>,
#  'marine_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95358>,
#  'richard_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95390>,
#  'ellis_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc953c8>,
#  'division_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95400>,
#  'paleontology_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95438>,
#  'tree_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc954a8>,
#  'decorate_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc954e0>,
#  'animal_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95518>,
#  'display_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95550>,
#  'theodore_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95588>,
#  'roosevelt_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc955c0>,
#  'memorial_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc955f8>,
#  'teacher_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95630>,
#  'resource_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95668>,
#  'musing_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc956a0>,
#  'web_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95710>,
#  'newsletter_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95748>,
#  'science_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95780>,
#  'educator_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc957b8>,
#  'toolong_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc957f0>,
#  'wall_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95828>,
#  'telephone_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95860>,
#  'science_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95898>,
#  'education_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc958d0>,
#  'nonprofit_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95908>,
#  'serve_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc95940>,
#  'information_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95978>,
#  'call_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc959e8>,
#  'toll-free_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95a20>,
#  'adult_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95a58>,
#  'begin_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc95a90>,
#  'choose_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc95ac8>,
#  'telescope_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95b00>,
#  'star_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95b38>,
#  'constellation_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95b70>,
#  'legend_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95ba8>,
#  'many_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95c18>,
#  'others_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95c50>,
#  'complete_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95c88>,
#  'description_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95cc0>,
#  'visit_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc95cf8>,
#  'news_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95d68>,
#  'biodiversity_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95da0>,
#  'conservation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95dd8>,
#  'go_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc95e48>,
#  'located_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95e80>,
#  'central_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95eb8>,
#  'park_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc95f28>,
#  '79th_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc95f98>,
#  'listing_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc95fd0>,
#  'exhibition_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c048>,
#  'hour_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c080>,
#  'site_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c0f0>,
#  'www.amnh.org_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c128>,
#  'show_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c198>,
#  'ticket_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c1d0>,
#  'retail_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c208>,
#  'product_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c240>,
#  'membership_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c278>,
#  'available_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c2b0>,
#  'online_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c2e8>,
#  'nancy_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c320>,
#  'c._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c390>,
#  'chair_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c3c8>,
#  'gender_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c400>,
#  'study_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c438>,
#  'associate_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c470>,
#  'southern_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c4a8>,
#  'california_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c4e0>,
#  'forthcoming_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c518>,
#  'icon_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c588>,
#  'finding_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c5c0>,
#  'reader_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c5f8>,
#  'cosmo_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c630>,
#  'animal_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c668>,
#  'behaviour_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c6a0>,
#  'obvious_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c6d8>,
#  'female_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c710>,
#  'right_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c748>,
#  'mate_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c7b8>,
#  'specie_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c7f0>,
#  'swan_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c828>,
#  'mate_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c860>,
#  'monogamous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c898>,
#  'monkey_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c8d0>,
#  'competency_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c908>,
#  'fatherhood_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c940>,
#  'potential_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c978>,
#  'desirable_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c9b0>,
#  'quality_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9c9e8>,
#  'court_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ca20>,
#  'male_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ca58>,
#  'display_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ca90>,
#  'paternal_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cac8>,
#  'skill_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cb00>,
#  'male_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cb70>,
#  'example_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cba8>,
#  'snatch_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cbe0>,
#  'worm_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cc18>,
#  'pretend_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cc50>,
#  'fee_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ccc0>,
#  'desire_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ccf8>,
#  'female_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cd30>,
#  'select_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cd68>,
#  'good_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cdd8>,
#  'high_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ce48>,
#  'list_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9ceb8>,
#  'female_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cef0>,
#  'homo_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cf60>,
#  'sapiens_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dc9cf98>,
#  'rat_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5048>,
#  'textbook_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5080>,
#  'decade_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca50b8>,
#  'psychologist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca50f0>,
#  'david_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5128>,
#  'm._NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5198>,
#  'bus_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5208>,
#  'publish_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dca5240>,
#  'celebrated_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5278>,
#  'study_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca52b0>,
#  'examine_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dca52e8>,
#  'attribute_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5320>,
#  'men_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5390>,
#  'desire_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca53c8>,
#  'canvass_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dca5400>,
#  'different_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5438>,
#  'culture_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5470>,
#  'race_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca54a8>,
#  'religion_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca54e0>,
#  'ethnicity_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5518>,
#  'live_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dca5550>,
#  'urban_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5588>,
#  'rural_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca55c0>,
#  'setting_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca55f8>,
#  'western_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5630>,
#  'develop_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dca5668>,
#  'capitalist_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca56a0>,
#  'socialist_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca56d8>,
#  'economy_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5710>,
#  'find_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dca5748>,
#  'likely_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5780>,
#  'consider_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dca57b8>,
#  'economic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca57f0>,
#  'prospect_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5828>,
#  'priority_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5860>,
#  'interpret_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5898>,
#  'sign_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5908>,
#  'want_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dca5940>,
#  'mate_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5978>,
#  'effective_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca59b0>,
#  'one_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5a20>,
#  'imagine_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dca5a58>,
#  'generate_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dca5a90>,
#  'sort_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5ac8>,
#  'unsettling_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5b00>,
#  'accusation_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dca5b38>,
#  'political_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5b70>,
#  'pair_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dca5be0>,
#  'reproduce_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dca5c18>,
#  'choose_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dca5c50>,
#  'particular_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5c88>,
#  'male_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5cf8>,
#  'basis_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5d30>,
#  'treat_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dca5d68>,
#  'offspring_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5da0>,
#  'olive_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5dd8>,
#  'baboon_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5e10>,
#  'prize_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5e48>,
#  'catch_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5e80>,
#  'foul_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5ef0>,
#  'mood_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5f60>,
#  'direct_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dca5f98>,
#  'aggression_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dca5fd0>,
#  'go_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcad080>,
#  'get_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcad0f0>,
#  'assistance_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad128>,
#  'much_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad198>,
#  'contact_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad1d0>,
#  'line_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad240>,
#  'integrate_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad278>,
#  'group_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcad2b0>,
#  'typical_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad2e8>,
#  'arrangement_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad320>,
#  'golden_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad358>,
#  'hamster_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcad390>,
#  'stable_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad3c8>,
#  'group_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad400>,
#  'boot_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad438>,
#  'long_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad4a8>,
#  'young_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad4e0>,
#  'bear_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad518>,
#  'call_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcad588>,
#  'harem_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad5c0>,
#  'primatologist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad5f8>,
#  'alison_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad630>,
#  'suggest_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad668>,
#  'call_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad6a0>,
#  'get_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad710>,
#  'brief_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad748>,
#  'liaison_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad780>,
#  'sperm_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad7b8>,
#  'pack_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad7f0>,
#  'gene_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcad828>,
#  'age-old_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcad860>,
#  'problem_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcad898>,
#  'figure_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcad8d0>,
#  'try_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcad940>,
#  'advertise_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcad978>,
#  'peacock_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcad9b0>,
#  'spread_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcad9e8>,
#  'gorgeous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcada20>,
#  'tail_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcada90>,
#  'fan_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadb00>,
#  'lion_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadb38>,
#  'elaborate_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcadb70>,
#  'mane_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadba8>,
#  'elk_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcadc18>,
#  'ornate_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcadc50>,
#  'antler_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadc88>,
#  'feature_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadcc0>,
#  'ornamental_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcadcf8>,
#  'useful_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcadd30>,
#  'purpose_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcadd68>,
#  'sexual_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcadda0>,
#  'attraction_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcaddd8>,
#  'question_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcade10>,
#  'vex_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcade80>,
#  'biologist_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadeb8>,
#  'ornament_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcadef0>,
#  'tell_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcadf28>,
#  'anything_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcadf60>,
#  'genetic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcadf98>,
#  'health_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcadfd0>,
#  'word_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5048>,
#  'truth_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5080>,
#  'advertising_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb50b8>,
#  'british_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcb50f0>,
#  'statistician_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5128>,
#  'geneticist_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5160>,
#  'ronald_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5198>,
#  'fisher_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcb51d0>,
#  'ornamentation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5208>,
#  'something_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5240>,
#  'attract_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5278>,
#  'huge_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcb52e8>,
#  'energy_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5320>,
#  'expenditure_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5358>,
#  'grow_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcb53c8>,
#  'maintain_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5400>,
#  'price_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5438>,
#  'tag_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb54a8>,
#  'term_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcb54e0>,
#  'darwinian_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5518>,
#  'fitness_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5550>,
#  'accord_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5588>,
#  'spend_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb55c0>,
#  'lot_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5630>,
#  'calorie_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5668>,
#  'grow_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcb56a0>,
#  'big_JJS': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5710>,
#  'sensible_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5748>,
#  'keep_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5780>,
#  'immune_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcb57b8>,
#  'system_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb57f0>,
#  'tune_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5828>,
#  'fisher_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5860>,
#  'fall_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcb5898>,
# ...
#  'interested_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0978>,
#  'use_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcc09e8>,
#  'low-tech_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0a20>,
#  'scientific_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0a58>,
#  'artifice_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0a90>,
#  'turn_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0b00>,
#  'appear_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0b38>,
#  'say_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0ba8>,
#  'surround_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0be0>,
#  'indifferent_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0c18>,
#  'decide_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0c50>,
#  "'s_VBZ": <gensim.models.keyedvectors.Vocab at 0x1a56dcc0cc0>,
#  'kinda_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0cf8>,
#  'cute_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0d68>,
#  'bandwagon_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0da0>,
#  'effect_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0dd8>,
#  'seem_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0e10>,
#  'mean_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0e80>,
#  'decide_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0eb8>,
#  'neon_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0f28>,
#  'hot_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0f98>,
#  'commodity_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc0fd0>,
#  'think_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6048>,
#  'look_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc60b8>,
#  'ridiculous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc60f0>,
#  'advantage_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6128>,
#  'mate_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6198>,
#  'rage_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6208>,
#  'order_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6240>,
#  'maximize_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6278>,
#  'pass_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcc62b0>,
#  'copy_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcc62e8>,
#  'circular_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6320>,
#  'logic_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6358>,
#  'trait_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6390>,
#  'become_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc63c8>,
#  'carry_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6400>,
#  'carrier_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6438>,
#  'possibility_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6470>,
#  'translate_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc64a8>,
#  'meaningful_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc64e0>,
#  'message_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6518>,
#  'bet_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6588>,
#  "'m_VBP": <gensim.models.keyedvectors.Vocab at 0x1a56dcc65f8>,
#  'afford_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6630>,
#  'waste_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6668>,
#  'three-foot-long_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc66a0>,
#  'feather_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcc66d8>,
#  'marlene_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6710>,
#  'biology_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6748>,
#  'formalize_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6780>,
#  'notion_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc67b8>,
#  'expensive_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc67f0>,
#  'signal_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6828>,
#  'free_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6898>,
#  'parasite_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcc68d0>,
#  'see_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6940>,
#  'charming_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6978>,
#  'response_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc69b0>,
#  'april_NNP': <gensim.models.keyedvectors.Vocab at 0x1a56dcc69e8>,
#  'find_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6a58>,
#  'appeal_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6a90>,
#  'decrease_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6ac8>,
#  'likelihood_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6b00>,
#  'wind_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6b70>,
#  'guy_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6be0>,
#  'reproduce_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6c18>,
#  'organism_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6c50>,
#  'need_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6c88>,
#  'worry_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6cc0>,
#  'transmitted_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6cf8>,
#  'disease_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6d30>,
#  'version_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6d68>,
#  'basic_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6da0>,
#  'theme_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6dd8>,
#  'signal_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6e10>,
#  'pass_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6e48>,
#  'next_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6eb8>,
#  'generation_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6ef0>,
#  'zahavi_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6f28>,
#  'tel_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcc6f98>,
#  'aviv_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce048>,
#  'israel_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce080>,
#  'posit_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce0b8>,
#  'evolve_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce0f0>,
#  'ability_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce128>,
#  'differentiate_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcce160>,
#  'reflect_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce198>,
#  'kind_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce208>,
#  'acquire_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce240>,
#  'least_JJS': <gensim.models.keyedvectors.Vocab at 0x1a56dcce278>,
#  'method_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcce2b0>,
#  'answer_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce2e8>,
#  'isolate_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcce320>,
#  'responsible_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce358>,
#  'certain_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce390>,
#  'tend_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcce3c8>,
#  'inherit_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce400>,
#  'reliable_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce438>,
#  'figure_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcce470>,
#  'function_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce4a8>,
#  'protein_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcce4e0>,
#  'neighbor_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcce518>,
#  'advantageous_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce550>,
#  'race_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce5c0>,
#  'sequence_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce5f8>,
#  'old-fashioned_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce630>,
#  'carry_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcce668>,
#  'mat_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce6d8>,
#  'differ_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcce710>,
#  'father_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce748>,
#  'fit_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce7b8>,
#  'adulthood_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce7f0>,
#  'produce_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcce828>,
#  "'ve_VBP": <gensim.models.keyedvectors.Vocab at 0x1a56dcce898>,
#  'get_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcce908>,
#  'reason_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcce940>,
#  'conclude_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcce978>,
#  'pass_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcce9b0>,
#  'adaptive_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcce9e8>,
#  'assemblage_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dccea20>,
#  'number_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dccea58>,
#  'show_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dccea90>,
#  'cast_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcceac8>,
#  'big_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcceb38>,
#  'vote_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcceba8>,
#  'hypothesis_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dccebe0>,
#  'startling_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dccec18>,
#  'creep_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dccec50>,
#  'duck_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dccec88>,
#  'emma_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dccecf8>,
#  'cunningham_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcced30>,
#  'march_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcced68>,
#  'mallard_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcceda0>,
#  'increase_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dccedd8>,
#  'vote_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dccee10>,
#  'lay_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dccee80>,
#  'large_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcceeb8>,
#  'egg_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dccef28>,
#  'factor_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dccef60>,
#  'size_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dccefd0>,
#  'invest_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7048>,
#  'result_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7080>,
#  'make_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcd70b8>,
#  'fact_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7128>,
#  'russell_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7160>,
#  'control_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7198>,
#  'egg_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7208>,
#  'difference_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7240>,
#  'similar_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7278>,
#  'journal_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd72b0>,
#  'october_NNP': <gensim.models.keyedvectors.Vocab at 0x1a56dcd72e8>,
#  'diego_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7320>,
#  'gil_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7390>,
#  'colleague_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd73c8>,
#  'saint_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7400>,
#  'andrew_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7438>,
#  'zebra_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7470>,
#  'finch_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd74a8>,
#  'beg_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7518>,
#  'food_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7588>,
#  'fledge_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcd75c0>,
#  'develop_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcd75f8>,
#  'contain_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7630>,
#  'hormone_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7668>,
#  'lope_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd76d8>,
#  'spain_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7710>,
#  'anders_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7748>,
#  'moller_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7780>,
#  'universit_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd77b8>,
#  'pierre_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd77f0>,
#  'curie_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7828>,
#  'france_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7860>,
#  'show_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7898>,
#  'barn_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7908>,
#  'swallow_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7940>,
#  'take_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7978>,
#  'good_JJR': <gensim.models.keyedvectors.Vocab at 0x1a56dcd79b0>,
#  'care_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7a20>,
#  'chick_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7a58>,
#  'logical_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7a90>,
#  'extension_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7ac8>,
#  'uncover_VBN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7b00>,
#  'starter_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7b38>,
#  'everyone_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7b70>,
#  'want_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7ba8>,
#  'seem_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7c18>,
#  'best_JJS': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7c50>,
#  'interest_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7c88>,
#  'know_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7cc0>,
#  'make_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7cf8>,
#  'carry_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7d30>,
#  'well-being_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7d68>,
#  'challenge_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7da0>,
#  'translate_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7dd8>,
#  'investment_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7e10>,
#  'knowledge_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7e48>,
#  'level_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7e80>,
#  'exist_VBZ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7eb8>,
#  'brain_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7ef0>,
#  'synthesize_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7f28>,
#  'gland_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7f60>,
#  'extra_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcd7f98>,
#  'mile_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd048>,
#  'eat_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd0b8>,
#  'classical_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd0f0>,
#  'dichotomy_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd128>,
#  'proximal_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd160>,
#  'distal_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd198>,
#  'concern_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd1d0>,
#  'simple_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd208>,
#  'invest_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd240>,
#  'trait_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd278>,
#  'enhance_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd2b0>,
#  'nut_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd320>,
#  'bolt_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd358>,
#  'hormone_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd390>,
#  'neural_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd3c8>,
#  'pathway_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd400>,
#  'great_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd438>,
#  'mystery_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd470>,
#  'amount_NN': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd4a8>,
#  'parental_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd4e0>,
#  'generate_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd518>,
#  'problem_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd550>,
#  'big_JJR': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd5c0>,
#  'raise_VBD': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd5f8>,
#  'underlie_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd630>,
#  'kid_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd6a0>,
#  'make_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd710>,
#  'sure_JJ': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd780>,
#  'survive_VBP': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd7b8>,
#  'researcher_NNS': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd7f0>,
#  'hatch_VBG': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd828>,
#  'exist_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd860>,
#  'disprove_VB': <gensim.models.keyedvectors.Vocab at 0x1a56dcdd898>,
#  ...}

# %%
from sklearn.manifold import TSNE
import re
import matplotlib.pyplot as plt
import pandas as pd

X = model[model.wv.vocab] # get list of word vectors
vocab = list(model.wv.vocab)
X = model[vocab]

print(len(X))
print(X[0])
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

df = pd.concat([pd.DataFrame(X_tsne), pd.Series(vocab)], axis = 1)
df.columns = ['x', 'y', 'word']

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for i, txt in enumerate(df['word']):
    ax.annotate(txt, (df['x'].iloc[i], df['y'].iloc[i]))
