# %% [markdown]
# # Pre-process function

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess
from nltk.stem import WordNetLemmatizer
import re

def preprocess(file_dir):
    
    ### Settings ###
    #Stop words
    stopWords = set(stopwords.words('english'))
    processed_text = []

    # WordNet can take POS tags too
    lemmatizer = WordNetLemmatizer()

    # Title pattern
    title = re.compile(r"%&%.*%&%")

    ####### NLP ######
    # read
    text = open(file_dir, 'r', encoding = 'utf-8').read()

    # replace title with blank
    text = re.sub(title, "", text)

    # rids special chars and lower cases
    text = simple_preprocess(text)

    # filters stop words
    text = [word for word in text if word not in stopWords]

    # lemmatization
    text = [lemmatizer.lemmatize(word) for word in text]

    return text # list of processed words

# %% [markdown]
# ### Get file list from dir

# %%
import os

directory = r"D:\COCA & GloWbE\COCA\Pre-processed Text\Science-related texts"
file_list = [file for file in os.listdir(directory) if file.endswith('.txt')]

print( len(file_list), "text files detected!")
# Out:
# 10258 text files detected!

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


def draw_cloud(text_string):
#     wordcloud = WordCloud().generate(text = text_string)

#     plt.imshow(wordcloud, interpolation='bilinear')
#     plt.axis("off")

    # lower max_font_size
    wordcloud = WordCloud(max_font_size=40).generate(text = text_string)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    
# For showing in a new window  
#     wordcloud = WordCloud().generate(text = text_string)
#     image = wordcloud.to_image()
#     image.show()

# %% [markdown]
# #### Word cloud for eachc article (control by index num)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for file in file_list[-5:]:
    print("File name:", file)
    text = preprocess(os.path.join(directory, file))
    print(text[0:100])
    processed = ' '.join(text)
    print(len(processed))
    draw_cloud(processed)
# Out:
# File name: news_9995.txt
# ['believe', 'another', 'way', 'low', 'budget', 'low', 'tech', 'alternative', 'rugged', 'individualist', 'enter', 'hypothetical', 'flying', 'machine', 'called', 'cislunar', 'space', 'cruiser', 'betting', 'heavy', 'odds', 'independent', 'rosslyn', 'engineer', 'developed', 'plan', 'private', 'corp', 'astronaut', 'could', 'punch', 'morning', 'coffee', 'six', 'eight', 'hour', 'stay', 'orbit', 'home', 'supper', 'operation', 'designed', 'provide', 'quick', 'response', 'low', 'cost', 'orbital', 'swat', 'team', 'hire', 'cruiser', 'shaped', 'like', 'slightly', 'squashed', 'ice', 'cream', 'cone', 'cluster', 'rocket', 'nozzle', 'ice', 'cream', 'end', 'seat', 'one', 'two', 'people', 'small', 'cheap', 'dumb', 'booster', 'rocket', 'would', 'deliver', 'crew', 'cruiser', 'equipment', 'orbit', 'exact', 'orbit', 'would', 'matter', 'much', 'cruiser', 'high', 'maneuverability', 'could', 'get', 'right', 'place', 'perform', 'spaceborne', 'utility', 'infielder', 'saving', 'falling', 'satellite', 'rescuing']
# 4463
# File name: news_9996.txt
# ['wave', 'plunge', 'onto', 'rock', 'northern', 'california', 'coast', 'white', 'sand', 'many', 'hued', 'water', 'inspired', 'artist', 'photographer', 'alike', 'standing', 'shore', 'mark', 'denny', 'decidedly', 'unorthodox', 'appreciation', 'setting', 'others', 'see', 'stuff', 'robert', 'wood', 'painting', 'observes', 'consummate', 'example', 'engineering', 'design', 'associate', 'professor', 'stanford', 'university', 'hopkins', 'marine', 'station', 'dr', 'denny', 'leading', 'authority', 'marine', 'biomechanics', 'hybrid', 'discipline', 'combining', 'marine', 'biology', 'mechanical', 'engineering', 'name', 'may', 'sound', 'formidable', 'field', 'deal', 'familiar', 'posing', 'basic', 'question', 'might', 'occur', 'someone', 'casually', 'strolling', 'beach', 'ask', 'biomechanics', 'scientist', 'mussel', 'algae', 'intertidal', 'sea', 'creature', 'withstand', 'constant', 'pounding', 'wave', 'quite', 'remarkable', 'denny', 'say', 'biological', 'standpoint', 'intertidal', 'zone', 'greater', 'diversity', 'life', 'region', 'except', 'coral', 'reef', 'rain', 'forest']
# 4543
# File name: news_9997.txt
# ['israel', 'aggressively', 'pursuing', 'space', 'program', 'economic', 'military', 'reason', 'said', 'akiva', 'bar', 'nun', 'coordinator', 'israel', 'space', 'agency', 'isa', 'day', 'country', 'launched', 'second', 'satellite', 'last', 'month', 'spy', 'satellite', 'camera', 'dr', 'bar', 'nun', 'said', 'although', 'israel', 'export', 'primarily', 'agricultural', 'sell', 'many', 'orange', 'bar', 'nun', 'said', 'interview', 'demonstrating', 'produce', 'launch', 'reliable', 'satellite', 'israel', 'hope', 'earn', 'slice', 'world', 'billion', 'year', 'space', 'market', 'said', 'israel', 'space', 'agency', 'purely', 'civilian', 'belong', 'ministry', 'science', 'technology', 'absolutely', 'military', 'involvement', 'said', 'nevertheless', 'launch', 'came', 'day', 'president', 'saddam', 'hussein', 'iraq', 'threatened', 'destroy', 'half', 'israel', 'chemical', 'weapon', 'nation', 'attacked', 'iraq', 'shimon', 'peres', 'leader', 'israel', 'labor', 'party', 'want', 'deal', 'israel', 'look', 'mean', 'military']
# 4064
# File name: news_9998.txt
# ['since', 'late', 'genetic', 'engineer', 'tantalized', 'rest', 'u', 'vision', 'wonder', 'hope', 'work', 'crop', 'plant', 'farm', 'include', 'coffee', 'tree', 'yield', 'flavorful', 'bean', 'low', 'caffeine', 'corn', 'rich', 'lysine', 'essential', 'amino', 'acid', 'today', 'maize', 'lack', 'drought', 'tolerant', 'wheat', 'genetic', 'planner', 'even', 'larger', 'goal', 'according', 'howard', 'schneiderman', 'vice', 'president', 'research', 'monsanto', 'agricultural', 'company', 'st', 'louis', 'plant', 'become', 'central', 'way', 'making', 'thing', 'genetic', 'engineer', 'say', 'persuade', 'plant', 'make', 'many', 'useful', 'product', 'make', 'naturally', 'plant', 'genetic', 'system', 'ghent', 'belgium', 'point', 'way', 'canola', 'variety', 'rapeseed', 'produce', 'pharmaceutical', 'blood', 'factor', 'growth', 'hormone', 'andrew', 'hiatt', 'robert', 'cafferkey', 'katherine', 'bowdish', 'research', 'institute', 'scripps', 'clinic', 'la', 'jolla', 'calif', 'reinforced', 'vision', 'showing', 'protein']
# 5857
# File name: news_9999.txt
# ['sunlight', 'central', 'source', 'united', 'state', 'energy', 'st', 'century', 'sprawling', 'low', 'rise', 'campus', 'solar', 'energy', 'research', 'institute', 'seri', 'answer', 'resounding', 'yes', 'politically', 'answer', 'may', 'coming', 'time', 'conventional', 'source', 'power', 'generation', 'coal', 'oil', 'natural', 'gas', 'coming', 'increasing', 'fire', 'environmentally', 'conscious', 'public', 'concerned', 'global', 'warming', 'acid', 'rain', 'air', 'pollution', 'also', 'concern', 'national', 'security', 'implication', 'dependence', 'oil', 'nearly', 'percent', 'imported', 'nuclear', 'energy', 'touted', 'environmentally', 'clean', 'alternative', 'suffering', 'continuing', 'revelation', 'following', 'explosion', 'soviet', 'nuclear', 'reactor', 'chernobyl', 'power', 'station', 'political', 'difficulty', 'surrounding', 'start', 'seabrook', 'nuclear', 'power', 'plant', 'new', 'hampshire', 'seen', 'many', 'portent', 'greater', 'challenge', 'facing', 'nuclear', 'energy', 'installation', 'future', 'sunlight', 'fill', 'gap', 'say', 'robert', 'stokes', 'deputy']
# 5191

# %% [markdown]
# #### Word Cloud for each genre

# %%
acad_files = [file for file in file_list if file.startswith("acad")]
mag_files = [file for file in file_list if file.startswith("mag")]
news_files = [file for file in file_list if file.startswith("news")]

print( len(acad_files) , "academic texts\n",
       len(mag_files) , "magazine texts\n",
       len(news_files) , "newspaper texts")
# Out:
# 4155 academic texts
#  5781 magazine texts
#  322 newspaper texts

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

all_text = ""

for file in acad_files:
    print("Academic texts", file)
    text = preprocess(os.path.join(directory, file))
    processed = ' '.join(text)
    all_text += processed 
    print(len(all_text))

draw_cloud(processed)
# Out:
# Academic texts acad_5782.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-3f989d1918d6> in <module>()
#       6     text = preprocess(os.path.join(directory, file))
#       7     processed = ' '.join(text)
# ----> 8     whole_text += processed
#       9     print(len(whole_text))
#      10
#
# NameError: name 'whole_text' is not defined

# %% [markdown]
# ### * In case of converting list to counts

# %%
from collections import Counter
counts = dict(Counter(text))
print(counts)
# Out:
# {'sunlight': 4, 'central': 1, 'source': 7, 'united': 3, 'state': 4, 'energy': 24, 'st': 1, 'century': 2, 'sprawling': 1, 'low': 1, 'rise': 1, 'campus': 1, 'solar': 11, 'research': 7, 'institute': 2, 'seri': 6, 'answer': 2, 'resounding': 1, 'yes': 1, 'politically': 1, 'may': 1, 'coming': 2, 'time': 1, 'conventional': 4, 'power': 13, 'generation': 1, 'coal': 2, 'oil': 6, 'natural': 1, 'gas': 6, 'increasing': 1, 'fire': 1, 'environmentally': 2, 'conscious': 1, 'public': 2, 'concerned': 1, 'global': 2, 'warming': 2, 'acid': 1, 'rain': 1, 'air': 2, 'pollution': 2, 'also': 2, 'concern': 1, 'national': 1, 'security': 1, 'implication': 1, 'dependence': 1, 'nearly': 3, 'percent': 10, 'imported': 1, 'nuclear': 7, 'touted': 1, 'clean': 1, 'alternative': 5, 'suffering': 1, 'continuing': 2, 'revelation': 1, 'following': 2, 'explosion': 1, 'soviet': 1, 'reactor': 1, 'chernobyl': 1, 'station': 2, 'political': 1, 'difficulty': 1, 'surrounding': 1, 'start': 1, 'seabrook': 1, 'plant': 7, 'new': 2, 'hampshire': 1, 'seen': 1, 'many': 4, 'portent': 1, 'greater': 1, 'challenge': 2, 'facing': 1, 'installation': 1, 'future': 1, 'fill': 1, 'gap': 1, 'say': 14, 'robert': 1, 'stokes': 3, 'deputy': 1, 'director': 1, 'year': 4, 'old': 1, 'facility': 1, 'owned': 1, 'u': 2, 'department': 1, 'currently': 1, 'budgeted': 1, 'million': 1, 'believe': 1, 'government': 1, 'set': 1, 'course': 1, 'gradually': 1, 'increase': 1, 'development': 2, 'investment': 2, 'renewable': 2, 'point': 1, 'technology': 13, 'become': 2, 'cost': 6, 'effective': 3, 'mr': 2, 'researcher': 3, 'taking': 1, 'expanded': 1, 'view': 1, 'word': 1, 'use': 2, 'cover': 2, 'resource': 5, 'ultimately': 2, 'derive': 1, 'sun': 3, 'including': 2, 'wind': 5, 'combustion': 1, 'organic': 1, 'biomass': 3, 'product': 1, 'wave': 1, 'tidal': 1, 'thermal': 3, 'gradient': 1, 'ocean': 1, 'number': 2, 'already': 8, 'certain': 2, 'application': 2, 'much': 3, 'closer': 1, 'today': 4, 'eight': 1, 'ago': 1, 'eventual': 1, 'economic': 1, 'parity': 1, 'variety': 1, 'tom': 1, 'bath': 4, 'manager': 1, 'photovoltaics': 2, 'pv': 4, 'direct': 2, 'conversion': 6, 'electricity': 3, 'using': 1, 'solid': 2, 'photo': 1, 'cell': 2, 'powering': 1, 'satellite': 1, 'since': 1, 'vanguard': 1, 'launched': 1, 'choice': 1, 'small': 1, 'far': 1, 'grid': 2, 'rural': 1, 'water': 3, 'pump': 1, 'communication': 1, 'relay': 1, 'vaccine': 1, 'refrigerator': 1, 'third': 2, 'world': 2, 'nation': 6, 'even': 1, 'competitive': 2, 'remote': 1, 'home': 1, 'mile': 1, 'dr': 2, 'pay': 1, 'buy': 1, 'battery': 2, 'rather': 1, 'try': 1, 'hook': 1, 'like': 1, 'luz': 2, 'international': 1, 'kramer': 1, 'junction': 1, 'calif': 2, 'acre': 1, 'trough': 1, 'shaped': 1, 'mirror': 1, 'focus': 1, 'ray': 1, 'vacuum': 1, 'insulated': 1, 'tube': 1, 'heated': 1, 'degree': 1, 'used': 1, 'generate': 2, 'superheated': 1, 'steam': 1, 'drive': 2, 'turbine': 3, 'generator': 1, 'le': 1, 'cent': 2, 'per': 2, 'kilowatt': 3, 'hour': 3, 'official': 1, 'cheaper': 1, 'producing': 2, 'megawatt': 2, 'southern': 1, 'california': 2, 'reach': 1, 'almost': 1, 'enough': 1, 'meet': 2, 'entire': 1, 'residential': 1, 'need': 5, 'city': 1, 'size': 1, 'san': 1, 'francisco': 1, 'phoenix': 1, 'typically': 1, 'generated': 1, 'windmill': 1, 'farm': 1, 'located': 2, 'high': 1, 'mountain': 1, 'pass': 1, 'west': 1, 'viable': 1, 'industry': 1, 'alone': 2, 'billion': 2, 'medium': 1, 'sized': 1, 'nonpolluting': 1, 'paul': 1, 'gipe': 1, 'american': 1, 'association': 1, 'tehachapi': 1, 'offset': 1, 'pound': 1, 'greenhouse': 2, 'would': 1, 'otherwise': 1, 'pour': 1, 'atmosphere': 1, 'take': 1, 'form': 1, 'wood': 1, 'burning': 1, 'municipal': 1, 'waste': 1, 'supplying': 1, 'potential': 2, 'complex': 1, 'biological': 1, 'crop': 1, 'alcohol': 1, 'fuel': 3, 'biogas': 1, 'cultivation': 1, 'microalgae': 1, 'oilseed': 1, 'synthetic': 1, 'limited': 3, 'operation': 1, 'taken': 1, 'together': 1, 'could': 2, 'produce': 3, 'hydrogen': 5, 'vapor': 1, 'burn': 1, 'increasingly': 1, 'considered': 1, 'transportation': 1,  ...
