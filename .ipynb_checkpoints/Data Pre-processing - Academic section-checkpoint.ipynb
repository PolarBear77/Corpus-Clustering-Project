# %% [markdown]
# # 1. Basic Settings

# %%
import gensim
import os
import logging

# Log settings
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# c:\nlp\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %%
# Note that this imports ALL FILES in dir
class MySentences(object):

    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield gensim.utils.simple_preprocess(line)

# a memory - friendly iterator
sentences = MySentences('D:\\coca and GloWbE\\coca\\temp\\text2doc')

# %% [markdown]
# # 2. (skip) Preprocessing - Dividing text in file into Docs

# %% [markdown]
# Each file has hundreds of documents, with number tags leading the start of each article
# i.e) ##300000, ##300001, #300002 . . .

# %%
for i in range(1990, 2013): # reads each text at directory and prints a few lines
    file = open("D:\\COCA & GloWbE\\COCA\\texts\\text_academic_rpe\\w_acad_%d.txt" % i)
    newtext = file.read()
    print("File", str(i), ":", newtext[1:100], "\n")
    file.close()
# Out:
# File 1990 : ##4000161 Section : Life and Letters <p> I do n't remember hearing the phrase " white guilt " very
#
# File 1991 : ##4000171 Scientific fraud has become a very hot topic . Most scientists have traditionally believe
#
# File 1992 : ##4000003 Long-term data on community dynamics are a necessary part of research studies <p> Conserv
#
# File 1993 : ##4000011 Section : Features Animals and plants of the floodplain thrive , while river researchers
#
# File 1994 : ##4000031 Section : Features Grassroots efforts and the Constitution hold their own against religio
#
# File 1995 : ##4000208 A Scholar in Washington <p> I guess I was ready when the call came . Although hard at wor
#
# File 1996 : ##4000046 Section : Features A crane's-eye-view of Panama 's forest canopy yields biological surpri
#
# File 1997 : ##4000054 Section : Features Research sheds new light on the origin of humanity 's most intimate qu
#
# File 1998 : ##4000061 Section : Features Elegant experiments confirm long-held theory of cellular aging <p> The
#
# File 1999 : ##4000070 Section : Features Study of the natural sources of many animals ' chemical defenses is pr
#
# File 2000 : ##4000077 Research on Kona slope shows promise for native ecosystem recovery <p> A half-dozen black
#
# File 2001 : ##1008237 ABSTRACT Headnote The paper summarises the key elements contained in recent proposals to
#
# File 2002 : ##4000092 Section : Viewpoint <p> Humanity confronts an enormous task : stimulating economic growth
#
# File 2003 : ##4000104 Section : Articles <p> The Multiscale Experimental Ecosystem Research Center has conducte
#
# File 2004 : ##4000110 Section : Feature What DNA-based techniques are revealing about the planet 's hidden biod
#
# File 2005 : ##4000124 Section : Articles <p> Ficus ( Moraceae ) is arguably one of the most important plant gen
#
# File 2006 : ##4000142 Section : Viewpoint <p> The quantitative synthesis research results is of fundamental imp
#
# File 2007 : ##4020260 Who knew that mixing the intelligent and the idiosyncratic would yield a long life for a
#
# File 2008 : ##4021936 Following the minority stress model as a framework , we examine the associations between
#
# File 2009 : ##4070597 During the last ten years , an infusion of private foundation and government funding mark
#
# File 2010 : ##4080515 In a 2009 article in Archaeology Charles Stanish , director of the UCLA Cotsen Institute
#
# File 2011 : ##4088889 Letter from SRI LANKA </p> ON THE MORNING of January 8 , 2009 , Lasantha Wickrematunge wa
#
# File 2012 : ##4119509 acm s annual report for fY11 aCM membership reached another all-time high for the ninth c

# %% [markdown]
# # Segement each yearly file to seperate documents

# %%
import re

doc_index = 1

for i in range(1990, 2013):
    file = open("D:\\COCA & GloWbE\\COCA\\texts\\text_academic_rpe\\w_acad_%d.txt" % i)
    newtext = file.read()
    
    # close file after reading
    file.close()
    
    text_ids = re.findall('\n##\d+', newtext)
    
    # Split file between " (line break) hash hash number+ "
    p = re.split('\n##\d+', newtext)
    p = p[1:] # due to list.split() the 1st item is blank
    p = list(zip(text_ids, p)) # zip text ids & text
    p = [''.join(item) for item in p ]
    
    print("File w_acad_%d" % i, "-", "Number of files : ", len(p))

    
    for f in p: # Writes out each element of list (=article) as a new file
        
        new_file = open(("D:\\COCA & GloWbe\\COCA\\Pre-processed text\\Doc2Vec Docs - Acad\\acad_%d.txt" % doc_index), 'w')
        new_file.write(f)

        doc_index += 1
        
print("Total number of files:", doc_index)
# Out:
# File w_acad_1990 - Number of files :  872
# File w_acad_1991 - Number of files :  890
# File w_acad_1992 - Number of files :  877
# File w_acad_1993 - Number of files :  907
# File w_acad_1994 - Number of files :  931
# File w_acad_1995 - Number of files :  946
# File w_acad_1996 - Number of files :  943
# File w_acad_1997 - Number of files :  994
# File w_acad_1998 - Number of files :  875
# File w_acad_1999 - Number of files :  839
# File w_acad_2000 - Number of files :  866
# File w_acad_2001 - Number of files :  870
# File w_acad_2002 - Number of files :  901
# File w_acad_2003 - Number of files :  974
# File w_acad_2004 - Number of files :  937
# File w_acad_2005 - Number of files :  940
# File w_acad_2006 - Number of files :  994
# File w_acad_2007 - Number of files :  1157
# File w_acad_2008 - Number of files :  912
# File w_acad_2009 - Number of files :  1103
# File w_acad_2010 - Number of files :  993
# File w_acad_2011 - Number of files :  1054
# File w_acad_2012 - Number of files :  451
# Total number of files: 21227

# %% [markdown]
# # 3. Extracting Science-related article numbers

# %% [markdown]
# ## 3.1 COCA excel sheet
# - containins year, domain, date, author, etc. for each text

# %%
import xlrd
workbook = xlrd.open_workbook('D:\COCA & GloWbE\COCA\coca_2015_12_23.xlsx')

# %%
# Print out sheet name
for i, sheet in enumerate(workbook.sheets()):
    print("Sheet",i+1 ,":" , sheet.name)
# Out:
# Sheet 1 : introduction
# Sheet 2 : TOTALS
# Sheet 3 : spoken
# Sheet 4 : fiction
# Sheet 5 : magazine
# Sheet 6 : newspaper
# Sheet 7 : academic
# Sheet 8 : Sheet1

# %% [markdown]
# ### Academic excel sheet

# %%
acad_sheet = workbook.sheets()[6]

# Headers - column "domain" is at 4th col 
print(acad_sheet.row_values(0))
# Out:
# ['textID', '# words', 'Year', 'Domain', 'Journal', 'Title', 'Author', 'PubInfo', 'Subject']

# %% [markdown]
# Our column of interest 'domain' is the 4th column. <br>
# We iterate through each row and check the 4th column for "Sci/Tech", which has 4356 articles

# %%
sci_text_rows = []

for i in range(acad_sheet.nrows):
    
    row = acad_sheet.row_values(i)
    
    if("Sci/Tech" in row[3]): # row[3] == 'Domain'
        sci_text_rows.append(i)
#    print(mag_sheet.col_values(i)) # mag_sheet.col_values()

# %% [markdown]
# Row numbers of entries with science related topics

# %%
sci_text_rows
# Out:
# [770,
#  771,
#  772,
#  773,
#  774,
#  775,
#  776,
#  777,
#  778,
#  779,
#  780,
#  781,
#  782,
#  783,
#  784,
#  785,
#  786,
#  787,
#  788,
#  789,
#  790,
#  791,
#  792,
#  793,
#  794,
#  795,
#  796,
#  797,
#  798,
#  799,
#  800,
#  801,
#  802,
#  803,
#  804,
#  805,
#  806,
#  807,
#  808,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  815,
#  816,
#  817,
#  818,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  829,
#  830,
#  831,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  839,
#  840,
#  841,
#  842,
#  843,
#  844,
#  845,
#  846,
#  847,
#  848,
#  849,
#  850,
#  851,
#  852,
#  853,
#  854,
#  855,
#  856,
#  857,
#  858,
#  859,
#  860,
#  861,
#  862,
#  863,
#  864,
#  865,
#  866,
#  867,
#  868,
#  869,
#  870,
#  871,
#  872,
#  1663,
#  1664,
#  1665,
#  1666,
#  1667,
#  1668,
#  1669,
#  1670,
#  1671,
#  1672,
#  1673,
#  1674,
#  1675,
#  1676,
#  1677,
#  1678,
#  1679,
#  1680,
#  1681,
#  1682,
#  1683,
#  1684,
#  1685,
#  1686,
#  1687,
#  1688,
#  1689,
#  1690,
#  1691,
#  1692,
#  1693,
#  1694,
#  1695,
#  1696,
#  1697,
#  1698,
#  1699,
#  1700,
#  1701,
#  1702,
#  1703,
#  1704,
#  1705,
#  1706,
#  1707,
#  1708,
#  1709,
#  1710,
#  1711,
#  1712,
#  1713,
#  1714,
#  1715,
#  1716,
#  1717,
#  1718,
#  1719,
#  1720,
#  1721,
#  1722,
#  1723,
#  1724,
#  1725,
#  1726,
#  1727,
#  1728,
#  1729,
#  1730,
#  1731,
#  1732,
#  1733,
#  1734,
#  1735,
#  1736,
#  1737,
#  1738,
#  1739,
#  1740,
#  1741,
#  1742,
#  1743,
#  1744,
#  1745,
#  1746,
#  1747,
#  1748,
#  1749,
#  1750,
#  1751,
#  1752,
#  1753,
#  1754,
#  1755,
#  1756,
#  1757,
#  1758,
#  1759,
#  1760,
#  1761,
#  1762,
#  2507,
#  2508,
#  2509,
#  2510,
#  2511,
#  2512,
#  2513,
#  2514,
#  2515,
#  2516,
#  2517,
#  2518,
#  2519,
#  2520,
#  2521,
#  2522,
#  2523,
#  2524,
#  2525,
#  2526,
#  2527,
#  2528,
#  2529,
#  2530,
#  2531,
#  2532,
#  2533,
#  2534,
#  2535,
#  2536,
#  2537,
#  2538,
#  2539,
#  2540,
#  2541,
#  2542,
#  2543,
#  2544,
#  2545,
#  2546,
#  2547,
#  2548,
#  2549,
#  2550,
#  2551,
#  2552,
#  2553,
#  2554,
#  2555,
#  2556,
#  2557,
#  2558,
#  2559,
#  2560,
#  2561,
#  2562,
#  2563,
#  2564,
#  2565,
#  2566,
#  2567,
#  2568,
#  2569,
#  2570,
#  2571,
#  2572,
#  2573,
#  2574,
#  2575,
#  2576,
#  2577,
#  2578,
#  2579,
#  2580,
#  2581,
#  2582,
#  2583,
#  2584,
#  2585,
#  2586,
#  2587,
#  2588,
#  2589,
#  2590,
#  2591,
#  2592,
#  2593,
#  2594,
#  2595,
#  2596,
#  2597,
#  2598,
#  2599,
#  2600,
#  2601,
#  2602,
#  2603,
#  2604,
#  2605,
#  2606,
#  2607,
#  2608,
#  2609,
#  2610,
#  2611,
#  2612,
#  2613,
#  2614,
#  2615,
#  2616,
#  2617,
#  2618,
#  2619,
#  2620,
#  2621,
#  2622,
#  2623,
#  2624,
#  2625,
#  2626,
#  2627,
#  2628,
#  2629,
#  2630,
#  2631,
#  2632,
#  2633,
#  2634,
#  2635,
#  2636,
#  2637,
#  2638,
#  2639,
#  3381,
#  3382,
#  3383,
#  3384,
#  3385,
#  3386,
#  3387,
#  3388,
#  3389,
#  3390,
#  3391,
#  3392,
#  3393,
#  3394,
#  3395,
#  3396,
#  3397,
#  3398,
#  3399,
#  3400,
#  3401,
#  3402,
#  3403,
#  3404,
#  3405,
#  3406,
#  3407,
#  3408,
#  3409,
#  3410,
#  3411,
#  3412,
#  3413,
#  3414,
#  3415,
#  3416,
#  3417,
#  3418,
#  3419,
#  3420,
#  3421,
#  3422,
#  3423,
#  3424,
#  3425,
#  3426,
#  3427,
#  3428,
#  3429,
#  3430,
#  3431,
#  3432,
#  3433,
#  3434,
#  3435,
#  3436,
#  3437,
#  3438,
#  3439,
#  3440,
#  3441,
#  3442,
#  3443,
#  3444,
#  3445,
#  3446,
#  3447,
#  3448,
#  3449,
#  3450,
#  3451,
#  3452,
#  3453,
#  3454,
#  3455,
#  3456,
#  3457,
#  3458,
#  3459,
#  3460,
#  3461,
#  3462,
#  3463,
#  3464,
#  3465,
#  3466,
#  3467,
#  3468,
#  3469,
#  3470,
#  3471,
#  3472,
#  3473,
#  3474,
#  3475,
#  3476,
#  3477,
#  3478,
#  3479,
#  3480,
#  3481,
#  3482,
#  3483,
#  3484,
#  3485,
#  3486,
#  3487,
#  3488,
#  3489,
#  3490,
#  3491,
#  3492,
#  3493,
#  3494,
#  3495,
#  3496,
#  3497,
#  3498,
#  3499,
#  3500,
#  3501,
#  3502,
#  3503,
#  3504,
#  3505,
#  3506,
#  3507,
#  3508,
#  3509,
#  3510,
#  3511,
#  3512,
#  3513,
#  3514,
#  3515,
#  3516,
#  3517,
#  3518,
#  3519,
#  3520,
#  3521,
#  3522,
#  3523,
#  3524,
#  3525,
#  3526,
#  3527,
#  3528,
#  3529,
#  3530,
#  3531,
#  3532,
#  3533,
#  3534,
#  3535,
#  3536,
#  3537,
#  3538,
#  3539,
#  3540,
#  3541,
#  3542,
#  3543,
#  3544,
#  3545,
#  3546,
#  4240,
#  4241,
#  4242,
#  4243,
#  4244,
#  4245,
#  4246,
#  4247,
#  4248,
#  4249,
#  4250,
#  4251,
#  4252,
#  4253,
#  4254,
#  4255,
#  4256,
#  4257,
#  4258,
#  4259,
#  4260,
#  4261,
#  4262,
#  4263,
#  4264,
#  4265,
#  4266,
#  4267,
#  4268,
#  4269,
#  4270,
#  4271,
#  4272,
#  4273,
#  4274,
#  4275,
#  4276,
#  4277,
#  4278,
#  4279,
#  4280,
#  4281,
#  4282,
#  4283,
#  4284,
#  4285,
#  4286,
#  4287,
#  4288,
#  4289,
#  4290,
#  4291,
#  4292,
#  4293,
#  4294,
#  4295,
#  4296,
#  4297,
#  4298,
#  4299,
#  4300,
#  4301,
#  4302,
#  4303,
#  4304,
#  4305,
#  4306,
#  4307,
#  4308,
#  4309,
#  4310,
#  4311,
#  4312,
#  4313,
#  4314,
#  4315,
#  4316,
#  4317,
#  4318,
#  4319,
#  4320,
#  4321,
#  4322,
#  4323,
#  4324,
#  4325,
#  4326,
#  4327,
#  4328,
#  4329,
#  4330,
#  4331,
#  4332,
#  4333,
#  4334,
#  4335,
#  4336,
#  4337,
#  4338,
#  4339,
#  4340,
#  4341,
#  4342,
#  4343,
#  4344,
#  4345,
#  4346,
#  4347,
#  4348,
#  4349,
#  4350,
#  4351,
#  4352,
#  4353,
#  4354,
#  4355,
#  4356,
#  4357,
#  4358,
#  4359,
#  4360,
#  4361,
#  4362,
#  4363,
#  4364,
#  4365,
#  4366,
#  4367,
#  4368,
#  4369,
#  4370,
#  4371,
#  4372,
#  4373,
#  4374,
#  4375,
#  4376,
#  4377,
#  4378,
#  4379,
#  4380,
#  4381,
#  4382,
#  4383,
#  4384,
#  4385,
#  4386,
#  4387,
#  4388,
#  4389,
#  4390,
#  4391,
#  4392,
#  4393,
#  4394,
#  4395,
#  4396,
#  4397,
#  4398,
#  4399,
#  4400,
#  4401,
#  4402,
#  4403,
#  4404,
#  4405,
#  4406,
#  4407,
#  4408,
#  4409,
#  4410,
#  4411,
#  4412,
#  4413,
#  4414,
#  4415,
#  4416,
#  4417,
#  4418,
#  4419,
#  4420,
#  4421,
#  4422,
#  4423,
#  4424,
#  4425,
#  4426,
#  4427,
#  4428,
#  4429,
#  4430,
#  4431,
#  4432,
#  4433,
#  4434,
#  4435,
#  4436,
#  4437,
#  4438,
#  4439,
#  4440,
#  4441,
#  4442,
#  4443,
#  4444,
#  4445,
#  4446,
#  4447,
#  4448,
#  4449,
#  4450,
#  4451,
#  4452,
#  4453,
#  4454,
#  4455,
#  4456,
#  4457,
#  4458,
#  4459,
#  4460,
#  4461,
#  4462,
#  4463,
#  4464,
#  4465,
#  4466,
#  4467,
#  4468,
#  4469,
#  4470,
#  4471,
#  4472,
#  4473,
#  4474,
#  4475,
#  4476,
#  4477,
#  4478,
#  5167,
#  5168,
#  5169,
#  5170,
#  5171,
#  5172,
#  5173,
#  5174,
#  5175,
#  5176,
#  5177,
#  5178,
#  5179,
#  5180,
#  5181,
#  5182,
#  5183,
#  5184,
#  5185,
#  5186,
#  5187,
#  5188,
#  5189,
#  5190,
#  5191,
#  5192,
#  5193,
#  5194,
#  5195,
#  5196,
#  5197,
#  5198,
#  5199,
#  5200,
#  5201,
#  5202,
#  5203,
#  5204,
#  5205,
#  5206,
#  5207,
#  5208,
#  5209,
#  5210,
#  5211,
#  5212,
#  5213,
#  5214,
#  5215,
#  5216,
#  5217,
#  5218,
#  5219,
#  5220,
#  5221,
#  5222,
#  5223,
#  5224,
#  5225,
#  5226,
#  5227,
#  5228,
#  5229,
#  5230,
#  5231,
#  5232,
#  5233,
#  5234,
#  5235,
#  5236,
#  5237,
#  5238,
#  5239,
#  5240,
#  5241,
#  5242,
#  5243,
#  5244,
#  5245,
#  5246,
#  5247,
#  5248,
#  5249,
#  5250,
#  5251,
#  5252,
#  5253,
#  5254,
#  5255,
#  5256,
#  5257,
#  5258,
#  5259,
#  5260,
#  5261,
#  5262,
#  5263,
#  5264,
#  5265,
#  5266,
#  5267,
#  5268,
#  5269,
#  5270,
#  5271,
#  5272,
#  5273,
#  5274,
#  5275,
#  5276,
#  5277,
#  5278,
#  5279,
#  5280,
#  5281,
#  5282,
#  5283,
#  5284,
#  5285,
#  5286,
#  5287,
#  5288,
#  5289,
#  5290,
#  5291,
#  5292,
#  5293,
#  5294,
#  5295,
#  5296,
#  5297,
#  5298,
#  5299,
#  5300,
#  5301,
#  5302,
#  5303,
#  5304,
#  5305,
#  5306,
#  5307,
#  5308,
#  5309,
#  5310,
#  5311,
#  5312,
#  5313,
#  5314,
#  5315,
#  5316,
#  5317,
#  5318,
#  5319,
#  5320,
#  5321,
#  5322,
#  5323,
#  5324,
#  5325,
#  5326,
#  5327,
#  5328,
#  5329,
#  5330,
#  5331,
#  5332,
#  5333,
#  5334,
#  5335,
#  5336,
#  5337,
#  5338,
#  5339,
#  5340,
#  5341,
#  5342,
#  5343,
#  5344,
#  5345,
#  5346,
#  5347,
#  5348,
#  5349,
#  5350,
#  5351,
#  5352,
#  5353,
#  5354,
#  5355,
#  5356,
#  5357,
#  5358,
#  5359,
#  5360,
#  5361,
#  5362,
#  5363,
#  5364,
#  5365,
#  5366,
#  5367,
#  5368,
#  5369,
#  5370,
#  5371,
#  5372,
#  5373,
#  5374,
#  5375,
#  5376,
#  5377,
#  5378,
#  5379,
#  5380,
#  5381,
#  5382,
#  5383,
#  5384,
#  5385,
#  5386,
#  5387,
#  5388,
#  5389,
#  5390,
#  5391,
#  5392,
#  5393,
#  5394,
#  5395,
#  5396,
#  5397,
#  5398,
#  5399,
#  5400,
#  5401,
#  5402,
#  5403,
#  5404,
#  5405,
#  5406,
#  5407,
#  5408,
#  5409,
#  5410,
#  5411,
#  5412,
#  5413,
#  5414,
#  5415,
#  5416,
#  5417,
#  5418,
#  5419,
#  5420,
#  5421,
#  5422,
#  5423,
#  5424,
#  6111,
#  ...]

# %%
len(sci_text_rows)
# Out:
# 4356

# %% [markdown]
# Put the relevant rows in a list

# %%
scienceAcadTexts_list = [acad_sheet.row_values(i) for i in sci_text_rows]

# %%
scienceAcadTexts_list
# Out:
# [[4018430.0,
#   9566.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Congressional Oversight of the Department of Defense: Reconsidering the Conventional Wisdom.',
#   'Lindsay, James M.<SUP>1</SUP>',
#   'Fall90, Vol. 17 Issue 1, p7-33, 27p',
#   'BUREAUCRACY;LEGISLATIVE oversight;LEGISLATORS;UNITED States. Congress;UNITED States. Dept. of Defense'],
#  [4018431.0,
#   5616.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'B. H. Liddell Hart and the Creation of a Theory of War, 1919-1933.',
#   'Swain, Richard M.<SUP>1</SUP>',
#   'Fall90, Vol. 17 Issue 1, p35-51, 17p',
#   'ARMED Forces;INDUSTRIAL efficiency;TACTICS;WAR'],
#  [4018432.0,
#   9492.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'The State, Capitalism, and World War II: The U.S. Case.',
#   'Feagin, Joe R.<SUP>1</SUP><BR>Riddell, Kelly<SUP>2</SUP>',
#   'Fall90, Vol. 17 Issue 1, p53-79, 27p',
#   'ADMINISTRATIVE agencies;AUTONOMY (Political science);CAPITALISM;INDUSTRIAL mobilization'],
#  [4018433.0,
#   6719.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'The Eritrean War.',
#   'Pateman, Roy<SUP>1</SUP>',
#   'Fall90, Vol. 17 Issue 1, p81-98, 18p',
#   'CIVIL rights movements;CONFLICT management;HISTORY;GEOPOLITICS;ERITREA;1962-1993'],
#  [4018434.0,
#   5921.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'The Royalist Army of New Spain, 1810-1821: Militarism, Praetorianism, or Protection of Interests?',
#   'Archer, Christon I.<SUP>1</SUP>',
#   'Fall90, Vol. 17 Issue 1, p99-116, 18p',
#   'GUERRILLA warfare;MILITARISM;POWER (Social sciences);PRAETORIAN Guard'],
#  [4018435.0,
#   2782.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Telephone Use by Peacekeeping Troops in the Sinai.',
#   'Applewhite, Larry W.<SUP>1</SUP><BR>Segal, David R.<SUP>2</SUP>',
#   'Fall90, Vol. 17 Issue 1, p117-126, 10p, 2 charts',
#   'FAMILY;MORALE;SOLDIERS;SPECIAL operations (Military science);PEACEKEEPING forces;TELEPHONE calls'],
#  [4018436.0,
#   2261.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Militarization, Military Regimes, and the General Quality of Life in the Third World.',
#   'Looney, Robert E.<SUP>1</SUP>',
#   'Fall90, Vol. 17 Issue 1, p127-139, 13p, 7 charts',
#   'ARMED Forces -- Appropriations & expenditures;FEDERAL government;GROSS national product;MILITARISM;SOCIOECONOMIC factors'],
#  [4018437.0,
#   7754.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'The Delegitimization of Nuclear Deterrence?',
#   'Yost, David S.<SUP>1</SUP>',
#   'Summer90, Vol. 16 Issue 4, p487-508, 22p',
#   'DETERRENCE (Strategy);ELITE (Social sciences);MILITARY policy'],
#  [4018438.0,
#   6344.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'The U.S. Print Media and the Conventional Military Balance in Europe.',
#   'Roy, Denny<SUP>1</SUP>',
#   'Summer90, Vol. 16 Issue 4, p509-528, 20p, 4 charts',
#   'PRESS;SOCIAL influence;STRATEGY;NORTH Atlantic Treaty Organization'],
#  [4018439.0,
#   5303.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Democratic Currents in Authoritarian Seas: The Military in Greece and the Philippines.',
#   'Danopoulos, Constantine P. / Gerston, Larry N. ',
#   'Summer90, Vol. 16 Issue 4, p529-545, 17p',
#   'ARMED Forces;PRESIDENTS -- Election;DEMOCRATIZATION;POLITICAL campaigns'],
#  [4018440.0,
#   6846.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Military Coups, Regime Change, and Interstate Conflicts in West Africa.',
#   'Agyeman-Duah, Baffour<SUP>1</SUP>',
#   'Summer90, Vol. 16 Issue 4, p547-570, 24p, 3 charts',
#   "COUPS d'etat;MILITARY government;POLITICAL development;SOCIAL conflict;POLITICAL change"],
#  [4018441.0,
#   4854.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Effects of Service in Vietnam on Canadian Forces Military Personnel.',
#   'Stretch, Robert H.<SUP>1</SUP>',
#   'Summer90, Vol. 16 Issue 4, p571-585, 15p, 2 charts',
#   'INTERNATIONAL police;POST-traumatic stress disorder;VETERANS;VIETNAM War, 1961-1975'],
#  [4018442.0,
#   6974.0,
#   1990.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'The Education of Military Officers in the Federal Republic of Germany.',
#   'Thompson, Wayne C.<SUP>1</SUP><BR>Peltier, Marc D.<SUP>2</SUP>',
#   'Summer90, Vol. 16 Issue 4, p587-606, 20p',
#   'ARMED Forces;EDUCATION -- Curricula;MILITARY education;SEA-power;STUDENTS'],
#  [4018592.0,
#   6116.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'Debt-for-nature swaps and the need for alternatives. (cover story)',
#   'Patterson, Alan',
#   'Dec90, Vol. 32 Issue 10, p4, 12p, 7bw',
#   'DEBT;ENVIRONMENTAL policy;ENVIRONMENTAL protection;ENVIRONMENTALISM'],
#  [4018593.0,
#   4916.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'Crossing the next meridian.',
#   'Wilkinson, Charles F.',
#   'Dec90, Vol. 32 Issue 10, p14, 10p, 5bw',
#   'ENVIRONMENTAL degradation;ENVIRONMENTAL policy;ENVIRONMENTAL protection;NATURE -- Effect of human beings on;WEST (U.S.)'],
#  [4018604.0,
#   4178.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'SALT of the EARTH. Secondary Soil Salinization in the Australian Wheat Belt. (cover story)',
#   'Conacher, Arthur J.<SUP>1</SUP>',
#   'Jul/Aug90, Vol. 32 Issue 6, p4-9, 6p, 1 diagram, 1 map, 4bw',
#   'ENVIRONMENTAL degradation;RESEARCH;SOIL conservation;SOIL salinization;WATERLOGGING (Soils)'],
#  [4018605.0,
#   5474.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'DEVELOPING CLEAN COAL TECHNOLOGIES.',
#   'Torrens, Ian M.<SUP>1</SUP>',
#   'Jul/Aug90, Vol. 32 Issue 6, p10-15, 6p, 1 chart, 2 diagrams, 6 graphs, 1 map, 3bw',
#   'AIR -- Pollution;COAL;ENVIRONMENTAL protection;FLUE gases;TECHNOLOGY'],
#  [4018606.0,
#   6932.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'Curbing Auto Emissions in Europe.',
#   'Boehmer-Christiansen, Sonja A.<SUP>1</SUP>',
#   'Jul/Aug90, Vol. 32 Issue 6, p16-20, 5p, 5 charts, 4bw',
#   'AIR -- Pollution;AUTOMOBILE industry & trade;ENVIRONMENTAL protection;EMISSIONS;EMISSION control;AIR pollution monitoring'],
#  [4018595.0,
#   5400.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'HISTORICAL PERSPECTIVES on Sustainable Development. (cover story)',
#   'Ponting, Clive<SUP>1</SUP>',
#   'Nov90, Vol. 32 Issue 9, p4-9, 6p, 5bw',
#   'ECOLOGY;HISTORY;NATURAL resources'],
#  [4018596.0,
#   7496.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'Ecological Concepts of SUSTAINABILITY.',
#   'Orians, Gordon H.<SUP>1</SUP>',
#   'Nov90, Vol. 32 Issue 9, p10-15, 6p, 7bw',
#   'CONSERVATION of natural resources;DEPLETION allowances;ECONOMIC development;NATURAL resources;SUSTAINABLE development;ORGANISMS'],
#  [4018597.0,
#   3981.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'INNOVATIONS IN International Environmental Governance.',
#   'Sand, Peter H.<SUP>1</SUP>',
#   'Nov90, Vol. 32 Issue 9, p16-20, 7p, 4 illustrations, 1bw',
#   'ENVIRONMENTAL management;ENVIRONMENTAL policy;ENVIRONMENTAL sciences;INTERNATIONAL organization;INTERNATIONAL relations'],
#  [4018598.0,
#   5027.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'ANTARCTICA. Ice Under Pressure. (cover story)',
#   'Holdgate, Martin W.<SUP>1</SUP>',
#   'Oct90, Vol. 32 Issue 8, p4-9, 6p, 1 chart, 2 maps, 5bw',
#   'ANTARCTIC Treaty system;ENVIRONMENTAL protection;INTERNATIONAL obligations;ANTARCTICA -- International status'],
#  [4018599.0,
#   4879.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'WILL RHODE ISLAND BE THE FIRST GREEN STATE?',
#   'Ward, Harold R.<SUP>1</SUP><BR>Kates, Robert W.<SUP>2</SUP>',
#   'Oct90, Vol. 32 Issue 8, p10-15, 6p, 2 maps, 5bw',
#   'CONSERVATION of natural resources;ENVIRONMENTAL protection;NATURE conservation;RESTORATION ecology'],
#  [4018600.0,
#   6768.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'HONG KONG. Can the dragon clean its nest?',
#   'Hills, Peter<SUP>1</SUP><BR>Barron, William<SUP>2</SUP>',
#   'Oct90, Vol. 32 Issue 8, p16-20, 5p, 1 map, 8bw',
#   'ENVIRONMENTAL impact analysis;ENVIRONMENTAL protection;POLLUTION;SEWAGE disposal;ENVIRONMENTAL quality'],
#  [4018601.0,
#   5110.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'Global Metal Pollution. (cover story)',
#   'Nriagu, Jerome O.<SUP>1</SUP>',
#   'Sep90, Vol. 32 Issue 7, p6-11, 6p, 6 charts, 1 illustration, 1c, 1bw',
#   'BIOTIC communities;CONTAMINATION (Technology);METALS;POLLUTION;ENVIRONMENTAL quality;TRACE metal'],
#  [4018602.0,
#   3730.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   "ENERGY FOR OUR GLOBE'S PEOPLE.",
#   'Lee, William S.<SUP>1</SUP>',
#   'Sep90, Vol. 32 Issue 7, p12-15, 4p, 1bw',
#   'COST & standard of living;DEMAND (Economic theory);ECONOMIC indicators;POPULATION;POWER resources;TECHNOLOGICAL innovations'],
#  [4018603.0,
#   7063.0,
#   1990.0,
#   'Sci/Tech',
#   'Environment',
#   'DID EARTH DAY CHANGE THE WORLD?',
#   'Cahn, Robert<BR>Cahn, Patricia',
#   'Sep90, Vol. 32 Issue 7, p16-20, 5p, 9bw',
#   'EARTH Day;ENVIRONMENTALISM;GLOBAL environmental change;INTERNATIONAL cooperation;SOCIAL movements'],
#  [4013795.0,
#   5422.0,
#   1990.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Perceptual Variation and the Implementation of Accounting Information Systems: An Empirical Investigation.',
#   'Ponemon, Lawrence Andrew / Nagoda II, Robert John ',
#   'Spring90, Vol. 4 Issue 2, p1-14, 14p, 1 diagram, 1 graph',
#   'ACCOUNTING;BUSINESS enterprises;COMPUTER software;EMPLOYEES -- Attitudes;INFORMATION resources management;INFORMATION technology;MANAGEMENT;MANAGEMENT information systems;INFORMATION resources;KNOWLEDGE management;INFORMATION professionals;RESOURCE management'],
#  [4013796.0,
#   9098.0,
#   1990.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'CO-STAR: A Semantic Representational Schema for Cost Management.',
#   'Reuber, A. Rebecca<SUP>1</SUP>',
#   'Spring90, Vol. 4 Issue 2, p15-37, 23p, 4 diagrams',
#   'ACCOUNTING;CAD/CAM systems;COST control;COSTS, Industrial;INFORMATION resources management;MANAGEMENT;MANAGERIAL accounting;INFORMATION resources'],
#  [4013797.0,
#   9593.0,
#   1990.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Frameworks, Paradigms, and Scientific Research in Management Information Systems.',
#   'Cushing, Barry E.<SUP>1</SUP>',
#   'Spring90, Vol. 4 Issue 2, p38-59, 22p',
#   'INFORMATION networks;INFORMATION resources management;INFORMATION storage & retrieval systems;MANAGEMENT information systems;MANAGEMENT literature;RESEARCH;ELECTRONIC information resources;COMPUTER systems;LITERATURE reviews'],
#  [4013798.0,
#   3487.0,
#   1990.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Audit Technology and the Use of Computer Assisted Audit Techniques.',
#   'Lovata, Linda M.<SUP>1</SUP>',
#   'Spring90, Vol. 4 Issue 2, p60-68, 9p, 1 diagram',
#   'ACCOUNTS receivable;AUDITING;AUDITING -- Data processing;COMPUTER software;ELECTRONIC data processing;ELECTRONIC data processing -- Auditing;FINANCIAL statements;MANAGEMENT information systems;COMPUTER systems'],
#  [4013799.0,
#   4454.0,
#   1990.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Interception Controls of Data Communications Systems.',
#   'Chao, Joseph C.<SUP>1</SUP>',
#   'Spring90, Vol. 4 Issue 2, p69-80, 12p, 5 diagrams',
#   'COMPUTER networks -- Security measures;COMPUTER security;DATA encryption (Computer science);DATA transmission systems;DIGITAL communications;ELECTRONIC data processing;ELECTRONIC systems;FIBER optics;TELECOMMUNICATION systems;PUBLIC key cryptography;COMMUNICATION infrastructure'],
#  [4013800.0,
#   4289.0,
#   1990.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Electronic Data Interchange: Foundations and Survey Evidence on Current Use.',
#   'Ferguson, Darnel M. / Hill, Ned C. / Hansen, James V. ',
#   'Spring90, Vol. 4 Issue 2, p81-91, 11p, 2 diagrams',
#   'BUSINESS -- Data processing;BUSINESS planning;DATA transmission systems;ELECTRONIC benefits transfers;ELECTRONIC data interchange;INDUSTRIAL productivity;INFORMATION resources management;INFORMATION storage & retrieval systems;MANAGEMENT information systems'],
#  [4017232.0,
#   2200.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Competing for the recreational dollar: An analysis of the...',
#   'Dewees, Christopher M.<BR>Strange, Elizabeth M.',
#   '1990, Vol. 52 Issue 1, p1, 4p, 6 charts',
#   'FISHING'],
#  [4017224.0,
#   3370.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Application of the Leslie model to commercial catch and...',
#   'Clarke, Raymond P.<BR>Yoshimoto, Stacey S.',
#   '1990, Vol. 52 Issue 2, p1, 7p, 2 graphs',
#   'FISHING'],
#  [4017225.0,
#   1645.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Distribution and apparent abundance of the basking shark,...',
#   'Squire, James L.',
#   '1990, Vol. 52 Issue 2, p8, 4p, 3 graphs, 1bw',
#   'BASKING shark'],
#  [4017226.0,
#   1096.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Blue marlin, Makaira nigricans, movements in the western...',
#   'Witzell, W.N.<BR>Scott, E.L.',
#   '1990, Vol. 52 Issue 2, p12, 6p, 1 chart, 1bw',
#   'BLUE marlin;FISH tagging'],
#  [4017227.0,
#   3584.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   "Thailand's shrimp culture growing.",
#   '',
#   '1990, Vol. 52 Issue 2, p21, 5p, 2 charts',
#   'PENAEUS esculentus;SHRIMP culture'],
#  [4017228.0,
#   4564.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'The fisheries of Seychelles.',
#   '',
#   '1990, Vol. 52 Issue 2, p25, 6p, 5 charts, 1 diagram',
#   'FISHERIES'],
#  [4017229.0,
#   5550.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'The Canadian salmon aquaculture industry.',
#   '',
#   '1990, Vol. 52 Issue 2, p31, 7p, 3 charts, 3 graphs',
#   'FISH culture'],
#  [4017230.0,
#   3119.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'The Spanish market for squid.',
#   '',
#   '1990, Vol. 52 Issue 2, p38, 6p, 5 charts, 5 graphs',
#   'SQUID fisheries'],
#  [4017231.0,
#   1612.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'The fisheries and fish trade of India.',
#   '',
#   '1990, Vol. 52 Issue 2, p44, 3p, 5 charts',
#   'SEAFOOD industry'],
#  [4017220.0,
#   7383.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Biology and potential use of Pacific grenadier,...',
#   'Matsui, Tetsuo<BR>Kato, Susumu',
#   '1990, Vol. 52 Issue 3, p1, 17p, 9 charts, 2 diagrams, 8 graphs, 3bw',
#   'MACROURIDAE'],
#  [4017221.0,
#   3118.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'NOAA/NMFS developments.',
#   '',
#   '1990, Vol. 52 Issue 3, p20, 6p, 9 charts',
#   'FISHING;UNITED States. National Marine Fisheries Service'],
#  [4017222.0,
#   13684.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Foreign fishery developments.',
#   '',
#   '1990, Vol. 52 Issue 3, p25, 17p, 7 charts, 5 graphs',
#   'FISHERIES'],
#  [4017223.0,
#   2097.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Publications.',
#   '',
#   '1990, Vol. 52 Issue 3, p42, 3p',
#   'FISHERIES;LITERATURE'],
#  [4017219.0,
#   24150.0,
#   1990.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'History of the fisheries of Raritan Bay, New York and...',
#   'MacKenzie, Clyde L.',
#   '1990, Vol. 52 Issue 4, p1, 45p, 6 charts, 3 diagrams, 28bw',
#   'FISHERIES'],
#  [4013970.0,
#   8723.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Young Edwin Hubble. (cover story)',
#   'Osterbrock, Donald<BR>Brashear, Ronald',
#   'Jan/Feb90, Vol. 19 Issue 1, p2, 14p, 17bw',
#   ''],
#  [4013971.0,
#   3793.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Cosmic impacts, cosmic catastrophes (Part 2).',
#   'Chapman, Clark R.<BR>Morrison, David',
#   'Jan/Feb90, Vol. 19 Issue 1, p21, 6p, 4bw',
#   'BOOKS'],
#  [4013964.0,
#   8028.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Gamma-Ray Observatory: The next great observatory in space.',
#   'Neal, Valerie<BR>Fishman, Gerald',
#   'July/Aug90, Vol. 19 Issue 4, p98, 14p, 1 chart, 12 diagrams, 3 graphs, 6c',
#   'GAMMA ray astronomy'],
#  [4013968.0,
#   9778.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'The Space Telescope: Eyes Above the Atmosphere.',
#   '',
#   'Mar/Apr90, Vol. 19 Issue 2, p34, 15p, 1 chart, 3 diagrams, 2 graphs, 20bw',
#   'BOOKS'],
#  [4013969.0,
#   6304.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Neutrinos from the sun: An astronomical puzzle.',
#   'Bahcall, John N.',
#   'Mar/Apr90, Vol. 19 Issue 2, p53, 10p, 3 charts, 1 diagram, 1 graph, 8bw',
#   'NEUTRINOS;RESEARCH'],
#  [4013965.0,
#   6792.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Mapping the universe: Slices and bubbles. (cover story)',
#   'Geller, Margaret J.',
#   'May/Jun90, Vol. 19 Issue 3, p66, 11p, 1 chart, 5 diagrams, 11bw',
#   'EARTH sciences;GALAXIES;MAPS'],
#  [4013966.0,
#   3415.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'How we get pictures from space.',
#   'Haynes, Robert',
#   'May/Jun90, Vol. 19 Issue 3, p77, 7p, 1 chart, 2 diagrams, 8bw',
#   'SPACE photography;EQUIPMENT & supplies'],
#  [4013967.0,
#   3461.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Eclipsing binary stars: The story of Algol and its ...',
#   'Kopal, Zdenek',
#   'May/Jun90, Vol. 19 Issue 3, p88, 6p, 1 diagram, 1 graph, 10bw',
#   'STARS -- Observations'],
#  [4013954.0,
#   4983.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'The origin of our constellations.',
#   'Ridpath, Ian',
#   'Nov/Dec90, Vol. 19 Issue 6, p163, 9p, 4 charts, 8bw',
#   'BOOKS'],
#  [4013955.0,
#   1330.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Hermann Carl Vogel: The Sixth Bruce medallist.',
#   'Tenn, Joseph S.',
#   'Nov/Dec90, Vol. 19 Issue 6, p172, 3p, 2bw',
#   ''],
#  [4013956.0,
#   1501.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'The hubble space telescope.',
#   'Hildreth, Scott',
#   'Nov/Dec90, Vol. 19 Issue 6, p174, 4p, 6bw',
#   'IMAGES, Photographic;INFORMATION services;TELESCOPES;Maintenance & repair;UNITED States. National Aeronautics & Space Administration'],
#  [4013957.0,
#   6785.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'The 1990 A.S.P. Awards.',
#   'Morrison, Nancy',
#   'Nov/Dec90, Vol. 19 Issue 6, p179, 9p, 2 graphs, 6bw',
#   'AWARDS'],
#  [4013958.0,
#   2044.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'The society pages.',
#   '',
#   'Nov/Dec90, Vol. 19 Issue 6, p188, 4p, 2bw',
#   ''],
#  [4013959.0,
#   7516.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   "Cosmic rays: `A thin rain of charged particles'",
#   'Friedlander, Michael',
#   'Sept/Oct90, Vol. 19 Issue 5, p130, 11p, 2 charts, 3 diagrams, 2 graphs, 10bw',
#   'COSMIC rays'],
#  [4013960.0,
#   2542.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'The hubble space telescope: Problems and solutions.',
#   'Villard, Ray',
#   'Sept/Oct90, Vol. 19 Issue 5, p141, 3p, 1bw',
#   'TELESCOPES;Maintenance & repair'],
#  [4013962.0,
#   1578.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'William Huggins: The fifth Bruce medalist.',
#   'S.Tenn, Joseph',
#   'Sept/Oct90, Vol. 19 Issue 5, p148, 3p, 1bw',
#   'ASTRONOMERS;ASTROPHYSICS'],
#  [4013963.0,
#   505.0,
#   1990.0,
#   'Sci/Tech',
#   'Mercury',
#   'Thank you!',
#   '',
#   'Sept/Oct90, Vol. 19 Issue 5, p154, 6p, 1 chart',
#   'CHARITABLE uses, trusts, & foundations'],
#  [4013074.0,
#   2528.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Chasing ghosts.',
#   'Nicholson, Rob',
#   'Dec90, Vol. 99 Issue 12, p8, 5p, 1 illustration, 2bw',
#   'CEDAR;TREE declines'],
#  [4013075.0,
#   2904.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Shoemaker and morning star.',
#   'Gould, Stephen Jay',
#   'Dec90, Vol. 99 Issue 12, p14, 4p, 4c',
#   'SOCIAL change;UTOPIAN socialism;MIDDLE Amana (Iowa);DARWIN, Charles, 1809-1882'],
#  [4013076.0,
#   3628.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Bach, God, and the jungle.',
#   'Diamond, Jared',
#   'Dec90, Vol. 99 Issue 12, p22, 5p, 2 illustrations, 1 graph',
#   'BIOLOGY;LIFE sciences;RAIN forest ecology;BACH, Johann Sebastian, 1685-1750'],
#  [4013077.0,
#   2374.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Alive and well in Tsimanampetsotsa.',
#   'Wozencraft, W. Chris',
#   'Dec90, Vol. 99 Issue 12, p28, 3p, 1c',
#   'BIOLOGY;ENDANGERED species;MONGOOSES;RARE animals'],
#  [4013078.0,
#   2884.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'A seahorse father makes a good mother. (cover story)',
#   'Vincent, Amanda',
#   'Dec90, Vol. 99 Issue 12, p34, 10p, 7c',
#   'CAMOUFLAGE (Biology);CHILDBIRTH;COURTSHIP in animals;SEA horses;SEX (Biology)'],
#  [4013079.0,
#   2510.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Columbus, my enemy.',
#   'Wilson, Samuel M.',
#   'Dec90, Vol. 99 Issue 12, p44, 6p, 3 illustrations, 2 maps, 3bw',
#   'COMMUNICABLE diseases;EPIDEMICS;INDIANS of the West Indies -- Hispaniola;TAINO Indians -- First contact with Europeans'],
#  [4013080.0,
#   3518.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Bee cool.',
#   'Underwood, Benjamin A.',
#   'Dec90, Vol. 99 Issue 12, p50, 8p, 4c',
#   'APIS (Insects);BEES;DEFORESTATION'],
#  [4013081.0,
#   2663.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Queuing to carol.',
#   'Russel, Ian',
#   'Dec90, Vol. 99 Issue 12, p58, 8p, 5c, 1bw',
#   'CAROLING;CHRISTMAS;FOLK songs'],
#  [4013082.0,
#   2976.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'The universal mushroom.',
#   'Sokolov, Raymond',
#   'Dec90, Vol. 99 Issue 12, p78, 5p, 1c',
#   'COOKERY (Morels);MUSHROOMS;MUSHROOMS, Edible'],
#  [4013083.0,
#   5055.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Darwin and Paley Meet the Invisible Hand.',
#   'Gould, Stephen Jay',
#   'Nov90, Vol. 99 Issue 11, p8, 5p',
#   'GOD;NATURAL selection;RELIGION;THEOLOGY'],
#  [4013084.0,
#   5026.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Pictures from an Expedition.',
#   'Chapin, James<BR>Gilliard, Thomas',
#   'Nov90, Vol. 99 Issue 11, p18, 11p, 7c',
#   'NATURAL history;VOYAGES & travels'],
#  [4013085.0,
#   1318.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Battlefields of Ashes and Mud.',
#   'Nietschmann, Bernard',
#   'Nov90, Vol. 99 Issue 11, p34, 4p, 2c, 1bw',
#   'BOMBINGS;CHEMICAL weapons;CHEMICALS'],
#  [4013086.0,
#   2347.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Degreening Vietnam.',
#   'Pfeiffer, E.W.',
#   'Nov90, Vol. 99 Issue 11, p37, 4p, 1 map, 1c',
#   'CLEARING of land;DEFORESTATION;FOREST fires;MANGROVE plants'],
#  [4013087.0,
#   2730.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Conservation by Conflict in Nicaragua.',
#   'Nietschmann, Bernard',
#   'Nov90, Vol. 99 Issue 11, p42, 7p, 1 map, 3c',
#   'CONSERVATION of natural resources;ENVIRONMENTAL management;WAR & society;NATURAL resources;MANAGEMENT'],
#  [4013088.0,
#   3314.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Courting Disaster in Cannibal Territory. (cover story)',
#   'Foster, Susan A.',
#   'Nov90, Vol. 99 Issue 11, p52, 10p, 9c',
#   'COURTSHIP in animals;FISHES;SEXUAL behavior in animals;STICKLEBACKS'],
#  [4013089.0,
#   3969.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   "The Bonobos' Peaceable Kingdom.",
#   'Kano, Takayoshi',
#   'Nov90, Vol. 99 Issue 11, p62, 10p, 9c',
#   'ANIMAL behavior;BONOBO;CHIMPANZEES;PAN (Mammals);PRIMATES -- Breeding'],
#  [4013090.0,
#   2035.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'The Target of a Victimless Hunt.',
#   'Sokolov, Raymond',
#   'Nov90, Vol. 99 Issue 11, p92, 3p',
#   'COOKERY (Mushrooms);FUNGI;FUNGI, Edible;MUSHROOMS;MUSHROOMS, Edible'],
#  [4013091.0,
#   5003.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Enigmas of the small shellies.',
#   'Gould, Stephen Jay',
#   'Oct90, Vol. 99 Issue 10, p6, 9p, 4 diagrams',
#   'EVOLUTION (Biology);FOSSILS;LIFE -- Origin;MICRODICTYON;PALEONTOLOGISTS'],
#  [4013092.0,
#   1057.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Gaudineer Knob, West Virginia.',
#   'Mohlenbrock, Robert H.',
#   'Oct90, Vol. 99 Issue 10, p20, 4p, 2 maps, 3c',
#   'FORESTS & forestry;LOGGING;MOUNTAINS -- West Virginia;SPRUCE'],
#  [4013093.0,
#   3353.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   "Bob Dylan and moas' ghosts.",
#   'Diamond, Jared',
#   'Oct90, Vol. 99 Issue 10, p26, 5p',
#   'ANIMAL behavior;DEVELOPMENTAL biology;MOA'],
#  [4013094.0,
#   2307.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Columbus the unwitting.',
#   'Sokolov, Raymond',
#   'Oct90, Vol. 99 Issue 10, p34, 4p, 1c',
#   'BREAD;CARIB Indians;CASSAVA;COOKERY (Bread)'],
#  [4013095.0,
#   1960.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Starter homes for young lizards.',
#   'Stamps, Judy',
#   'Oct90, Vol. 99 Issue 10, p40, 4p, 2c',
#   'ANIMAL feeding;ANOLES;GRACKLES;LIZARDS;REPRODUCTION'],
#  [4013096.0,
#   3306.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Wet behind the gills.',
#   'Wolcott, Thomas G.<BR>Wolcott, Donna L.',
#   'Oct90, Vol. 99 Issue 10, p46, 10p, 7c',
#   'CRABS;BEHAVIOR;CRUSTACEA;CRUSTACEA -- Anatomy;GECARCINIDAE;OCYPODIDAE'],
#  [4013097.0,
#   3320.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'The hunters of Los Medaños.',
#   'Bednarz, James C.',
#   'Oct90, Vol. 99 Issue 10, p56, 8p, 7c',
#   "BIRDS;HARRIS'S hawk;HAWKS;SOCIAL behavior in animals"],
#  [4013098.0,
#   2081.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'A day with the dead. (cover story)',
#   'Day, Douglas',
#   'Oct90, Vol. 99 Issue 10, p66, 8p, 7c',
#   "ALL Souls' Day;AZTECS;FESTIVALS -- Mexico;RITES & ceremonies"],
#  [4013099.0,
#   3843.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'The real vampire.',
#   'Barber, Paul',
#   'Oct90, Vol. 99 Issue 10, p74, 8p, 1c, 5bw',
#   'FOLKLORE;MYTHOLOGY, Slavic;PATHOLOGISTS;VAMPIRES'],
#  [4013100.0,
#   3241.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   "Taraka's ghost.",
#   'Freed, Stanley A.<BR>Freed, Ruth S.',
#   'Oct90, Vol. 99 Issue 10, p84, 5p',
#   'GODDESSES, Hindu;HINDUISM;SITA (Hindu deity);INDIA -- Social life & customs'],
#  [4013101.0,
#   995.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'A meeting with Mars.',
#   'Nicholson, Thomas D.',
#   'Oct90, Vol. 99 Issue 10, p100, 3p, 2 diagrams',
#   'ASTRONOMY;PLANETS;SATELLITES;STARS;MARS (Planet)'],
#  [4013102.0,
#   5734.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Indecent exposure.',
#   'Stenehjem, Michele',
#   'Sep90, Vol. 99 Issue 9, p6, 10p, 1 diagram, 2 maps, 2c, 3bw',
#   'ENVIRONMENTAL impact analysis;NUCLEAR facilities;PLUTONIUM;HANFORD Nuclear Reservation (Richland, Wash.)'],
#  [4013103.0,
#   3943.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'The Golden Rule--a proper scale for our environmental crisis.',
#   'Gould, Stephen Jay',
#   'Sep90, Vol. 99 Issue 9, p24, 5p',
#   'ENVIRONMENTALISTS;OBSERVATORIES;TAMIASCIURUS;TELESCOPES;Design & construction;UNIVERSITY of Arizona (Tucson, Ariz.)'],
#  [4013104.0,
#   3163.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'Caught in the middle.',
#   'Gmelch, George',
#   'Sep90, Vol. 99 Issue 9, p32, 4p, 1c',
#   'ANTHROPOLOGY;CULTURE;SALMON fishing;TLINGIT Indians'],
#  [4013105.0,
#   3519.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'In the minds of monkeys.',
#   'Cheney, Dorothy<BR>Seyfarth, Robert',
#   'Sep90, Vol. 99 Issue 9, p38, 10p, 8c',
#   'CERCOPITHECUS aethiops;MONKEYS;BEHAVIOR;SAVANNA animals;SAVANNA ecology -- Africa'],
#  [4013106.0,
#   3736.0,
#   1990.0,
#   'Sci/Tech',
#   'Natural History',
#   'The Ordeal of Moharram.',
#   'Cardoza, Rod',
#   'Sep90, Vol. 99 Issue 9, p50, 8p, 7c',
#   'FLAGELLATION;ISLAM;MUSLIMS;RITES & ceremonies;SHIITES'],
#  [4013668.0,
#   3329.0,
#   1990.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Fall90, Vol. 27 Issue 3, p4, 4p, 3bw',
#   'SCIENCE -- Study & teaching;United States'],
#  [4013669.0,
#   2356.0,
#   1990.0,
#   'Sci/Tech',
#   'Science Activities',
#   'Bring on the computers!',
#   'Atwater, Mary M.',
#   'Fall90, Vol. 27 Issue 3, p19, 5p, 1 chart, 1bw',
#   'ELECTRONIC data processing;SCIENCE -- Study & teaching (Secondary)'],
#  [4013671.0,
#   3255.0,
#   1990.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Spring90, Vol. 27 Issue 1, p4, 4p, 3bw',
#   'SCIENCE'],
#  [4013670.0,
#   3630.0,
#   1990.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Summer90, Vol. 27 Issue 2, p4, 4p, 2bw',
#   'EARTH Day;SCIENCE -- United States'],
#  [4013666.0,
#   3089.0,
#   1990.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Winter90, Vol. 27 Issue 4, p4, 4p, 3bw',
#   'SCIENCE -- Study & teaching;United States'],
#  [4013667.0,
#   3612.0,
#   1990.0,
#   'Sci/Tech',
#   'Science Activities',
#   "The `Winning Words' science competition: Students write about science.",
#   'Carr, Kate',
#   'Winter90, Vol. 27 Issue 4, p24, 6p, 2 charts, 4 diagrams',
#   'AUTHORSHIP;Competitions'],
#  [4018443.0,
#   7465.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   "The People's Liberation Army and China's Crisis.",
#   'Gregor, A. James<SUP>1</SUP>',
#   'Fall91, Vol. 18 Issue 1, p7-28, 22p',
#   'LEADERSHIP;SINOLOGISTS'],
#  [4018444.0,
#   7855.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   "Israel's Small War: The Military Response to the Intifada.",
#   'Inbar, Efraim<SUP>1,2</SUP>',
#   'Fall91, Vol. 18 Issue 1, p29-50, 22p',
#   'INTIFADA, 1987-;MANPOWER policy;MILITARY readiness;ARAB-Israeli conflict -- 1993-'],
#  [4018445.0,
#   10102.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'CFE II: A Quest for Stability.',
#   'Garrett, James M.',
#   'Fall91, Vol. 18 Issue 1, p51-79, 29p',
#   'ARMS control;NEGOTIATION;WEAPONS;NORTH Atlantic Treaty Organization'],
#  [4018446.0,
#   4513.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Military Professionalism, Education, and Political Behavior in Mexico.',
#   'Ackroyd, William S.<SUP>1</SUP>',
#   'Fall91, Vol. 18 Issue 1, p81-96, 16p',
#   'ARMED Forces;MILITARY education;MILITARY readiness;POLITICAL participation'],
#  [4018447.0,
#   3930.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   "Profile of a Citizen Army: Shiloh's Soldiers.",
#   'Frank, Joseph Allan<SUP>1</SUP>',
#   'Fall91, Vol. 18 Issue 1, p97-110, 14p',
#   'ARMIES;CIVIL war;NATIONALISM;WAR'],
#  [4018448.0,
#   5874.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Retention of Junior Enlisted Soldiers in the All-Volunteer Army Reserve.',
#   'Perry, Shelley / Griffith, James / White, Terry ',
#   'Fall91, Vol. 18 Issue 1, p111-133, 23p, 4 charts',
#   'ARMIES;LEADERSHIP;SELF-culture;UNITED States. Army;EMPLOYMENT'],
#  [4018449.0,
#   8687.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Congress and the Politics of Military Reform.',
#   'Wirls, Daniel<SUP>1</SUP>',
#   'Summer91, Vol. 17 Issue 4, p487-512, 26p, 1 chart',
#   'MILITARY policy;NUCLEAR arms control;DEMOCRATIZATION;MILITARY reform'],
#  [4018450.0,
#   10281.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'Revising the War Powers Act.',
#   'Nathan, James A.<SUP>1</SUP>',
#   'Summer91, Vol. 17 Issue 4, p513-543, 31p',
#   'EXECUTIVE power;MILITARY readiness;WAR;WAR & emergency powers'],
#  [4018451.0,
#   8300.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'From Professional to Political: The Redecline of the Lebanese Army.',
#   'McLaurin, Ronald D.<SUP>1</SUP>',
#   'Summer91, Vol. 17 Issue 4, p545-568, 24p',
#   'ARMED Forces;ARMIES;COMBAT;LEBANESE'],
#  [4018452.0,
#   7387.0,
#   1991.0,
#   'Sci/Tech',
#   'Armed Forces & Society (Transaction Publishers)',
#   'El Salvador: The Military and Politics.',
#   'Needler, Martin C.<SUP>1</SUP>',
#   'Summer91, Vol. 17 Issue 4, p569-588, 20p',
#   'COLD War;GUERRILLAS;PEASANTRY'],
#  [4018607.0,
#   2800.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Environmental Implications of the Single European Market.',
#   'Howe, Charles W.<SUP>1,2</SUP>',
#   'Dec91, Vol. 33 Issue 10, p2-5, 5p, 1 chart, 1 cartoon',
#   'ENVIRONMENTAL sciences;MARKETS;SOCIAL sciences;TREATIES'],
#  [4018608.0,
#   4810.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Clearing the Air Environmental Reform in MEXICO.',
#   'Mumme, Stephen P.<SUP>1</SUP>',
#   'Dec91, Vol. 33 Issue 10, p6-11, 11p, 1c, 5bw',
#   'ENVIRONMENTAL sciences;FORESTS & forestry;POPULATION;Law & legislation'],
#  [4018609.0,
#   3988.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   "Chemical Hazards and the Public's RIGHT TO KNOW.",
#   'Pease, William S.<SUP>1</SUP>',
#   'Dec91, Vol. 33 Issue 10, p12-20, 9p, 2 charts',
#   'DRINKING water;ENVIRONMENTAL law;ENVIRONMENTAL protection;POISONS'],
#  [4018610.0,
#   2322.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Integrated Catchment Management: The Western Australian Experience.',
#   'Wallis, R.L.<SUP>1</SUP><BR>Robinson, S.J.<SUP>2</SUP>',
#   'Dec91, Vol. 33 Issue 10, p31-33, 3p',
#   'ADMINISTRATIVE agencies;ENVIRONMENTAL management;ENVIRONMENTAL sciences;LAND use'],
#  [4018616.0,
#   4345.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Debating Gaia. (cover story)',
#   'Schneider, Stephen H.',
#   'May90, Vol. 32 Issue 4, p4, 9p, 7bw',
#   'ATMOSPHERE;GAIA hypothesis;GLOBAL warming;SCIENTISTS'],
#  [4018617.0,
#   4508.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'A framework for reshaping water management.',
#   'Viessman Jr, Warren',
#   'May90, Vol. 32 Issue 4, p10, 9p, 1bw',
#   'WATER quality;WATER-supply;WATER-supply engineering'],
#  [4018618.0,
#   6110.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Fueling our global future.',
#   'Dreyfus, Daniel A.<BR>Ashby, Anne B.',
#   'May90, Vol. 32 Issue 4, p16, 11p, 4 charts, 1 illustration, 3 graphs, 6bw',
#   'CONSUMPTION (Economics);ENERGY consumption;ENERGY policy;POWER resources'],
#  [4018619.0,
#   2699.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Our Changing Planet: The FY 1990 Research Plan The U.S. Global Change Research Program/Our Changing Planet: The FY 1991 U.S. Global Change Research Program.',
#   'Pittock, A. Barrie',
#   'May90, Vol. 32 Issue 4, p25, 4p, 1 chart',
#   'EARTH sciences;ECOLOGY;ENVIRONMENTAL policy;ENVIRONMENTAL sciences'],
#  [4018611.0,
#   1948.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Air-Traffic Emissions.',
#   'Egli, Robert A.<SUP>1</SUP>',
#   'Nov91, Vol. 33 Issue 9, p2-5, 4p, 2bw',
#   'AIR -- Pollution;CARBON dioxide;CARBON monoxide;EMISSIONS trading;OZONE layer depletion;AIR pollution monitoring'],
#  [4018612.0,
#   2542.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'Biological Treatment of Hazardous Wastes.',
#   'Glass, David J.<SUP>1</SUP>',
#   'Nov91, Vol. 33 Issue 9, p5-45, 4p, 1bw',
#   'BIOREMEDIATION;ENVIRONMENTAL policy;HAZARDOUS waste sites;HAZARDOUS wastes;REFUSE & refuse disposal'],
#  [4018613.0,
#   5785.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'THE FOLLY AT FOLLY BEACH and Other Failings of U.S. Coastal Erosion Policy.',
#   'Platt, Rutherford H.<BR>Beatley, Timothy<BR>Miller, H. Crane',
#   'Nov91, Vol. 33 Issue 9, p6-32, 12p',
#   'BEACH erosion;COASTAL zone management;COASTS;SHORE protection;SHORELINES;Law & legislation'],
#  [4018614.0,
#   6424.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'OBSTACLES and OPPORTUNITIES for a CONSUMER ECOLABEL.',
#   'Salzhauer, Amy Lynn',
#   'Nov91, Vol. 33 Issue 9, p10-37, 11p',
#   'CHLOROFLUOROCARBONS;COMMERCIAL products;GREEN marketing;LABELS -- Law & legislation;ECO-labeling'],
#  [4018615.0,
#   4932.0,
#   1991.0,
#   'Sci/Tech',
#   'Environment',
#   'The Federal Research Puzzle.',
#   'Schaeffer, Mark',
#   'Nov91, Vol. 33 Issue 9, p16-42, 9p',
#   'ENVIRONMENTAL engineering;ENVIRONMENTAL protection;RESEARCH;RESEARCH institutes;ENVIRONMENTAL agencies'],
#  [4013801.0,
#   6905.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'The impact of expert system usage on experiential learning in an auditing setting.',
#   'Eining, Martha M.<SUP>1</SUP><BR>Dorr, Patrick B.<SUP>2</SUP>',
#   'Spring91, Vol. 5 Issue 1, p1-16, 16p, 9 charts',
#   'ACTIVE learning;ARTIFICIAL intelligence;AUDITING;AUDITORS;DECISION support systems;EXPERIENTIAL learning;EXPERT systems (Computer science)'],
#  [4013802.0,
#   6098.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Accounting Information System Selection in Small Organizations: Incongruences Between Accounting Professionals.',
#   'Gray, Glen L.<SUP>1</SUP>',
#   'Spring91, Vol. 5 Issue 1, p17-35, 19p, 6 charts, 1 diagram, 2 graphs',
#   'ACCOUNTANTS;ACCOUNTING;INFORMATION resources management;INFORMATION storage & retrieval systems;SMALL business;INFORMATION resources'],
#  [4013803.0,
#   6344.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Assessing Intangible Costs and Benefits in the Systems Decision Via Option Pricing Theory.',
#   'Cheung, Joseph K.<SUP>1</SUP><BR>Bagranoff, Nancy A.<SUP>2</SUP>',
#   'Spring91, Vol. 5 Issue 1, p36-47, 12p',
#   'COSTS, Industrial;DECISION making;INFORMATION resources management;INTANGIBLE property;INVESTMENTS;OPTIONS (Finance)'],
#  [4013804.0,
#   7725.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'An MIS Data Quality Methodology Based on Optimal Error Detection.',
#   'Paradice, David B.<SUP>1</SUP><BR>Fuerst, William L.<SUP>1</SUP>',
#   'Spring91, Vol. 5 Issue 1, p48-66, 19p, 4 charts, 2 diagrams, 7 graphs',
#   'DATABASE management;INFORMATION storage & retrieval systems;MANAGEMENT information systems;QUALITY assurance;QUALITY control;DATA warehousing'],
#  [4013805.0,
#   5487.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Factors Influencing Software Piracy: Implications for Accountants.',
#   'Christensen, Anne L.<SUP>1</SUP><BR>Eining, Martha M.<SUP>2</SUP>',
#   'Spring91, Vol. 5 Issue 1, p67-80, 14p, 5 charts, 1 diagram',
#   'ACCOUNTANTS;ACCOUNTING;COMPUTER programs -- Pirated editions;COMPUTER software;COPYRIGHT -- Computer programs;COPYRIGHT infringement;PIRACY (Copyright)'],
#  [4013806.0,
#   1320.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Accounting and Business Data Communications.',
#   'Grabski, Severin V.<SUP>1</SUP>',
#   'Spring91, Vol. 5 Issue 1, p81-83, 3p',
#   'ACCOUNTING -- Study & teaching;BUSINESS communication;COMPUTER networks;DATA transmission systems;LOCAL area networks (Computer networks);MICROCOMPUTERS;OPERATING systems (Computers);Study & teaching'],
#  [4013807.0,
#   7546.0,
#   1991.0,
#   'Sci/Tech',
#   'Journal of Information Systems',
#   'Information System Development: Four Process Scenarios With Case Studies.',
#   'Newman, Michael<SUP>1</SUP><BR>Sabherwal, Rajiv<SUP>2</SUP>',
#   'Spring91, Vol. 5 Issue 1, p84-101, 18p, 3 charts, 2 diagrams',
#   'ACCOUNTANTS;ACCOUNTING -- Data processing;INFORMATION resources management;INFORMATION resources;COMPUTER systems;CASE studies'],
#  [4017245.0,
#   6332.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'A demographic profile of participants in two Gulf of Mexico...',
#   'Nance, James M.<BR>Garfield, Nina',
#   '1991, Vol. 53 Issue 1, p10, 9p, 2 charts, 13 graphs',
#   'SHRIMP fisheries'],
#  [4017241.0,
#   5594.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Simulated economic impact of TED regulations on selected...',
#   'Clark, Joy<BR>Griffin, Wade',
#   '1991, Vol. 53 Issue 2, p1, 8p, 4 charts, 5 diagrams',
#   'SHRIMP fisheries -- Law & legislation'],
#  [4017242.0,
#   3172.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'The by-catch from the artisanal shrimp trawl fishery, Gulf...',
#   'Maharaj, Vishwanie<BR>Recksiek, Conrad',
#   '1991, Vol. 53 Issue 2, p9, 8p, 1 chart, 12 graphs',
#   'SHRIMP fisheries'],
#  [4017243.0,
#   2596.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   "Construction and operation of a two-place diver's sled.",
#   'Workman, Ian K.<BR>Watson, John W.',
#   '1991, Vol. 53 Issue 2, p16, 9p, 8 diagrams',
#   'FISHERIES -- Equipment & supplies'],
#  [4017244.0,
#   2820.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Maturity and fecundity in the rockfishes, Sebastes spp...',
#   'Haldorson, Lewis<BR>Love, Milton',
#   '1991, Vol. 53 Issue 2, p25, 7p, 2 charts, 3 graphs',
#   'SEBASTES viviparus'],
#  [4017238.0,
#   9377.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Restricted access vs. open access methods of management:...',
#   'Waters, James R.',
#   '1991, Vol. 53 Issue 3, p1, 10p',
#   'FISHERY management;FISHERIES -- Limited entry licenses'],
#  [4017239.0,
#   10487.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Pacific salmon, oncorhynchus spp., and the definition of...',
#   'Waples, Robin S.',
#   '1991, Vol. 53 Issue 3, p11, 12p',
#   'ENDANGERED species -- Law & legislation;PACIFIC salmon'],
#  [4017240.0,
#   3943.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Biographic memoir of Ernest Ingersoll: Naturalist,...',
#   'MacKenzie, Clyde L.',
#   '1991, Vol. 53 Issue 3, p23, 7p, 5bw',
#   'BIOLOGISTS'],
#  [4017233.0,
#   9026.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Population biology and life history of the North American...',
#   'Ahrenholz, Dean W.',
#   '1991, Vol. 53 Issue 4, p3, 17p, 4 charts, 3 diagrams, 1 graph, 12bw',
#   'MENHADEN fisheries'],
#  [4017234.0,
#   2977.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Overview of Mark-recovery studies on Adult and Juvenile...',
#   'Ahrenholz, Dean W.<BR>Dudley, Donnie L.',
#   '1991, Vol. 53 Issue 4, p20, 8p, 4 charts, 2 diagrams, 8bw',
#   'MENHADEN fisheries'],
#  [4017235.0,
#   6829.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'The Atlantic and Gulf menhaden purse seine fisheries:...',
#   'Smith, Joseph W.',
#   '1991, Vol. 53 Issue 4, p28, 14p, 4 charts, 1 diagram, 1 graph, 10bw',
#   'MENHADEN;PURSE seining'],
#  [4017236.0,
#   4340.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'New products and markets for Menhaden, Brevoortia spp.',
#   'Hale, Malcolm B.<BR>Bauersfeld, Paul E.',
#   '1991, Vol. 53 Issue 4, p42, 7p, 1 diagram, 3bw',
#   'MENHADEN fisheries'],
#  [4017237.0,
#   5588.0,
#   1991.0,
#   'Sci/Tech',
#   'Marine Fisheries Review',
#   'Assessment and management of Atlantic and Gulf Menhaden...',
#   'Vaughan, D.S.<BR>Merriner, J.V.',
#   '1991, Vol. 53 Issue 4, p49, 9p',
#   'MENHADEN'],
#  [4013988.0,
#   9307.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Discovering the invisible universe. (cover story)',
#   'Friedman, Herbert',
#   'Jan/Feb91, Vol. 20 Issue 1, p2, 15p, 4 diagrams, 25bw',
#   'BOOKS'],
#  [4013989.0,
#   1871.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'A funny thing happened on the way to the Stanford Press...',
#   'Bidelman, William P.',
#   'Jan/Feb91, Vol. 20 Issue 1, p23, 3p, 6bw',
#   ''],
#  [4013990.0,
#   1861.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Edward C. Pickering: The seventh Bruce medalist.',
#   'Tenn, Joseph S.',
#   'Jan/Feb91, Vol. 20 Issue 1, p26, 3p, 1bw',
#   'AWARDS'],
#  [4013979.0,
#   9523.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   "God's turnstile: The work of John Wheeler and Stephen Hawking.",
#   'Overbye, Dennis',
#   'Jul/Aug91, Vol. 20 Issue 4, p98, 11p, 1 diagram, 1 graph, 15bw',
#   'BOOKS'],
#  [4013980.0,
#   3985.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Starry, starry night: Observing on Kitt Peak.',
#   'Teske, Richard G.',
#   'Jul/Aug91, Vol. 20 Issue 4, p115, 5p, 3bw',
#   'STARS -- Observations;MICHIGAN Alumnus (Periodical)'],
#  [4013981.0,
#   2445.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   '103rd annual meeting in Laramie.',
#   '',
#   'Jul/Aug91, Vol. 20 Issue 4, p124, 4p, 4bw',
#   'CONGRESSES & conventions'],
#  [4013985.0,
#   4107.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Two years in Hollywood: An astronomer in television land. (cover story)',
#   'Goldsmith, Donald',
#   'Mar/Apr91, Vol. 20 Issue 2, p34, 6p, 7bw',
#   'TELEVISION in science education'],
#  [4013986.0,
#   8442.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'The wave of the future: Searching for gravity waves. (cover story)',
#   'Goldsmith, Donald',
#   'Mar/Apr91, Vol. 20 Issue 2, p40, 12p, 3 diagrams, 12bw',
#   'GRAVITY waves'],
#  [4013987.0,
#   3716.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Problems with pulsars.',
#   'Bailyn, Charles',
#   'Mar/Apr91, Vol. 20 Issue 2, p55, 6p, 1 diagram, 2 graphs, 3bw',
#   'NEUTRON stars;PULSARS'],
#  [4013982.0,
#   7291.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'The sun: A star close up. (cover story)',
#   'Pasachoff, Jay M.',
#   'May/Jun91, Vol. 20 Issue 3, p67, 11p, 2 diagrams, 2 graphs, 12bw',
#   'SOLAR photosphere;Spectra'],
#  [4013983.0,
#   5333.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'The solar chimes: Searching for oscillations inside the sun.',
#   'Wentzel, Donat G.',
#   'May/Jun91, Vol. 20 Issue 3, p77, 8p, 1 chart, 2 graphs, 7bw',
#   'SOLAR oscillations'],
#  [4013984.0,
#   4715.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Computer software in astronomy.',
#   'Mosley, John<BR>Fraknoi, Andrew',
#   'May/Jun91, Vol. 20 Issue 3, p87, 8p',
#   'ASTRONOMY;Software'],
#  [4013973.0,
#   11240.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Along the milky way.',
#   'Krupp, E.C.',
#   'Nov/Dec91, Vol. 20 Issue 6, p162, 14p, 2 diagrams, 16bw',
#   'BOOKS'],
#  [4013974.0,
#   1288.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Bruce medalist profiles: Oskar Backlund.',
#   'Tenn, Joseph S.',
#   'Nov/Dec91, Vol. 20 Issue 6, p175, 3p, 2bw',
#   'AWARDS'],
#  [4013975.0,
#   7156.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'The 1991 A.S.P. award winners.',
#   'Morrison, Nancy',
#   'Nov/Dec91, Vol. 20 Issue 6, p182, 9p, 10bw',
#   'AWARDS'],
#  [4013976.0,
#   6472.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'The exploration of Venus: A Magellan progress report. (cover story)',
#   'Saunders, Steve',
#   'Sept/Oct91, Vol. 20 Issue 5, p130, 14p, 2 diagrams, 27bw',
#   'REPRINTS (Publications);VENUS (Planet) -- Exploration'],
#  [4013977.0,
#   2302.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'Jacobus Cornelius Kapteyn: The tenth Bruce medalist.',
#   'Tenn, Joseph S.',
#   'Sept/Oct91, Vol. 20 Issue 5, p145, 4p, 2bw',
#   'AWARDS'],
#  [4013978.0,
#   4270.0,
#   1991.0,
#   'Sci/Tech',
#   'Mercury',
#   'The great molecule factory in Orion.',
#   'Goldsmith, Donald<BR>Cohen, Nathan',
#   'Sept/Oct91, Vol. 20 Issue 5, p148, 5p, 4bw',
#   'BOOKS'],
#  [4013107.0,
#   3046.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   "Pearl Harbor & the emperor's physiologists.",
#   'Diamond, Jared',
#   'Dec91, Vol. 100 Issue 12, p2, 4p',
#   'BIOLOGISTS;BIOLOGY;GENETICS;PEARL Harbor (Hawaii), Attack on, 1941;PHYSIOLOGY -- Research;SWEAT glands;TEMPERATE climate'],
#  [4013108.0,
#   4890.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'The smoking gun of eugenics.',
#   'Gould, Stephen J.',
#   'Dec91, Vol. 100 Issue 12, p8, 7p, 3 cartoons',
#   'BIOLOGY;EVOLUTION (Biology);FAMILY size;FERTILITY;GENETICS;LUNGS -- Cancer;NATURAL selection;REPRODUCTION;SMOKING;SOCIAL groups;SOCIAL status;UPPER class;TOBACCO use;NICOTINE addiction'],
#  [4013109.0,
#   1187.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'Buffalo Beats, Ohio.',
#   'Mohlenbrock, Robert H.',
#   'Dec91, Vol. 100 Issue 12, p18, 3p, 2 maps, 3c',
#   'FOREST reserves -- Ohio;NATIONAL parks & reserves -- Ohio;OAK;SILICA;SILICON'],
#  [4013110.0,
#   1749.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'Saint George and John Canoe.',
#   'Wilson, Samuel M.',
#   'Dec91, Vol. 100 Issue 12, p22, 5p, 1 illustration, 3c',
#   'AMUSEMENTS;CHRISTMAS;CLOTHING & dress;COSTUME;DECORATIVE arts;HOLIDAYS;MANNERS & customs;MASQUERADES'],
#  [4013111.0,
#   2388.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'Life styles of the huge and famous. (cover story)',
#   'Dodson, Peter',
#   'Dec91, Vol. 100 Issue 12, p30, 4p, 1 diagram, 2 illustrations, 2c, 1bw',
#   'DINOSAURS;PALEONTOLOGISTS;PALEONTOLOGY;SAURISCHIA;TITANOSAURIDAE;VULCANODON'],
#  [4013112.0,
#   2512.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'Barosaurus on Central Park West. (cover story)',
#   'Norell, Mark<BR>Dingus, Lowell W.<BR>Gaffney, Eugene S.',
#   'Dec91, Vol. 100 Issue 12, p36, 6p, 5c, 1bw',
#   'ARCHAEOLOGICAL expeditions;ARCHAEOLOGY;BAROSAURUS;EXCAVATIONS (Archaeology);EXHIBITIONS;NATURAL history museums;SAURISCHIA;MUSEUM exhibits'],
#  [4013113.0,
#   1009.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   "This bug's for you.",
#   'Austad, Steven N.<BR>Thornhill, Randy',
#   'Dec91, Vol. 100 Issue 12, p44, 6p, 6c',
#   'ANIMAL societies;ARACHNIDA;INSECT societies;INSECTS;INSECTS -- Behavior;SPIDERS;BEHAVIOR'],
#  [4013114.0,
#   3492.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'The cold facts of winter.',
#   'Halfpenny, James C.',
#   'Dec91, Vol. 100 Issue 12, p50, 12p, 10c',
#   'ANIMAL behavior;ANIMAL homing;ANIMAL migration;ANIMALS -- Wintering;BIOENERGETICS;DORMANCY (Biology);ENERGY budget (Geophysics);FRONTS (Meteorology);HIBERNATION;MOOSE;NATIONAL parks & reserves -- Idaho;NATIONAL parks & reserves -- Montana;NATIONAL parks & reserves -- Wyoming;SLEEP behavior in animals;WEATHER;WILDLIFE management;WINTER'],
#  [4013115.0,
#   1819.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'How to bear gifts.',
#   'Welsch, Roger L.',
#   'Dec91, Vol. 100 Issue 12, p62, 4p, 1 cartoon',
#   'CEREMONIAL exchange;DHEGIHA Indians;GIFTS;INDIANS of North America -- Great Plains;OMAHA Indians;SOCIAL interaction;OMAHA Indians -- Rites & ceremonies;GIFT giving;Social life & customs'],
#  [4013116.0,
#   2221.0,
#   1991.0,
#   'Sci/Tech',
#   'Natural History',
#   'Report from Oxford.',
#   'Sokolov, Raymond',
#   'Dec91, Vol. 100 Issue 12, p76, 3p',
# ...
#  [4013274.0,
#   3015.0,
#   1995.0,
#   'Sci/Tech',
#   'Natural History',
#   'Fossils by the sea.',
#   'Taylor, Michael A.<BR>Torrens, Hugh S.',
#   'Oct95, Vol. 104 Issue 10, p66, 6p, 1 map, 3c, 2bw',
#   'EVOLUTION (Biology);FOSSILS -- Collection & preservation;NATURAL selection;DARWIN, Charles, 1809-1882'],
#  [4013275.0,
#   1310.0,
#   1995.0,
#   'Sci/Tech',
#   'Natural History',
#   "Turner's Hall Woods, Barbados.",
#   'Mohlenbrock, Robert H.',
#   'Oct95, Vol. 104 Issue 10, p72, 3p, 2 maps, 3c',
#   'FOREST reserves;NATIONAL parks & reserves;NATURAL resources conservation areas;RAIN forests;TOURISM'],
#  [4013276.0,
#   1328.0,
#   1995.0,
#   'Sci/Tech',
#   'Natural History',
#   'Diary of a Museum Naturalist.',
#   '',
#   'Oct95, Vol. 104 Issue 10, p80, 3p, 1bw',
#   'EXHIBITIONS;FOSSILS -- Catalogs & collections;FOSSILS -- Collection & preservation;NATURAL history museums;ZOOLOGY;MUSEUM exhibits'],
#  [4013277.0,
#   3183.0,
#   1995.0,
#   'Sci/Tech',
#   'Natural History',
#   'The evolved imagination.',
#   'Dawkins, Richard',
#   'Sep95, Vol. 104 Issue 9, p8, 6p',
#   'ANIMAL experimentation;ANIMAL models in research;EVOLUTION (Biology);HUMAN behavior;NATURAL selection'],
#  [4013279.0,
#   3285.0,
#   1995.0,
#   'Sci/Tech',
#   'Natural History',
#   'Reversing established orders.',
#   'Gould, Stephen Jay',
#   'Sep95, Vol. 104 Issue 9, p12, 4p, 1 cartoon',
#   'ANIMAL behavior;ARTHROPODA;DINOFLAGELLATES;FISHES;INVERTEBRATES;SOCIAL behavior in animals;SOCIAL hierarchy in animals;SPONGES;ZOOLOGY'],
#  [4013280.0,
#   4739.0,
#   1995.0,
#   'Sci/Tech',
#   'Natural History',
#   'Swimming with salmon.',
#   'Maxwell, Jessica',
#   'Sep95, Vol. 104 Issue 9, p26, 14p, 1 chart, 3 maps, 10c',
#   'FISH trade;FISHERIES;FISHERY law & legislation;FISHERY scientists;HATCHERY fishes;SALMON fisheries;SALMON fisheries -- Law & legislation;SALMON industry'],
#  [4014387.0,
#   1409.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'The fundamental physical constants.',
#   'Cohen, E. Richard<BR>Taylor, Barry N.',
#   'Aug95 Supplement, Vol. 48 Issue 8, pBG9, 5p, 2 charts, 1 diagram',
#   'PHYSICAL constants;CHARTS, diagrams, etc.'],
#  [4014362.0,
#   2132.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Nobel Prize in Physics goes to Frederick Reines for detection of the neutrino...',
#   'Lubkin, Gloria B.',
#   'Dec95, Vol. 48 Issue 12, p17, 3p, 1c',
#   'NOBEL Prizes'],
#  [4014363.0,
#   2004.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   '...and Martin Perl wins for discovering the tau lepton.',
#   'Schwarzschild, Bertram',
#   'Dec95, Vol. 48 Issue 12, p17, 3p, 1c',
#   'NOBEL Prizes'],
#  [4014364.0,
#   5244.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'What future will we choose for physics?',
#   'Gruner, Sol M.<BR>Langer, James S.',
#   'Dec95, Vol. 48 Issue 12, p25, 6p, 1 chart, 4 graphs',
#   'PHYSICS -- Vocational guidance'],
#  [4014365.0,
#   3417.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Scanning force microscopy in biology.',
#   'Bustamante, Carlos<BR>Keller, David',
#   'Dec95, Vol. 48 Issue 12, p32, 7p, 1 diagram, 2 graphs, 5c, 2bw',
#   'BIOLOGICAL apparatus & supplies;MICROSCOPES;Design & construction'],
#  [4014366.0,
#   2766.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Eugene Paul Wigner: A towering figure of modern physics.',
#   'Vogt, Erich',
#   'Dec95, Vol. 48 Issue 12, p40, 5p, 5bw',
#   'PHYSICISTS -- United States'],
#  [4014367.0,
#   3616.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   "Symmetry in physics: Wigner's legacy.",
#   'Gross, David J.',
#   'Dec95, Vol. 48 Issue 12, p46, 5p, 7 diagrams, 1bw',
#   'SYMMETRY groups'],
#  [4014368.0,
#   2028.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'New gamma detector array finds evidence of hyperdeformed nuclei.',
#   'Schwarzschild, Bertram',
#   'Nov95, Vol. 48 Issue 11, p17, 3p, 2 graphs',
#   'ISOTOPES;NUCLEAR shell theory;GADOLINIUM'],
#  [4014369.0,
#   4967.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Wilhelm Conrad Rontgen and the glimmer of light.',
#   'Seliger, Howard H.',
#   'Nov95, Vol. 48 Issue 11, p25, 7p, 5bw',
#   'X-rays;HISTORY'],
#  [4014370.0,
#   4876.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Recent applications of x rays in condensed matter physics.',
#   'Als-Nielsen, Jens<BR>Materlik, Gerhard',
#   'Nov95, Vol. 48 Issue 11, p34, 7p, 2 diagrams, 8 graphs, 2bw',
#   'CONDENSED matter;X-rays'],
#  [4014371.0,
#   4762.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'X rays in molecular biophysics.',
#   'Hendrickson, Wayne A.',
#   'Nov95, Vol. 48 Issue 11, p42, 7p, 1 diagram, 1 graph, 9c, 2bw',
#   'MOLECULAR biology;X-rays'],
#  [4014372.0,
#   4022.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'X rays in medicine.',
#   'Hendee, William R.',
#   'Nov95, Vol. 48 Issue 11, p51, 6p, 5 diagrams, 2 graphs',
#   'MEDICINE -- Research;X-rays'],
#  [4014373.0,
#   4757.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'X rays from the rest of the universe.',
#   'Helfand, David J.',
#   'Nov95, Vol. 48 Issue 11, p58, 7p, 1 graph, 7c',
#   'COSMIC physics;X-rays'],
#  [4014374.0,
#   2232.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   "PhD programs II: NRC's new pecking order sets off crowning and puts some danders up.",
#   'Goodwin, Irwin',
#   'Nov95, Vol. 48 Issue 11, p67, 3p, 4 charts',
#   'PHYSICS -- Study & teaching;UNIVERSITIES & colleges -- Graduate work;NATIONAL Research Council (U.S)'],
#  [4014375.0,
#   2484.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Oscillating granular layers produce stripes, squares, hexagons...',
#   'Lubkin, Gloria B.',
#   'Oct95, Vol. 48 Issue 10, p17, 3p, 6bw',
#   'GRANULAR materials'],
#  [4014376.0,
#   2009.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Space-based telescopes see primordial helium in spectra of distant quasars.',
#   'Levi, Barbara Goss',
#   'Oct95, Vol. 48 Issue 10, p19, 3p, 1c',
#   'HELIUM;Spectra'],
#  [4014377.0,
#   5690.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Quantum information and computation.',
#   'Bennett, Charles H.',
#   'Oct95, Vol. 48 Issue 10, p24, 7p, 5 diagrams',
#   'COMPUTER algorithms;QUANTUM theory'],
#  [4014378.0,
#   5262.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Helioseismology.',
#   'Harvey, John',
#   'Oct95, Vol. 48 Issue 10, p32, 7p, 3 graphs, 2c, 1bw',
#   'ASTROPHYSICS;PHYSICS;SUN -- Internal structure'],
#  [4014379.0,
#   5233.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Julian Schwinger: Prodigy, problem solver, pioneering physicist.',
#   'Martin, Paul C.<BR>Glashow, Sheldon L.',
#   'Oct95, Vol. 48 Issue 10, p40, 7p, 5bw',
#   ''],
#  [4014380.0,
#   2569.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Despite nuclear tests by France and China, prospects rise for comprehensive test ban.',
#   'Goodwin, Irwin',
#   'Oct95, Vol. 48 Issue 10, p51, 3p, 2 graphs',
#   'NUCLEAR nonproliferation;INTERNATIONAL cooperation;NUCLEAR weapons -- Testing'],
#  [4014381.0,
#   1610.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'A model of turbulence.',
#   'Kadanoff, Leo P.',
#   'Sep95, Vol. 48 Issue 9, p11, 3p, 1 graph, 1c, 1bw',
#   'MATHEMATICAL models;TURBULENCE'],
#  [4014382.0,
#   5668.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Where does the proton really get its spin?',
#   'Jaffe, Robert L.',
#   'Sep95, Vol. 48 Issue 9, p24, 7p, 1 diagram, 2 graphs, 1 cartoon, 1c',
#   'PROTONS -- Polarization;QUANTUM chromodynamics;QUARKS'],
#  [4014383.0,
#   4831.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'Acoustic wavefronts in crystalline solids.',
#   'Wolfe, James P.',
#   'Sep95, Vol. 48 Issue 9, p34, 7p, 1 diagram, 3 graphs, 1c, 11bw',
#   'ANISOTROPY;HEARING;RESEARCH;MENSURATION;WAVE mechanics'],
#  [4014384.0,
#   3940.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'The role of science in our society.',
#   'Richter, Burton',
#   'Sep95, Vol. 48 Issue 9, p43, 5p, 2 charts, 1 diagram, 1 graph',
#   'SCIENCE -- Social aspects;TECHNOLOGY -- Social aspects'],
#  [4014385.0,
#   1257.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'PCAST meets its boss at last at third meeting, then Clinton receives an irate letter from Walker.',
#   'Goodwin, Irwin',
#   'Sep95, Vol. 48 Issue 9, p74, 3p, 1c',
#   'CONSULTANTS;CLINTON, Bill, 1946-'],
#  [4014386.0,
#   2130.0,
#   1995.0,
#   'Sci/Tech',
#   'Physics Today',
#   'What changes lie in store for US graduate physics education?',
#   'Cioffi, Denis F.',
#   'Sep95, Vol. 48 Issue 9, p79, 3p, 1 graph, 1 cartoon',
#   'PHYSICISTS;EDUCATION'],
#  [4018078.0,
#   2143.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'PSA International Conference of Photography program listing.',
#   'Mosser, Susan',
#   'Apr95, Vol. 61 Issue 4, p21, 4p, 1bw',
#   'PHOTOGRAPHY;Congresses'],
#  [4018065.0,
#   2599.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'An analysis of judging.',
#   'Sethma, E.R.',
#   'Aug95, Vol. 61 Issue 8, p9, 3p',
#   'PHOTOGRAPHS;EVALUATION'],
#  [4018066.0,
#   1652.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   "Let's try printing from slides.",
#   'Frodey, Ray<BR>Frodey, Arlene',
#   'Aug95, Vol. 61 Issue 8, p20, 3p, 3bw',
#   'PHOTOGRAPHY;SLIDES (Photography)'],
#  [4018067.0,
#   1095.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'How to enter and win photo contests.',
#   'Deitcher, Kenneth A.',
#   'Aug95, Vol. 61 Issue 8, p28, 3p, 5bw',
#   'PHOTOGRAPHY;Competitions'],
#  [4018052.0,
#   1337.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Video editing.',
#   'Hammond, Robert A.',
#   'Dec95, Vol. 61 Issue 12, p20, 3p, 5 diagrams',
#   'VIDEO tapes -- Editing'],
#  [4018053.0,
#   2332.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Exotic ports of the orient.',
#   'Ertel, Grace<BR>Ertel, Donald',
#   'Dec95, Vol. 61 Issue 12, p24, 4p, 5bw',
#   'TRAVEL'],
#  [4018082.0,
#   1138.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Colonial Williamsburg -- where the past meets the present.',
#   'Rhoda, Mary Ann',
#   'Feb95, Vol. 61 Issue 2, p8, 3p, 5bw',
#   'TRAVEL'],
#  [4018083.0,
#   1352.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Detergent fractional dimensions.',
#   'Rydquist, Susie V.',
#   'Feb95, Vol. 61 Issue 2, p11, 3p, 4bw',
#   'PHOTOGRAPHY'],
#  [4018085.0,
#   1289.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Programs & presenters.',
#   'Vaness, Jerry',
#   'Feb95, Vol. 61 Issue 2, p23, 3p, 6bw',
#   'CONGRESSES & conventions'],
#  [4018069.0,
#   2679.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'An analysis of judging.',
#   'Sethna, E.R.',
#   'Jul95, Vol. 61 Issue 7, p10, 3p',
#   'PHOTOGRAPHY;Competitions'],
#  [4018070.0,
#   1137.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'What is a portrait?',
#   'Pickrell, Barbara J.',
#   'Jul95, Vol. 61 Issue 7, p14, 3p, 4bw',
#   'PORTRAIT photography;PORTRAITS'],
#  [4018071.0,
#   1910.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Maximizing color slide division services.',
#   'Wells, Mildred G.',
#   'Jul95, Vol. 61 Issue 7, p30, 3p',
#   'SLIDES (Photography)'],
#  [4018072.0,
#   1672.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'New tools.',
#   'Horwitz, Sil',
#   'Jun95, Vol. 61 Issue 6, p6, 3p, 9bw',
#   'PHOTOGRAPHY -- Equipment & supplies'],
#  [4018073.0,
#   1109.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'How to make and use a Harris shutter.',
#   'Van Wagner, Fran',
#   'Jun95, Vol. 61 Issue 6, p14, 3p, 3 diagrams, 4bw',
#   'CAMERA shutters'],
#  [4018074.0,
#   3026.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Marketing your photography.',
#   'Traudt, Steve',
#   'Jun95, Vol. 61 Issue 6, p24, 3p',
#   'PHOTOGRAPHS;MARKETING'],
#  [4018075.0,
#   1456.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Dorothea Lange.',
#   'Perchick, Max',
#   'Jun95, Vol. 61 Issue 6, p26, 3p, 3bw',
#   'DOCUMENTARY photography'],
#  [4018076.0,
#   1701.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Pictorial photography with infrared film.',
#   'Banerjee, Debidas',
#   'Jun95, Vol. 61 Issue 6, p29, 3p, 1 chart, 3bw',
#   'INFRARED photography;PHOTOGRAPHY, Artistic'],
#  [4018080.0,
#   1727.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'March through time.',
#   'Rhoda, Mary Ann',
#   'Mar95, Vol. 61 Issue 3, p10, 4p, 7bw',
#   'CONGRESSES & conventions'],
#  [4018081.0,
#   1839.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Manifesto for digital imaging and manipulation.',
#   'Rohde, Russell A.',
#   'Mar95, Vol. 61 Issue 3, p26, 4p, 2c, 2bw',
#   'IMAGE processing -- Digital techniques;PHOTOGRAPHY'],
#  [4018077.0,
#   2328.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   "Who's who 1994.",
#   'Mudrak, Irene<BR>Mahon, Terry',
#   'May95, Vol. 61 Issue 5, p20, 22p, 21 charts',
#   ''],
#  [4018056.0,
#   1564.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Slot canyons of Arizona.',
#   'Deitcher, Kenneth A.',
#   'Nov95, Vol. 61 Issue 11, p14, 3p, 1 chart, 3bw',
#   'CANYONS -- Arizona;NATURE photography'],
#  [4018057.0,
#   2192.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Photographing the computer screen.',
#   'Klee, Albert J.',
#   'Nov95, Vol. 61 Issue 11, p17, 3p, 4bw',
#   'APPLIED photography;VIDEO display terminals'],
#  [4018058.0,
#   1009.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'A look back at Williamsburg.',
#   'Christi, Wanda',
#   'Nov95, Vol. 61 Issue 11, p20, 4p, 16bw',
#   'PHOTOGRAPHY;Congresses'],
#  [4018059.0,
#   2463.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'The lithographic/diazochrome connection.',
#   'Perchick, Max',
#   'Nov95, Vol. 61 Issue 11, p26, 4p, 1 diagram, 2c, 3bw',
#   'COLOR photography -- Processing;SLIDES (Photography)'],
#  [4018060.0,
#   3424.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Awards and honor recipients.',
#   '',
#   'Oct95, Vol. 61 Issue 10, p14, 6p, 25bw',
#   ''],
#  [4018061.0,
#   481.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'The spice of the exhibition.',
#   'Kraght, Bert<BR>Kraght, Margaret',
#   'Oct95, Vol. 61 Issue 10, p20, 6p, 1 chart, 13bw',
#   'PHOTOGRAPHY, Artistic;AWARDS'],
#  [4018062.0,
#   1947.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Taking the Cayuse challenge.',
#   'Roberts, Wilma',
#   'Oct95, Vol. 61 Issue 10, p26, 3p, 3bw',
#   'ACTION photography'],
#  [4018063.0,
#   1814.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Photographing gymnastics.',
#   'Leonard, Robert J.<BR>Leonard, Ronald J.',
#   'Sep95, Vol. 61 Issue 9, p12, 3p, 1 diagram, 3bw',
#   'PHOTOGRAPHY of sports'],
#  [4018064.0,
#   1231.0,
#   1995.0,
#   'Sci/Tech',
#   'PSA Journal',
#   'Journey through Tibet.',
#   'Williams, Marie',
#   'Sep95, Vol. 61 Issue 9, p26, 3p, 7bw',
#   'TRAVEL'],
#  [4013692.0,
#   2975.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Fall95, Vol. 32 Issue 3, p4, 4p, 5bw',
#   'SCIENCE -- Study & teaching;United States'],
#  [4013693.0,
#   2295.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'Carpe diem.',
#   'Bentley, Michael L.',
#   'Fall95, Vol. 32 Issue 3, p23, 5p, 1 chart, 1 diagram',
#   'SCIENCE -- Study & teaching'],
#  [4013698.0,
#   3027.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Spring95, Vol. 32 Issue 1, p4, 3p, 2bw',
#   'SCIENCE -- Study & teaching;United States'],
#  [4013694.0,
#   3455.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'News notes.',
#   '',
#   'Summer95, Vol. 32 Issue 2, p4, 3p, 2bw',
#   'SCIENCE -- Exhibitions'],
#  [4013695.0,
#   1535.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'Global climate change in the Great Lakes: How will agriculture in the Great Lakes region be...',
#   '',
#   'Summer95, Vol. 32 Issue 2, p17, 4p, 2 charts, 2 graphs',
#   'CROPS & climate'],
#  [4013696.0,
#   1558.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'Seeds in a sock.',
#   'Kuechle, Judy',
#   'Summer95, Vol. 32 Issue 2, p28, 6p, 24bw',
#   'ACTIVITY programs in education;CRITICAL thinking in children;ENGLISH language -- Study & teaching (Elementary)'],
#  [4013697.0,
#   4461.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'Developing science activities: Millions of ideas available.',
#   'Schlenker, Richard M.<BR>Yoshida, Sarah J.',
#   'Summer95, Vol. 32 Issue 2, p34, 7p, 3 charts',
#   'ACTIVITY programs in education;SCIENCE -- Study & teaching'],
#  [4013699.0,
#   1300.0,
#   1995.0,
#   'Sci/Tech',
#   'Science Activities',
#   'Introduction.',
#   'Fortner, Rosanne',
#   'Winter95, Vol. 31 Issue 4, p9, 3p',
#   'WATER conservation;ENVIRONMENT;Study & teaching'],
#  [4016562.0,
#   4641.0,
#   1996.0,
#   'Sci/Tech',
#   'Agricultural Research',
#   'High-tech fattens the bottom line.',
#   'Kaplan, J. Kim<BR>Senft, Dennis',
#   'Apr96, Vol. 44 Issue 4, p4, 8p, 8c',
#   'AGRICULTURE;PRECISION farming'],
#  ...]

# %% [markdown]
# Check if any rows have different lengths with each other - that is, if they have differing number of elements

# %%
temp = [str(i) for i in scienceAcadTexts_list[0]]
temp_string = '\n'.join(temp)
print("A normal row would have %d elements, as: \n\n" % len(temp), temp_string)
# Out:
# A normal row would have 9 elements, as:
#
#  4018430.0
# 9566.0
# 1990.0
# Sci/Tech
# Armed Forces & Society (Transaction Publishers)
# Congressional Oversight of the Department of Defense: Reconsidering the Conventional Wisdom.
# Lindsay, James M.<SUP>1</SUP>
# Fall90, Vol. 17 Issue 1, p7-33, 27p
# BUREAUCRACY;LEGISLATIVE oversight;LEGISLATORS;UNITED States. Congress;UNITED States. Dept. of Defense

# %%
for i in range(len(scienceAcadTexts_list)):
    
    if i == 0: 
        temp = len(scienceAcadTexts_list[i])
        pass
    
    print(temp == len(scienceAcadTexts_list[i]))
    
    temp = len(scienceAcadTexts_list[i])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ### Now to write out a new excel file with only the relevant entries

# %%
import xlsxwriter
processed_workbook = xlsxwriter.Workbook(r'D:\COCA & GloWbE\COCA\COCA Science texts Acad')
worksheet = processed_workbook.add_worksheet()

# %%
original_sheet_COLS = len(acad_sheet.row_values(0))
target_sheet_ROWS = len(scienceAcadTexts_list)
target_sheet_COLS = len(scienceAcadTexts_list[0])

# Write header
for col in range(original_sheet_COLS):
    worksheet.write(0, col, acad_sheet.row_values(0)[col])
    
# Write each row by iterating column-wise

for row in range(target_sheet_ROWS):
    for col in range(target_sheet_COLS):
        worksheet.write(row+1, col, scienceAcadTexts_list[row][col]) # row+1 because of the header

# %%
processed_workbook.close()
