# %% [markdown]
# # StanfordCoreNLP parser
# ##### Currently using the parser only, add NER later
# git - https://github.com/smilli/py-corenlp
# <br>
# how to run local web server - https://stanfordnlp.github.io/CoreNLP/corenlp-server.html#getting-started
# <br>
# on output formats - https://stanfordnlp.github.io/CoreNLP/corenlp-server.html
# <br><br>
# Run in cmd to start server
# <br>
# cd C:\stanford-corenlp-full-2017-06-09
# <br>
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000

# %% [markdown]
# API server setup

# %%
from pycorenlp import StanfordCoreNLP
import re

# Initiate CorNLP object
nlp = StanfordCoreNLP('http://localhost:9000')

output = nlp.annotate("Bears bear with other bears.", properties={
                'annotators': 'pos',
                'outputFormat': 'text' # json, xml, 
         })
print(output)
# Out:
# Sentence #1 (6 tokens):
# Bears bear with other bears.
# [Text=Bears CharacterOffsetBegin=0 CharacterOffsetEnd=5 PartOfSpeech=NNS]
# [Text=bear CharacterOffsetBegin=6 CharacterOffsetEnd=10 PartOfSpeech=VBP]
# [Text=with CharacterOffsetBegin=11 CharacterOffsetEnd=15 PartOfSpeech=IN]
# [Text=other CharacterOffsetBegin=16 CharacterOffsetEnd=21 PartOfSpeech=JJ]
# [Text=bears CharacterOffsetBegin=22 CharacterOffsetEnd=27 PartOfSpeech=NNS]
# [Text=. CharacterOffsetBegin=27 CharacterOffsetEnd=28 PartOfSpeech=.]

# %% [markdown]
# # Pre-process function

# %% [markdown]
# Raw text preprocessor

# %%
from nltk.stem import WordNetLemmatizer
import re

def preprocess(file_dir):
    """
    Removes special chars , title
    Normalizes spaces>2  to one
    """

    title = re.compile(r"%&%.*%&%")
    special_chars = re.compile(r"[!@##$$%^&*(),:\"]") 
    parag_tag = re.compile("<p>")
    
    text = open(file_dir, 'r', encoding = 'utf-8').read()
    
    text = re.sub(title, "", text)
    text = re.sub(special_chars, "", text)
    text = re.sub(parag_tag, "", text)
    text = re.sub("\s{2,}", " ",text) # Normalize 2 > whitespace to 1 whitespace
    
    return text

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(treebank_tag): 
    """
    Changes treebank tags to Wordnet tags to be fed into the WordNet lemmatizer
    Returns -1 except for ADJ, VERB, NOUN, ADV
    """
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
#     elif treebank_tag.startswith('R'):
#         return wordnet.ADV
    else:
        return -1

# %%
from nltk.tokenize import sent_tokenize


def parse_text(text, show_pos = True):
    """
    Parses text via the Stanford parser, filters outuput based on POS tags to be fed into lemmatizer   
    Removes stop words from the output
    
    Params
    lemmatize: uses WordNet to normalized words. If pos_filter ins enabled, POS is fed into the lemmatizer too. 
    For a list of POS recognized by the WordNet lemmatizer, refer to get_wordnet_pos
    stopWords_filter: removes words that are in the stop-word list
    show_pos = returns POS tags with words as a pair
    
    API parameters for Standford parser
    annotators: tokenize, ssplit, pos, lemma, ner, parse, dcoref
    outputFormats: text, json, xml, Serialized
    """              
        
    text = text.lower()
    
    output = nlp.annotate(text, properties={
            'annotators': 'ssplit, pos', 
            'outputFormat': 'json'
            })
    
    word_tags_list = []
    for sentence in output['sentences']:
        for item in sentence['tokens']:
            
            word = item['word']
            pos = item['pos']
            
            # Append to list
            if (show_pos == False):
                word_tags_list.append(word)
            elif (show_pos == True):
                word_tags_list.append(word + "_"+ pos)
            
    return word_tags_list

# %%
parse_text("I like you a/@!#?#$RE,.';'")
# Out:
# ['i_LS',
#  'like_IN',
#  'you_PRP',
#  'a_DT',
#  '/_:',
#  '@_SYM',
#  '!_.',
#  '#_#',
#  '?_.',
#  '#_#',
#  '$_$',
#  're_JJ',
#  ',_,',
#  '._.',
#  "'_''",
#  ';_:',
#  "'_''"]

# %%
# Do not add to list if:
def lemmatizer(listOfWords):
    
    
def removeStopWords(listOfWords):
    
    
    stopWords = []
    stopWords = stopwords.words('English')
        with open(r"C:\nlp\extra_stopwords.txt", 'r', encoding = 'UTF-8') as f:
            extra_stopWords = f.read()
            extra_stopWords = extra_stopWords.split("\n")
            stopWords.append(extra_stopWords)
            
    if (lemmatize == True):
        wordNet = WordNetLemmatizer()

            
            if (get_wordnet_pos(pos) == -1): # kept POS: ADJ, VERB, NOUN, ADV 
                continue
            if (stopWords_filter == True) & (word in stopWords): 
                continue
            
            if (lemmatize == True):
                word = wordNet.lemmatize(word)

# %% [markdown]
# ### Show difference w/ and w/o lemmatize
# - notice plural words and verbs lemmatzied to their original form

# %%
import os
directory = r"C:\nlp\Science-related texts"
file_list = [file for file in os.listdir(directory) if file.endswith('.txt')]

# Use 1st file as example
temp_dir = directory+"\\"+file_list[0]

# %%
from pprint import pprint
temp = preprocess(temp_dir)
lemmatized = parse_text(temp,lemmatize=False, show_pos=True)
not_lemmatized = parse_text(temp,lemmatize=True, show_pos=True)

pprint(list(zip(lemmatized, not_lemmatized)))
# Out:
# [('section_NN', 'section_NN'),
#  ('museum_NN', 'museum_NN'),
#  ('centenary_JJ', 'centenary_JJ'),
#  ('birth_NN', 'birth_NN'),
#  ('margaret_NN', 'margaret_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('remembered_VBN', 'remembered_VBN'),
#  ('world_NN', 'world_NN'),
#  ('influential_JJ', 'influential_JJ'),
#  ('anthropologist_NN', 'anthropologist_NN'),
#  ('margaret_NN', 'margaret_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('arrived_VBD', 'arrived_VBD'),
#  ('american_JJ', 'american_JJ'),
#  ('museum_NN', 'museum_NN'),
#  ('natural_JJ', 'natural_JJ'),
#  ('history_NN', 'history_NN'),
#  ('having_VBG', 'having_VBG'),
#  ('completed_VBN', 'completed_VBN'),
#  ('first_JJ', 'first_JJ'),
#  ('significant_JJ', 'significant_JJ'),
#  ('ethnographic_JJ', 'ethnographic_JJ'),
#  ('research_NN', 'research_NN'),
#  ('samoa_NN', 'samoa_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('appointed_VBN', 'appointed_VBN'),
#  ('assistant_JJ', 'assistant_JJ'),
#  ('curator_NN', 'curator_NN'),
#  ('department_NN', 'department_NN'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('years_NNS', 'year_NNS'),
#  ('old_JJ', 'old_JJ'),
#  ('mead_NN', 'mead_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('given_VBN', 'given_VBN'),
#  ('temporary_JJ', 'temporary_JJ'),
#  ('office_NN', 'office_NN'),
#  ('attic_NN', 'attic_NN'),
#  ('room_NN', 'room_NN'),
#  ('museum_NN', 'museum_NN'),
#  ('west_NN', 'west_NN'),
#  ('tower_NN', 'tower_NN'),
#  ('did_VBD', 'did_VBD'),
#  ('out-of-the-way_JJ', 'out-of-the-way_JJ'),
#  ('office_NN', 'office_NN'),
#  ('views_NNS', 'view_NNS'),
#  ('rooftops_NNS', 'rooftop_NNS'),
#  ('new_JJ', 'new_JJ'),
#  ('york_JJ', 'york_JJ'),
#  ('city_NN', 'city_NN'),
#  ('stairways_NNS', 'stairway_NNS'),
#  ('ideal_JJ', 'ideal_JJ'),
#  ('said_VBD', 'said_VBD'),
#  ('creeping_VBG', 'creeping_VBG'),
#  ('stairway_NN', 'stairway_NN'),
#  ('someone_NN', 'someone_NN'),
#  ('be_VB', 'be_VB'),
#  ('avoided_VBN', 'avoided_VBN'),
#  ('such_JJ', 'such_JJ'),
#  ('too-solicitous_JJ', 'too-solicitous_JJ'),
#  ('elderly_JJ', 'elderly_JJ'),
#  ('curator_NN', 'curator_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('laboring_VBG', 'laboring_VBG'),
#  ('other_JJ', 'other_JJ'),
#  ('stayed_VBD', 'stayed_VBD'),
#  ('rest_NN', 'rest_NN'),
#  ('life_NN', 'life_NN'),
#  ('arriving_VBG', 'arriving_VBG'),
#  ('same_JJ', 'same_JJ'),
#  ('office_NN', 'office_NN'),
#  ('be_VB', 'be_VB'),
#  ('interviewed_VBN', 'interviewed_VBN'),
#  ('mead_NN', 'mead_NN'),
#  ('position_NN', 'position_NN'),
#  ('assistant_NN', 'assistant_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('undergraduate_JJ', 'undergraduate_JJ'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('major_JJ', 'major_JJ'),
#  ('barnard_NN', 'barnard_NN'),
#  ('college_NN', 'college_NN'),
#  ('felt_VBD', 'felt_VBD'),
#  ('finding_VBG', 'finding_VBG'),
#  ('way_NN', 'way_NN'),
#  ('maze_NN', 'maze_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('inner_JJ', 'inner_JJ'),
#  ('sanctum_NN', 'sanctum_NN'),
#  ('have_VB', 'have_VB'),
#  ('been_VBN', 'been_VBN'),
#  ('test_NN', 'test_NN'),
#  ("'d_VBD", "'d_VBD"),
#  ('devised_VBN', 'devised_VBN'),
#  ('determine_VB', 'determine_VB'),
#  ('suitability_NN', 'suitability_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('grew_VBD', 'grew_VBD'),
#  ('fond_JJ', 'fond_JJ'),
#  ('office_NN', 'office_NN'),
#  ('remote_JJ', 'remote_JJ'),
#  ('location_NN', 'location_NN'),
#  ('bird_NN', 'bird_NN'),
#  ('eye_NN', 'eye_NN'),
#  ('view_NN', 'view_NN'),
#  ('busy_JJ', 'busy_JJ'),
#  ('streets_NNS', 'street_NNS'),
#  ('way_NN', 'way_NN'),
#  ('tower_NN', 'tower_NN'),
#  ('position_NN', 'position_NN'),
#  ('symbolizes_VBZ', 'symbolizes_VBZ'),
#  ('mead_NN', 'mead_NN'),
#  ('relationship_NN', 'relationship_NN'),
#  ('museum_NN', 'museum_NN'),
#  ('anthropology_VB', 'anthropology_VB'),
#  ('tower_NN', 'tower_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('part_NN', 'part_NN'),
#  ('set_VBN', 'set_VBN'),
#  ('museum_NN', 'museum_NN'),
#  ('overall_JJ', 'overall_JJ'),
#  ('structure_NN', 'structure_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('part_NN', 'part_NN'),
#  ('institution_NN', 'institution_NN'),
#  ('discipline_NN', 'discipline_NN'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('felt_VBD', 'felt_VBD'),
#  ('museum_NN', 'museum_NN'),
#  ('discipline_NN', 'discipline_NN'),
#  ('be_VB', 'be_VB'),
#  ('repository_NN', 'repository_NN'),
#  ('artifacts_NNS', 'artifact_NNS'),
#  ('engage_VB', 'engage_VB'),
#  ('finding_VBG', 'finding_VBG'),
#  ('solutions_NNS', 'solution_NNS'),
#  ('challenges_NNS', 'challenge_NNS'),
#  ('facing_VBG', 'facing_VBG'),
#  ('society_NN', 'society_NN'),
#  ('course_NN', 'course_NN'),
#  ('fifty-two-year_JJ', 'fifty-two-year_JJ'),
#  ('association_NN', 'association_NN'),
#  ('museum_NN', 'museum_NN'),
#  ('margaret_NN', 'margaret_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('scientist_NN', 'scientist_NN'),
#  ('curator_NN', 'curator_NN'),
#  ('teacher_NN', 'teacher_NN'),
#  ('author_NN', 'author_NN'),
#  ('social_JJ', 'social_JJ'),
#  ('activist_NN', 'activist_NN'),
#  ('media_NNS', 'medium_NNS'),
#  ('celebrity_NN', 'celebrity_NN'),
#  ('success_NN', 'success_NN'),
#  ('first_JJ', 'first_JJ'),
#  ('book_NN', 'book_NN'),
#  ('coming_VBG', 'coming_VBG'),
#  ('age_NN', 'age_NN'),
#  ('samoa_NN', 'samoa_NN'),
#  ('published_VBN', 'published_VBN'),
#  ('had_VBD', 'had_VBD'),
#  ('thrust_VBN', 'thrust_VBN'),
#  ('media_NNS', 'medium_NNS'),
#  ('spotlight_NN', 'spotlight_NN'),
#  ('book_NN', 'book_NN'),
#  ('comparison_NN', 'comparison_NN'),
#  ('adolescence_NN', 'adolescence_NN'),
#  ('south_JJ', 'south_JJ'),
#  ('seas_NNS', 'sea_NNS'),
#  ('time_NN', 'time_NN'),
#  ('public_NN', 'public_NN'),
#  ('was_VBD', 'wa_VBD'),
#  ('concerned_VBN', 'concerned_VBN'),
#  ('social_JJ', 'social_JJ'),
#  ('transformations_NNS', 'transformation_NNS'),
#  ('jazz_NN', 'jazz_NN'),
#  ('age_NN', 'age_NN'),
#  ('youth_NN', 'youth_NN'),
#  ('early_JJ', 'early_JJ'),
#  ('television_NN', 'television_NN'),
#  ('became_VBD', 'became_VBD'),
#  ('widespread_JJ', 'widespread_JJ'),
#  ('mead_NN', 'mead_NN'),
#  ('appeared_VBD', 'appeared_VBD'),
#  ('cbs_NNS', 'cbs_NNS'),
#  ('program_NN', 'program_NN'),
#  ('adventure_NN', 'adventure_NN'),
#  ('series_NN', 'series_NN'),
#  ('produced_VBD', 'produced_VBD'),
#  ('live_JJ', 'live_JJ'),
#  ('museum_NN', 'museum_NN'),
#  ('talk_VB', 'talk_VB'),
#  ('trance_NN', 'trance_NN'),
#  ('balinese_JJ', 'balinese_JJ'),
#  ('impact_NN', 'impact_NN'),
#  ('world_NN', 'world_NN'),
#  ('war_NN', 'war_NN'),
#  ('social_JJ', 'social_JJ'),
#  ('change_NN', 'change_NN'),
#  ('remote_JJ', 'remote_JJ'),
#  ('societies_NNS', 'society_NNS'),
#  ('new_JJ', 'new_JJ'),
#  ('guinea_NN', 'guinea_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('flair_NN', 'flair_NN'),
#  ('writing_VBG', 'writing_VBG'),
#  ('public_JJ', 'public_JJ'),
#  ('speaking_NN', 'speaking_NN'),
#  ('combined_VBN', 'combined_VBN'),
#  ('belief_NN', 'belief_NN'),
#  ('anthropologists_NNS', 'anthropologist_NNS'),
#  ('museums_NNS', 'museum_NNS'),
#  ('address_VB', 'address_VB'),
#  ('contemporary_JJ', 'contemporary_JJ'),
#  ('social_JJ', 'social_JJ'),
#  ('issues_NNS', 'issue_NNS'),
#  ('led_VBD', 'led_VBD'),
#  ('participation-as_NNS', 'participation-as_NNS'),
#  ('expert_NN', 'expert_NN'),
#  ('human_JJ', 'human_JJ'),
#  ('behavior-in_NN', 'behavior-in_NN'),
#  ('united_VBN', 'united_VBN'),
#  ('nations_NNS', 'nation_NNS'),
#  ('conferences_NNS', 'conference_NNS'),
#  ('other_JJ', 'other_JJ'),
#  ('international_JJ', 'international_JJ'),
#  ('forums_NNS', 'forum_NNS'),
#  ('acting_NN', 'acting_NN'),
#  ('consultant_NN', 'consultant_NN'),
#  ('institutions_NNS', 'institution_NNS'),
#  ('organizations_NNS', 'organization_NNS'),
#  ('discussed_VBD', 'discussed_VBD'),
#  ('role_NN', 'role_NN'),
#  ('scientist_NN', 'scientist_NN'),
#  ('society_NN', 'society_NN'),
#  ('changing_VBG', 'changing_VBG'),
#  ('nature_NN', 'nature_NN'),
#  ('family_NN', 'family_NN'),
#  ('racial_JJ', 'racial_JJ'),
#  ('inequality_NN', 'inequality_NN'),
#  ('peaceful_JJ', 'peaceful_JJ'),
#  ('alternatives_NNS', 'alternative_NNS'),
#  ('war_NN', 'war_NN'),
#  ('population_NN', 'population_NN'),
#  ('growth_NN', 'growth_NN'),
#  ('environmental_JJ', 'environmental_JJ'),
#  ('degradation_NN', 'degradation_NN'),
#  ('creation_NN', 'creation_NN'),
#  ('humane_JJ', 'humane_JJ'),
#  ('human_JJ', 'human_JJ'),
#  ('settlements_NNS', 'settlement_NNS'),
#  ('wide-ranging_JJ', 'wide-ranging_JJ'),
#  ('concern_NN', 'concern_NN'),
#  ('humanity_NN', 'humanity_NN'),
#  ('led_VBD', 'led_VBD'),
#  ('time_NN', 'time_NN'),
#  ('declare_VB', 'declare_VB'),
#  ('mead_NN', 'mead_NN'),
#  ('mother_NN', 'mother_NN'),
#  ('world_NN', 'world_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('surprising_JJ', 'surprising_JJ'),
#  ('museum_NN', 'museum_NN'),
#  ('celebrated_VBD', 'celebrated_VBD'),
#  ('125th_NN', '125th_NN'),
#  ('treasures_NNS', 'treasure_NNS'),
#  ('margaret_NNP', 'margaret_NNP'),
#  ('mead_VBD', 'mead_VBD'),
#  ('is_VBZ', 'is_VBZ'),
#  ('listed_VBN', 'listed_VBN'),
#  ('treasure_NN', 'treasure_NN'),
#  ('no._NN', 'no._NN'),
#  ('right_NN', 'right_NN'),
#  ('folsom_NN', 'folsom_NN'),
#  ('point_NN', 'point_NN'),
#  ('treasure_NN', 'treasure_NN'),
#  ('no._NN', 'no._NN'),
#  ('peregrine_JJ', 'peregrine_JJ'),
#  ('falcon_NN', 'falcon_NN'),
#  ('diorama_NN', 'diorama_NN'),
#  ('treasure_NN', 'treasure_NN'),
#  ('guidebook_NN', 'guidebook_NN'),
#  ('states_VBZ', 'state_VBZ'),
#  ('mead_NN', 'mead_NN'),
#  ('brought_VBD', 'brought_VBD'),
#  ('serious_JJ', 'serious_JJ'),
#  ('work_NN', 'work_NN'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('public_JJ', 'public_JJ'),
#  ('consciousness_NN', 'consciousness_NN'),
#  ('books_NNS', 'book_NNS'),
#  ('courses_NNS', 'course_NNS'),
#  ('taught_VBD', 'taught_VBD'),
#  ('columbia_NN', 'columbia_NN'),
#  ('university_NN', 'university_NN'),
#  ('articles_NNS', 'article_NNS'),
#  ('wrote_VBD', 'wrote_VBD'),
#  ('monthly_JJ', 'monthly_JJ'),
#  ('column_NN', 'column_NN'),
#  ('redbook_NN', 'redbook_NN'),
#  ('frequent_JJ', 'frequent_JJ'),
#  ('interviews_NNS', 'interview_NNS'),
#  ('were_VBD', 'were_VBD'),
#  ('published_VBN', 'published_VBN'),
#  ('magazines_NNS', 'magazine_NNS'),
#  ('newspapers_NNS', 'newspaper_NNS'),
#  ('broadcast_NN', 'broadcast_NN'),
#  ('radio_NN', 'radio_NN'),
#  ('television_NN', 'television_NN'),
#  ('visited_VBD', 'visited_VBD'),
#  ('museum_NN', 'museum_NN'),
#  ('last_JJ', 'last_JJ'),
#  ('spring_NN', 'spring_NN'),
#  ('renovated_VBN', 'renovated_VBN'),
#  ('hall_NN', 'hall_NN'),
#  ('peoples_NNS', 'people_NNS'),
#  ('pacific-which_NN', 'pacific-which_NN'),
#  ('had_VBD', 'had_VBD'),
#  ('opened_VBN', 'opened_VBN'),
#  ('decades_NNS', 'decade_NNS'),
#  ('mead_NN', 'mead_NN'),
#  ('began_VBD', 'began_VBD'),
#  ('planning_VBG', 'planning_VBG'),
#  ('it-had_NN', 'it-had_NN'),
#  ('reopened_VBD', 'reopened_VBD'),
#  ('was_VBD', 'wa_VBD'),
#  ('pleased_VBN', 'pleased_VBN'),
#  ('see_VB', 'see_VB'),
#  ('hall_NN', 'hall_NN'),
#  ('incorporates_VBZ', 'incorporates_VBZ'),
#  ('mead_NN', 'mead_NN'),
#  ('exhibition_NN', 'exhibition_NN'),
#  ('continuous_JJ', 'continuous_JJ'),
#  ('videotapes_NNS', 'videotape_NNS'),
#  ('show_VBP', 'show_VBP'),
#  ('interviews_NNS', 'interview_NNS'),
#  ('photographs_NNS', 'photograph_NNS'),
#  ('mead_NN', 'mead_NN'),
#  ('people_NNS', 'people_NNS'),
#  ('studied_VBD', 'studied_VBD'),
#  ('quotes_NNS', 'quote_NNS'),
#  ('notes_NNS', 'note_NNS'),
#  ('lectures_VBZ', 'lecture_VBZ'),
#  ('artifacts_NNS', 'artifact_NNS'),
#  ('collected_VBD', 'collected_VBD'),
#  ('give_VB', 'give_VB'),
#  ('viewer_NN', 'viewer_NN'),
#  ('insights_NNS', 'insight_NNS'),
#  ('process_NN', 'process_NN'),
#  ('doing_VBG', 'doing_VBG'),
#  ('fieldwork_NN', 'fieldwork_NN'),
#  ('add_VB', 'add_VB'),
#  ('social_JJ', 'social_JJ'),
#  ('historical_JJ', 'historical_JJ'),
#  ('context_NN', 'context_NN'),
#  ('presented-the_JJ', 'presented-the_JJ'),
#  ('presidential_JJ', 'presidential_JJ'),
#  ('medal_NN', 'medal_NN'),
#  ('freedom_NN', 'freedom_NN'),
#  ('received_VBD', 'received_VBD'),
#  ('president_NN', 'president_NN'),
#  ('jimmy_NN', 'jimmy_NN'),
#  ('carter_JJ', 'carter_JJ'),
#  ('signature_NN', 'signature_NN'),
#  ('red_JJ', 'red_JJ'),
#  ('cape_NN', 'cape_NN'),
#  ('stick_NN', 'stick_NN'),
#  ('label_NN', 'label_NN'),
#  ('reads_VBZ', 'read_VBZ'),
#  ('later_JJ', 'later_JJ'),
#  ('years_NNS', 'year_NNS'),
#  ('margaret_NN', 'margaret_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('wore_VBD', 'wore_VBD'),
#  ('cape_NN', 'cape_NN'),
#  ('used_VBD', 'used_VBD'),
#  ('style_NN', 'style_NN'),
#  ('walking_VBG', 'walking_VBG'),
#  ('stick_NN', 'stick_NN'),
#  ('called_VBD', 'called_VBD'),
#  ('thumbstick_NN', 'thumbstick_NN'),
#  ('items_NNS', 'item_NNS'),
#  ('became_VBD', 'became_VBD'),
#  ('familiar_JJ', 'familiar_JJ'),
#  ('sight_NN', 'sight_NN'),
#  ('dr._NN', 'dr._NN'),
#  ('mead_NN', 'mead_NN'),
#  ('traveled_VBD', 'traveled_VBD'),
#  ('numerous_JJ', 'numerous_JJ'),
#  ('lectures_VBZ', 'lecture_VBZ'),
#  ('conferences_NNS', 'conference_NNS'),
#  ('margaret_NN', 'margaret_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('used_VBN', 'used_VBN'),
#  ('joke_VB', 'joke_VB'),
#  ('did_VBD', 'did_VBD'),
#  ('want_VB', 'want_VB'),
#  ('be_VB', 'be_VB'),
#  ('recognized_VBN', 'recognized_VBN'),
#  ('had_VBD', 'had_VBD'),
#  ('do_VB', 'do_VB'),
#  ('was_VBD', 'wa_VBD'),
#  ('leave_VB', 'leave_VB'),
#  ('cape_NN', 'cape_NN'),
#  ('thumbstick_NN', 'thumbstick_NN'),
#  ('home_NN', 'home_NN'),
#  ('fitting_JJ', 'fitting_JJ'),
#  ('has_VBZ', 'ha_VBZ'),
#  ('become_VBN', 'become_VBN'),
#  ('museum_NN', 'museum_NN'),
#  ('treasure_NN', 'treasure_NN'),
#  ('artifact_NN', 'artifact_NN'),
#  ('december_NNP', 'december_NNP'),
#  ('lecture_NN', 'lecture_NN'),
#  ('cosmic_JJ', 'cosmic_JJ'),
#  ('habitat_NN', 'habitat_NN'),
#  ('distinguished_VBN', 'distinguished_VBN'),
#  ('authors_NNS', 'author_NNS'),
#  ('astronomy_NN', 'astronomy_NN'),
#  ('series_NN', 'series_NN'),
#  ('astronomer_NN', 'astronomer_NN'),
#  ('royal_NN', 'royal_NN'),
#  ('martin_NN', 'martin_NN'),
#  ('rees_NNS', 'rees_NNS'),
#  ('royal_JJ', 'royal_JJ'),
#  ('society_NN', 'society_NN'),
#  ('research_NN', 'research_NN'),
#  ('professor_NN', 'professor_NN'),
#  ('university_NN', 'university_NN'),
#  ('cambridge_NN', 'cambridge_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('space_NN', 'space_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('hayden_NN', 'hayden_NN'),
#  ('planetarium_NN', 'planetarium_NN'),
#  ('december_NNP', 'december_NNP'),
#  ('panel_NN', 'panel_NN'),
#  ('discussion_NN', 'discussion_NN'),
#  ('using_VBG', 'using_VBG'),
#  ('genome_NN', 'genome_NN'),
#  ('understand_VB', 'understand_VB'),
#  ('human_JJ', 'human_JJ'),
#  ('ancestry_NN', 'ancestry_NN'),
#  ('moderated_VBN', 'moderated_VBN'),
#  ('nicholas_NNS', 'nicholas_NNS'),
#  ('wade_VB', 'wade_VB'),
#  ('new_JJ', 'new_JJ'),
#  ('york_NN', 'york_NN'),
#  ('times_NNS', 'time_NNS'),
#  ('biologist_NN', 'biologist_NN'),
#  ('andrew_NN', 'andrew_NN'),
#  ('clark_NN', 'clark_NN'),
#  ('pennsylvania_NN', 'pennsylvania_NN'),
#  ('state_NN', 'state_NN'),
#  ('university_NN', 'university_NN'),
#  ('douglas_NNS', 'douglas_NNS'),
#  ('wallace_NN', 'wallace_NN'),
#  ('center_NN', 'center_NN'),
#  ('molecular_JJ', 'molecular_JJ'),
#  ('medicine_NN', 'medicine_NN'),
#  ('emory_NN', 'emory_NN'),
#  ('university_NN', 'university_NN'),
#  ('evolutionary_JJ', 'evolutionary_JJ'),
#  ('biologist_NN', 'biologist_NN'),
#  ('joseph_NN', 'joseph_NN'),
#  ('graves_VBZ', 'graf_VBZ'),
#  ('jr._NN', 'jr._NN'),
#  ('arizona_NN', 'arizona_NN'),
#  ('state_NN', 'state_NN'),
#  ('university_NN', 'university_NN'),
#  ('west_NN', 'west_NN'),
#  ('december_NNP', 'december_NNP'),
#  ('p.m._NN', 'p.m._NN'),
#  ('kaufmann_NN', 'kaufmann_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('presented_VBN', 'presented_VBN'),
#  ('conjunction_NN', 'conjunction_NN'),
#  ('exhibition_NN', 'exhibition_NN'),
#  ('genomic_JJ', 'genomic_JJ'),
#  ('revolution_NN', 'revolution_NN'),
#  ('view_NN', 'view_NN'),
#  ('january_NNP', 'january_NNP'),
#  ('gallery_NN', 'gallery_NN'),
#  ('workshops_NNS', 'workshop_NNS'),
#  ('genetics_NNS', 'genetics_NNS'),
#  ('december_NNP', 'december_NNP'),
#  ('a.m._NN', 'a.m._NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('december_NNP', 'december_NNP'),
#  ('a.m._NN', 'a.m._NN'),
#  ('follow-up_NN', 'follow-up_NN'),
#  ('explanation_NN', 'explanation_NN'),
#  ('session_NN', 'session_NN'),
#  ('december_NNP', 'december_NNP'),
#  ('p.m._NN', 'p.m._NN'),
#  ('december_NNP', 'december_NNP'),
#  ('roundtable_JJ', 'roundtable_JJ'),
#  ('presentation_NN', 'presentation_NN'),
#  ('border_NN', 'border_NN'),
#  ('crossing_VBG', 'crossing_VBG'),
#  ('cultural_JJ', 'cultural_JJ'),
#  ('appropriation_NN', 'appropriation_NN'),
#  ('artistic_JJ', 'artistic_JJ'),
#  ('freedom_NN', 'freedom_NN'),
#  ('arts_NNS', 'art_NNS'),
#  ('media_NNS', 'medium_NNS'),
#  ('literature_NN', 'literature_NN'),
#  ('indigenous_JJ', 'indigenous_JJ'),
#  ('latina_JJ', 'latina_JJ'),
#  ('women_NNS', 'woman_NNS'),
#  ('identities_NNS', 'identity_NNS'),
#  ('borders_NNS', 'border_NNS'),
#  ('series_NN', 'series_NN'),
#  ('moderated_VBN', 'moderated_VBN'),
#  ('writer_NN', 'writer_NN'),
#  ('helena_NN', 'helena_NN'),
#  ('maria_NN', 'maria_NN'),
#  ('viramontes_NNS', 'viramontes_NNS'),
#  ('cornell_VBP', 'cornell_VBP'),
#  ('university_NN', 'university_NN'),
#  ('artist_NN', 'artist_NN'),
#  ('participants_NNS', 'participant_NNS'),
#  ('nadema_JJ', 'nadema_JJ'),
#  ('agard_NN', 'agard_NN'),
#  ('maria_NN', 'maria_NN'),
#  ('dominguez_NN', 'dominguez_NN'),
#  ('carol_NN', 'carol_NN'),
#  ('kalafatic_NN', 'kalafatic_NN'),
#  ('kinder_JJR', 'kinder_JJR'),
#  ('theater_NN', 'theater_NN'),
#  ('gallery_NN', 'gallery_NN'),
#  ('visit_NN', 'visit_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('virgin_JJ', 'virgin_JJ'),
#  ('guadalupe_NN', 'guadalupe_NN'),
#  ('women_NNS', 'woman_NNS'),
#  ('artists_NNS', 'artist_NNS'),
#  ('crossing_VBG', 'crossing_VBG'),
#  ('borders_NNS', 'border_NNS'),
#  ('henry_JJ', 'henry_JJ'),
#  ('street_NN', 'street_NN'),
#  ('settlement_NN', 'settlement_NN'),
#  ('abrons_NNS', 'abrons_NNS'),
#  ('art_NN', 'art_NN'),
#  ('center_NN', 'center_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('shuttle_NN', 'shuttle_NN'),
#  ('amnh_NN', 'amnh_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('see_VB', 'see_VB'),
#  ('www.amnh.org/programs_NNS', 'www.amnh.org/programs_NNS'),
#  ('december_NNP', 'december_NNP'),
#  ('lecture_VB', 'lecture_VB'),
#  ('hubble_JJ', 'hubble_JJ'),
#  ('time_NN', 'time_NN'),
#  ('machine_NN', 'machine_NN'),
#  ('frontiers_NNS', 'frontier_NNS'),
#  ('astrophysics_NNS', 'astrophysics_NNS'),
#  ('series_NN', 'series_NN'),
#  ('astronomer_NN', 'astronomer_NN'),
#  ('james_NNS', 'james_NNS'),
#  ('lowenthal_JJ', 'lowenthal_JJ'),
#  ('university_NN', 'university_NN'),
#  ('massachusetts_NNS', 'massachusetts_NNS'),
#  ('amherst_NN', 'amherst_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('space_NN', 'space_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('hayden_NN', 'hayden_NN'),
#  ('planetarium_NN', 'planetarium_NN'),
#  ('december_NNP', 'december_NNP'),
#  ('january_NNP', 'january_NNP'),
#  ('lectures_VBZ', 'lecture_VBZ'),
#  ('upcoming_VBG', 'upcoming_VBG'),
#  ('sky_NN', 'sky_NN'),
#  ('events_NNS', 'event_NNS'),
#  ('celestial_JJ', 'celestial_JJ'),
#  ('highlights_VBZ', 'highlight_VBZ'),
#  ('hayden_JJ', 'hayden_JJ'),
#  ('lecturer_NN', 'lecturer_NN'),
#  ('amateur_JJ', 'amateur_JJ'),
#  ('astronomer_NN', 'astronomer_NN'),
#  ('hank_NN', 'hank_NN'),
#  ('bartol_NN', 'bartol_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('space_NN', 'space_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('hayden_NN', 'hayden_NN'),
#  ('planetarium_NN', 'planetarium_NN'),
#  ('december_NNP', 'december_NNP'),
#  ('kwanzaa_NN', 'kwanzaa_NN'),
#  ('celebration_NN', 'celebration_NN'),
#  ('performances_NNS', 'performance_NNS'),
#  ('workshops_NNS', 'workshop_NNS'),
#  ('marketplace_NN', 'marketplace_NN'),
#  ('african_JJ', 'african_JJ'),
#  ('american_JJ', 'american_JJ'),
#  ('holiday_NN', 'holiday_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('hall_NN', 'hall_NN'),
#  ('ocean_NN', 'ocean_NN'),
#  ('life_NN', 'life_NN'),
#  ('schedule_NN', 'schedule_NN'),
#  ('events_NNS', 'event_NNS'),
#  ('call_VBP', 'call_VBP'),
#  ('visit_VB', 'visit_VB'),
#  ('www.anmh.org/programs_NNS', 'www.anmh.org/programs_NNS'),
#  ('january_NNP', 'january_NNP'),
#  ('lecture_VB', 'lecture_VB'),
#  ('riddle_NN', 'riddle_NN'),
#  ('compass_NN', 'compass_NN'),
#  ('distinguished_VBN', 'distinguished_VBN'),
#  ('authors_NNS', 'author_NNS'),
#  ('astronomy_NN', 'astronomy_NN'),
#  ('series_NN', 'series_NN'),
#  ('author_NN', 'author_NN'),
#  ('mathematician_NN', 'mathematician_NN'),
#  ('amir_NN', 'amir_NN'),
#  ('d._NN', 'd._NN'),
#  ('aczel_NN', 'aczel_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('space_NN', 'space_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('hayden_NN', 'hayden_NN'),
#  ('planetarium_NN', 'planetarium_NN'),
#  ('january_NNP', 'january_NNP'),
#  ('weekend_NN', 'weekend_NN'),
#  ('programs_NNS', 'program_NNS'),
#  ('america_NN', 'america_NN'),
#  ('home_NN', 'home_NN'),
#  ('arab_JJ', 'arab_JJ'),
#  ('american_NN', 'american_NN'),
#  ('asian_JJ', 'asian_JJ'),
#  ('community-based_JJ', 'community-based_JJ'),
#  ('organizations_NNS', 'organization_NNS'),
#  ('present_JJ', 'present_JJ'),
#  ('films_NNS', 'film_NNS'),
#  ('artist_NN', 'artist_NN'),
#  ('talks_NNS', 'talk_NNS'),
#  ('panel_NN', 'panel_NN'),
#  ('discussions_NNS', 'discussion_NNS'),
#  ('readings_NNS', 'reading_NNS'),
#  ('performances_NNS', 'performance_NNS'),
#  ('leonhardt_NN', 'leonhardt_NN'),
#  ('people_NNS', 'people_NNS'),
#  ('center_NN', 'center_NN'),
#  ('january_NNP', 'january_NNP'),
#  ('frederick_NN', 'frederick_NN'),
#  ('p._NN', 'p._NN'),
#  ('rose_VBD', 'rose_VBD'),
#  ('director_NN', 'director_NN'),
#  ('hayden_NN', 'hayden_NN'),
#  ('planetarium_NN', 'planetarium_NN'),
#  ('charles_NNS', 'charles_NNS'),
#  ('department_NN', 'department_NN'),
#  ('astrophysics_NNS', 'astrophysics_NNS'),
#  ('p.m._NN', 'p.m._NN'),
#  ('kaufmann_NN', 'kaufmann_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('january_NNP', 'january_NNP'),
#  ('lecture/demonstration_NN', 'lecture/demonstration_NN'),
#  ('time_NN', 'time_NN'),
#  ('space_NN', 'space_NN'),
#  ('following_VBG', 'following_VBG'),
#  ('beat_NN', 'beat_NN'),
#  ('series_NN', 'series_NN'),
#  ('based_VBN', 'based_VBN'),
#  ('instruments_NNS', 'instrument_NNS'),
#  ('amnh_NN', 'amnh_NN'),
#  ('hall_NN', 'hall_NN'),
#  ('african_JJ', 'african_JJ'),
#  ('peoples_NNS', 'people_NNS'),
#  ('percussionists_NNS', 'percussionist_NNS'),
#  ('neil_NN', 'neil_NN'),
#  ('ayanda_NN', 'ayanda_NN'),
#  ('clarke_NN', 'clarke_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('leonhardt_NN', 'leonhardt_NN'),
#  ('people_NNS', 'people_NNS'),
#  ('center_NN', 'center_NN'),
#  ('january_NNP', 'january_NNP'),
#  ('lecture_NN', 'lecture_NN'),
#  ('aquagenesis_NN', 'aquagenesis_NN'),
#  ('origin_NN', 'origin_NN'),
#  ('evolution_NN', 'evolution_NN'),
#  ('life_NN', 'life_NN'),
#  ('sea_NN', 'sea_NN'),
#  ('marine_JJ', 'marine_JJ'),
#  ('biologist_NN', 'biologist_NN'),
#  ('artist_NN', 'artist_NN'),
#  ('richard_NN', 'richard_NN'),
#  ('ellis_VBZ', 'elli_VBZ'),
#  ('amnh_NN', 'amnh_NN'),
#  ('division_NN', 'division_NN'),
#  ('paleontology_NN', 'paleontology_NN'),
#  ('p.m._NN', 'p.m._NN'),
#  ('kaufmann_NN', 'kaufmann_NN'),
#  ('theater_NN', 'theater_NN'),
#  ('december/january_JJ', 'december/january_JJ'),
#  ('museum_NN', 'museum_NN'),
#  ('origami_JJ', 'origami_JJ'),
#  ('holiday_NN', 'holiday_NN'),
#  ('tree_NN', 'tree_NN'),
#  ('decorated_VBN', 'decorated_VBN'),
#  ('folded-paper_JJ', 'folded-paper_JJ'),
#  ('animals_NNS', 'animal_NNS'),
#  ('is_VBZ', 'is_VBZ'),
#  ('display_NN', 'display_NN'),
#  ('theodore_NN', 'theodore_NN'),
#  ('roosevelt_NN', 'roosevelt_NN'),
#  ('memorial_NN', 'memorial_NN'),
#  ('hall_NN', 'hall_NN'),
#  ('teachers_NNS', 'teacher_NNS'),
#  ('resource_NN', 'resource_NN'),
#  ('musings_NNS', 'musing_NNS'),
#  ('web_NN', 'web_NN'),
#  ('newsletter_NN', 'newsletter_NN'),
#  ('science_NN', 'science_NN'),
#  ('educators_NNS', 'educator_NNS'),
#  ('toolong_NN', 'toolong_NN'),
#  ('university_NN', 'university_NN'),
#  ('walls_NNS', 'wall_NNS'),
#  ('telephone_NN', 'telephone_NN'),
#  ('courses_NNS', 'course_NNS'),
#  ('natural_JJ', 'natural_JJ'),
#  ('sciences_NNS', 'science_NNS'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('museum_NN', 'museum_NN'),
#  ('department_NN', 'department_NN'),
#  ('education_NN', 'education_NN'),
#  ('dorot_VB', 'dorot_VB'),
#  ('nonprofit_JJ', 'nonprofit_JJ'),
#  ('serving_VBG', 'serving_VBG'),
#  ('elderly_JJ', 'elderly_JJ'),
#  ('information_NN', 'information_NN'),
#  ('call_NN', 'call_NN'),
#  ('dorot_NN', 'dorot_NN'),
#  ('toll-free_JJ', 'toll-free_JJ'),
#  ('adults_NNS', 'adult_NNS'),
#  ('museum_NN', 'museum_NN'),
#  ('call_NN', 'call_NN'),
#  ('information_NN', 'information_NN'),
#  ('planetarium_NN', 'planetarium_NN'),
#  ('courses_NNS', 'course_NNS'),
#  ('beginning_VBG', 'beginning_VBG'),
#  ('january_NNP', 'january_NNP'),
#  ('choose_VB', 'choose_VB'),
#  ('telescope_NN', 'telescope_NN'),
#  ('stars_VBZ', 'star_VBZ'),
#  ('constellations_NNS', 'constellation_NNS'),
#  ('legends_NNS', 'legend_NNS'),
#  ('many_JJ', 'many_JJ'),
#  ('others_NNS', 'others_NNS'),
#  ('complete_JJ', 'complete_JJ'),
#  ('course_NN', 'course_NN'),
#  ('descriptions_NNS', 'description_NNS'),
#  ('visit_VBP', 'visit_VBP'),
#  ('www.amnh.org/hayden/_NN', 'www.amnh.org/hayden/_NN'),
#  ('news_NN', 'news_NN'),
#  ('center_NN', 'center_NN'),
#  ('biodiversity_NN', 'biodiversity_NN'),
#  ('conservation_NN', 'conservation_NN'),
#  ('go_VBP', 'go_VBP'),
#  ('toolong_NN', 'toolong_NN'),
#  ('american_JJ', 'american_JJ'),
#  ('museum_NN', 'museum_NN'),
#  ('natural_JJ', 'natural_JJ'),
#  ('history_NN', 'history_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('located_JJ', 'located_JJ'),
#  ('central_JJ', 'central_JJ'),
#  ('park_NN', 'park_NN'),
#  ('west_NN', 'west_NN'),
#  ('79th_JJ', '79th_JJ'),
#  ('street_NN', 'street_NN'),
#  ('new_JJ', 'new_JJ'),
#  ('york_JJ', 'york_JJ'),
#  ('city_NN', 'city_NN'),
#  ('listings_NNS', 'listing_NNS'),
#  ('exhibitions_NNS', 'exhibition_NNS'),
#  ('public_JJ', 'public_JJ'),
#  ('programs_NNS', 'program_NNS'),
#  ('hours_NNS', 'hour_NNS'),
#  ('call_VBP', 'call_VBP'),
#  ('visit_VB', 'visit_VB'),
#  ('museum_NN', 'museum_NN'),
#  ('web_NN', 'web_NN'),
#  ('site_NN', 'site_NN'),
#  ('www.amnh.org_NN', 'www.amnh.org_NN'),
#  ('space_NN', 'space_NN'),
#  ('show_NN', 'show_NN'),
#  ('tickets_NNS', 'ticket_NNS'),
#  ('retail_JJ', 'retail_JJ'),
#  ('products_NNS', 'product_NNS'),
#  ('museum_NN', 'museum_NN'),
#  ('memberships_NNS', 'membership_NNS'),
#  ('are_VBP', 'are_VBP'),
#  ('available_JJ', 'available_JJ'),
#  ('online_NN', 'online_NN'),
#  ('nancy_NN', 'nancy_NN'),
#  ('c._NN', 'c._NN'),
#  ('lutkehaus_NN', 'lutkehaus_NN'),
#  ('nancy_NN', 'nancy_NN'),
#  ('c._NN', 'c._NN'),
#  ('lutkehaus_NN', 'lutkehaus_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('chair_NN', 'chair_NN'),
#  ('gender_NN', 'gender_NN'),
#  ('studies_NNS', 'study_NNS'),
#  ('program_NN', 'program_NN'),
#  ('associate_JJ', 'associate_JJ'),
#  ('professor_NN', 'professor_NN'),
#  ('department_NN', 'department_NN'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('university_NN', 'university_NN'),
#  ('southern_JJ', 'southern_JJ'),
#  ('california_NN', 'california_NN'),
#  ('is_VBZ', 'is_VBZ'),
#  ('author_NN', 'author_NN'),
#  ('forthcoming_JJ', 'forthcoming_JJ'),
#  ('margaret_NN', 'margaret_NN'),
#  ('mead_NN', 'mead_NN'),
#  ('media_NNS', 'medium_NNS'),
#  ('anthropology_NN', 'anthropology_NN'),
#  ('creation_NN', 'creation_NN'),
#  ('american_JJ', 'american_JJ'),
#  ('icon_NN', 'icon_NN')]
