# %% [markdown]
# # 1. Basic Settings

# %%
import gensim
import os
import logging

# Log settings
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# # 2. Training - Import file list

# %%
from os import listdir
from os.path import isfile, join
docList = []
docList = [f for f in listdir("D:\\COCA & GloWbE\\COCA\\Pre-processed Text\\Science-related Texts\\") if f.endswith('.txt')]

# %%
len(docList)
# Out:
# 10258

# %%
# Note that this imports ALL FILES in dir
class SentenceIterator(object):

    def __init__(self, dirname):
        self.dirname = dirname

    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield gensim.utils.simple_preprocess(line)

# a memory - friendly iterator
sentence_interator = SentenceIterator('D:\\COCA & GloWbE\\COCA\\Pre-processed Text\\Science-related Texts')

# %% [markdown]
# # Get doc labels
# - Doc labels are *titles* of each text
# - titles are at the forefront of a text, with the delimiters %&% front to back on the title

# %%
import re

directory = "D:\\COCA & GloWbE\\COCA\\Pre-processed Text\\Science-related Texts\\"
pattern = re.compile(r"%&%.*%&%") # to get title of text

titleList = []

for fileName in docList:
    
    with open(directory + fileName, encoding='utf-8') as f:
        text = f.read()
    
    matched = pattern.match(text)
    title = matched.group().strip("%&%")
    titleList.append(title)
    
    # print(title)

# %% [markdown]
# Load file data

# %%
texts = []

for file in os.listdir(directory):
    texts.append( str( open( os.path.join(directory, file), encoding='utf-8').readlines() ))

# %% [markdown]
# # Labeled Sentence interator

# %%
# import gensim
# LabeledSentence = gensim.models.doc2vec.LabeledSentence
# preprocess = gensim.utils.simple_preprocess


class LabeledLineSentence(object):
    def __init__(self, doc_list, labels_list):
        LabeledSentence = gensim.models.doc2vec.LabeledSentence
        preprocess = gensim.utils.simple_preprocess
        self.labels_list = labels_list
        self.doc_list = doc_list
    def __iter__(self):
        for idx, doc in enumerate(self.doc_list):
            yield LabeledSentence(words=preprocess(doc),tags=[self.labels_list[idx]])

# %% [markdown]
# # Training

# %%
sentences = LabeledLineSentence(texts, titleList)

# %%
# This is too slow to run
model = gensim.models.Doc2Vec(size=300, window=10, min_count=5, workers=11,alpha=0.025, min_alpha=0.025) # use fixed learning rate
model.build_vocab(sentences)
for epoch in range(10):
    model.train(sentences, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.002 # decrease the learning rate
    model.min_alpha = model.alpha # fix the learning rate, no deca
    model.train(it, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# 2017-11-04 21:52:49,322 : INFO : collecting all words and their counts
# 2017-11-04 21:52:49,327 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-11-04 21:53:30,102 : INFO : PROGRESS: at example #10000, processed 23403653 words (573990/s), 199240 word types, 9206 tags
# 2017-11-04 21:53:30,589 : INFO : collected 199240 word types and 9206 unique tags from a corpus of 10258 examples and 23683065 words
# 2017-11-04 21:53:30,590 : INFO : Loading a fresh vocabulary
# 2017-11-04 21:53:31,731 : INFO : min_count=5 retains 72438 unique words (36% of original 199240, drops 126802)
# 2017-11-04 21:53:31,732 : INFO : min_count=5 leaves 23475162 word corpus (99% of original 23683065, drops 207903)
# 2017-11-04 21:53:32,046 : INFO : deleting the raw counts dictionary of 199240 items
# 2017-11-04 21:53:32,054 : INFO : sample=0.001 downsamples 32 most-common words
# 2017-11-04 21:53:32,056 : INFO : downsampling leaves estimated 18884695 word corpus (80.4% of prior 23475162)
# 2017-11-04 21:53:32,057 : INFO : estimated required memory for 72438 words and 300 dimensions: 222958600 bytes
# 2017-11-04 21:53:32,343 : INFO : resetting layer weights
# 2017-11-04 21:53:33,611 : INFO : training model with 11 workers on 72438 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017
words/s, in_qsize 21, out_qsize 0
# 2017-11-04 21:59:03,993 : INFO : PROGRESS: at 97.98% examples, 280038 words/s, in_qsize 20, out_qsize 1
# 2017-11-04 21:59:05,019 : INFO : PROGRESS: at 98.26% examples, 280043 words/s, in_qsize 21, out_qsize 0
# 2017-11-04 21:59:06,055 : INFO : PROGRESS: at 98.56% examples, 279987 words/s, in_qsize 20, out_qsize 1
# 2017-11-04 21:59:07,064 : INFO : PROGRESS: at 98.91% examples, 280012 words/s, in_qsize 21, out_qsize 0
# 2017-11-04 21:59:08,094 : INFO : PROGRESS: at 99.24% examples, 279973 words/s, in_qsize 21, out_qsize 0
# 2017-11-04 21:59:08,971 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2017-11-04 21:59:08,978 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2017-11-04 21:59:08,989 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2017-11-04 21:59:09,007 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2017-11-04 21:59:09,013 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-11-04 21:59:09,019 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-11-04 21:59:09,029 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-11-04 21:59:09,037 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-11-04 21:59:09,055 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-11-04 21:59:09,059 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-11-04 21:59:09,081 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-11-04 21:59:09,083 : INFO : training on 118415325 raw words (94038777 effective words) took 335.5s, 280327 effective words/s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-f6577a7a96cc> in <module>()
#       6     model.alpha -= 0.002 # decrease the learning rate
#       7     model.min_alpha = model.alpha # fix the learning rate, no deca
# ----> 8     model.train(it, total_examples=model.corpus_count, epochs=model.iter)
#
# NameError: name 'it' is not defined

# %%
model.wv.vocab
# Out:
# {'american': <gensim.models.keyedvectors.Vocab at 0x2610b63e438>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x2617bc18390>,
#  'section': <gensim.models.keyedvectors.Vocab at 0x2610b492668>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x2610b503390>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x2610bd24940>,
#  'museum': <gensim.models.keyedvectors.Vocab at 0x2610bd24b38>,
#  'centenary': <gensim.models.keyedvectors.Vocab at 0x2610bd24c50>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x2610bd24a20>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x2610bd24cc0>,
#  'birth': <gensim.models.keyedvectors.Vocab at 0x2610bd24cf8>,
#  'margaret': <gensim.models.keyedvectors.Vocab at 0x2610bd24d30>,
#  'mead': <gensim.models.keyedvectors.Vocab at 0x2610bd24da0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x2610bd24dd8>,
#  'remembered': <gensim.models.keyedvectors.Vocab at 0x2610bd24e10>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x2610bd24198>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x2610bd24048>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x2610bd24080>,
#  'influential': <gensim.models.keyedvectors.Vocab at 0x2610bd240b8>,
#  'anthropologist': <gensim.models.keyedvectors.Vocab at 0x2610bd240f0>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x2610bd24630>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x2610bd24240>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x2610bd242b0>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x2610bd243c8>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x2610bd24438>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x2610bd245f8>,
#  'completed': <gensim.models.keyedvectors.Vocab at 0x2610bd24710>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x2610bd24780>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x2610bd247f0>,
#  'ethnographic': <gensim.models.keyedvectors.Vocab at 0x2610bd24978>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x2610bd249b0>,
#  'samoa': <gensim.models.keyedvectors.Vocab at 0x2610b4f0b00>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x2610b602c18>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x2610b6502b0>,
#  'appointed': <gensim.models.keyedvectors.Vocab at 0x2610b650dd8>,
#  'assistant': <gensim.models.keyedvectors.Vocab at 0x2610b650860>,
#  'curator': <gensim.models.keyedvectors.Vocab at 0x2610b6503c8>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x2610b7e05c0>,
#  'anthropology': <gensim.models.keyedvectors.Vocab at 0x2610b7e06a0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x2610b7e0710>,
#  'twenty': <gensim.models.keyedvectors.Vocab at 0x2610b7e0ba8>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x2610b7e0b70>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x2610b7e02b0>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x2610b7e0198>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x2610b7e0e10>,
#  'temporary': <gensim.models.keyedvectors.Vocab at 0x2610b7e0978>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x2610b7e0a20>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x2610b7e0e48>,
#  'attic': <gensim.models.keyedvectors.Vocab at 0x2610b7e0f28>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x2610b7e0438>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x2610b7e0f60>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x2610b7e00b8>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x2610b7e0b00>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x2610b7e0080>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x2610b7e0128>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x2610b7e0160>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x2610b7e0240>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x2610b7e0c88>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x2610b7e0390>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x2610b7e03c8>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x2610b66a390>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x2610b66a860>,
#  'rooftops': <gensim.models.keyedvectors.Vocab at 0x2610b66a0b8>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x2610b66a358>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x2610b66a320>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x2610b66acc0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x2610b66a518>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x2610b805f28>,
#  'stairways': <gensim.models.keyedvectors.Vocab at 0x2610b805748>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x2610b8056a0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x2610b805550>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x2610b805ac8>,
#  'creeping': <gensim.models.keyedvectors.Vocab at 0x2610b805b00>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x2610b805c50>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x2610b805c88>,
#  'stairway': <gensim.models.keyedvectors.Vocab at 0x2610b805d30>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x2610b805d68>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x2610b805e80>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x2610b805f60>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x2610b805fd0>,
#  'avoided': <gensim.models.keyedvectors.Vocab at 0x2610b8051d0>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x2610b805208>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x2610b8050b8>,
#  'solicitous': <gensim.models.keyedvectors.Vocab at 0x2610b805400>,
#  'elderly': <gensim.models.keyedvectors.Vocab at 0x2610b805710>,
#  'laboring': <gensim.models.keyedvectors.Vocab at 0x2610b805358>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x2610b8052b0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x2610b805320>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x2610b805390>,
#  'stayed': <gensim.models.keyedvectors.Vocab at 0x2610b805438>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x2610b8054e0>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x2610b805048>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x2610b8056d8>,
#  'arriving': <gensim.models.keyedvectors.Vocab at 0x2610b498ef0>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x2610b89bb00>,
#  'interviewed': <gensim.models.keyedvectors.Vocab at 0x2610b89b940>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x2610b89b978>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x2610b89bb70>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x2610b89bba8>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x2610b89bc18>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x2610b89bc88>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x2610b89bcf8>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x2610b89bd68>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x2610b89bda0>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x2610b89bdd8>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x2610b89be10>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x2610b89beb8>,
#  'maze': <gensim.models.keyedvectors.Vocab at 0x2610b89bef0>,
#  'inner': <gensim.models.keyedvectors.Vocab at 0x2610b89bf60>,
#  'sanctum': <gensim.models.keyedvectors.Vocab at 0x2610b89b588>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x2610b89b048>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x2610b89b0b8>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x2610b89b128>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x2610b89b160>,
#  'devised': <gensim.models.keyedvectors.Vocab at 0x2610b89b198>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x2610b89b1d0>,
#  'suitability': <gensim.models.keyedvectors.Vocab at 0x2610b89b278>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x2610b89b2e8>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x2610b89b320>,
#  'fond': <gensim.models.keyedvectors.Vocab at 0x2610b89b470>,
#  'remote': <gensim.models.keyedvectors.Vocab at 0x2610b89b4e0>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x2610b89b518>,
#  'bird': <gensim.models.keyedvectors.Vocab at 0x2610b89bb38>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x2610b89b5c0>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x2610b89b6a0>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x2610b89b710>,
#  'streets': <gensim.models.keyedvectors.Vocab at 0x2610b89b748>,
#  'below': <gensim.models.keyedvectors.Vocab at 0x2610b89b3c8>,
#  'symbolizes': <gensim.models.keyedvectors.Vocab at 0x2610b89b7b8>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x2610b89b908>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x2610b89b2b0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x2610b89b7f0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x2610b89b828>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x2610b89b898>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x2610b89b8d0>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x2610b89ba58>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x2610b89bac8>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x2610b84d3c8>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x2610b84df28>,
#  'discipline': <gensim.models.keyedvectors.Vocab at 0x2610b84d710>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x2610b84d438>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x2610b84d4a8>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x2610b84d2b0>,
#  'strongly': <gensim.models.keyedvectors.Vocab at 0x2610b84d470>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x2610b84d4e0>,
#  'repository': <gensim.models.keyedvectors.Vocab at 0x2610b84d5c0>,
#  'artifacts': <gensim.models.keyedvectors.Vocab at 0x2610b84d630>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x2610b84d6d8>,
#  'engage': <gensim.models.keyedvectors.Vocab at 0x2610b84d908>,
#  'solutions': <gensim.models.keyedvectors.Vocab at 0x2610b84d978>,
#  'challenges': <gensim.models.keyedvectors.Vocab at 0x2610b84da58>,
#  'facing': <gensim.models.keyedvectors.Vocab at 0x2610b84da90>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x2610b84dbe0>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x2610b84dc88>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x2610b84de10>,
#  'fifty': <gensim.models.keyedvectors.Vocab at 0x2610b84df98>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x2610b84d8d0>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x2610b84d0f0>,
#  'scientist': <gensim.models.keyedvectors.Vocab at 0x2610b84d390>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x2610b84d1d0>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x2610b84dcf8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x2610b84d320>,
#  'activist': <gensim.models.keyedvectors.Vocab at 0x2610b59fa20>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x2610b59fac8>,
#  'celebrity': <gensim.models.keyedvectors.Vocab at 0x2610b59fc18>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x2610bd03080>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x2610bd03cc0>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x2610bd03a90>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x2610bd03e10>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x2610bd031d0>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x2610bd03240>,
#  'thrust': <gensim.models.keyedvectors.Vocab at 0x2610bd030f0>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x2610bd035c0>,
#  'spotlight': <gensim.models.keyedvectors.Vocab at 0x2610bd03c50>,
#  'comparison': <gensim.models.keyedvectors.Vocab at 0x2610b8041d0>,
#  'adolescence': <gensim.models.keyedvectors.Vocab at 0x2610b8040b8>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x2610b804908>,
#  'seas': <gensim.models.keyedvectors.Vocab at 0x2610b804128>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x2610b804e10>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x2610b804518>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x2610b804400>,
#  'concerned': <gensim.models.keyedvectors.Vocab at 0x2610b804470>,
#  'transformations': <gensim.models.keyedvectors.Vocab at 0x2610b804550>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x2610b804588>,
#  'jazz': <gensim.models.keyedvectors.Vocab at 0x2610b804630>,
#  'youth': <gensim.models.keyedvectors.Vocab at 0x2610b804668>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x2610b8046d8>,
#  'television': <gensim.models.keyedvectors.Vocab at 0x2610b804748>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x2610b804780>,
#  'widespread': <gensim.models.keyedvectors.Vocab at 0x2610b8047b8>,
#  'appeared': <gensim.models.keyedvectors.Vocab at 0x2610b804860>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x2610b804940>,
#  'cbs': <gensim.models.keyedvectors.Vocab at 0x2610b804b00>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x2610b804ba8>,
#  'adventure': <gensim.models.keyedvectors.Vocab at 0x2610b804be0>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x2610b804c50>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x2610b804c88>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x2610b804358>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x2610b804dd8>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x2610b804f60>,
#  'trance': <gensim.models.keyedvectors.Vocab at 0x2610b804fd0>,
#  'balinese': <gensim.models.keyedvectors.Vocab at 0x2610b804898>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x2610b804cf8>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x2610b804cc0>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x2610b8044e0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x2610b4a5cc0>,
#  'societies': <gensim.models.keyedvectors.Vocab at 0x2610b5c1278>,
#  'guinea': <gensim.models.keyedvectors.Vocab at 0x2610b5c1828>,
#  'flair': <gensim.models.keyedvectors.Vocab at 0x2610b5c19e8>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x2610b5c1320>,
#  'speaking': <gensim.models.keyedvectors.Vocab at 0x2610b473be0>,
#  'combined': <gensim.models.keyedvectors.Vocab at 0x2610b6ab860>,
#  'belief': <gensim.models.keyedvectors.Vocab at 0x2610b4e0828>,
#  'anthropologists': <gensim.models.keyedvectors.Vocab at 0x2610b5b9b38>,
#  'museums': <gensim.models.keyedvectors.Vocab at 0x2610b5b9668>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x2610b5b9198>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x2610b5b94a8>,
#  'contemporary': <gensim.models.keyedvectors.Vocab at 0x2610bd2a128>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x2610bd2a630>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x2610bd2a4a8>,
#  'participation': <gensim.models.keyedvectors.Vocab at 0x2610bd2a5f8>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x2610bd2a6a0>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x2610bd2a978>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x2610bd2a9b0>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x2610bd2ad30>,
#  'nations': <gensim.models.keyedvectors.Vocab at 0x2610bd2a390>,
#  'conferences': <gensim.models.keyedvectors.Vocab at 0x2610bd2aac8>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x2610bd2a278>,
#  'forums': <gensim.models.keyedvectors.Vocab at 0x2610bd2a240>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x2610bd2aa20>,
#  'consultant': <gensim.models.keyedvectors.Vocab at 0x2610bd2a3c8>,
#  'institutions': <gensim.models.keyedvectors.Vocab at 0x2610bd2a6d8>,
#  'organizations': <gensim.models.keyedvectors.Vocab at 0x2610bd2a9e8>,
#  'worldwide': <gensim.models.keyedvectors.Vocab at 0x2610bd2a898>,
#  'discussed': <gensim.models.keyedvectors.Vocab at 0x2610bd2ae10>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x2610bd2ae80>,
#  'changing': <gensim.models.keyedvectors.Vocab at 0x2610bd2a208>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x2610bd2a550>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x2610bd2a320>,
#  'racial': <gensim.models.keyedvectors.Vocab at 0x2610bd2a358>,
#  'inequality': <gensim.models.keyedvectors.Vocab at 0x2610bd2a400>,
#  'peaceful': <gensim.models.keyedvectors.Vocab at 0x2610b5fd0b8>,
#  'alternatives': <gensim.models.keyedvectors.Vocab at 0x2617b8b85f8>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x2610b518860>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x2610b521e10>,
#  'environmental': <gensim.models.keyedvectors.Vocab at 0x2610b656940>,
#  'degradation': <gensim.models.keyedvectors.Vocab at 0x2610b656550>,
#  'creation': <gensim.models.keyedvectors.Vocab at 0x2610b6569b0>,
#  'humane': <gensim.models.keyedvectors.Vocab at 0x2610b656ac8>,
#  'settlements': <gensim.models.keyedvectors.Vocab at 0x2610b656b38>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x2610b656e10>,
#  'ranging': <gensim.models.keyedvectors.Vocab at 0x2610b656128>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x2610b656470>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x2610b656518>,
#  'declare': <gensim.models.keyedvectors.Vocab at 0x2610b656198>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x2610b870eb8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x2610b8706d8>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x2610b870b00>,
#  'surprising': <gensim.models.keyedvectors.Vocab at 0x2610b870748>,
#  'celebrated': <gensim.models.keyedvectors.Vocab at 0x2610b8705f8>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x2610b870f28>,
#  'treasures': <gensim.models.keyedvectors.Vocab at 0x2610b8705c0>,
#  'herself': <gensim.models.keyedvectors.Vocab at 0x2610b870780>,
#  'listed': <gensim.models.keyedvectors.Vocab at 0x2610b8707f0>,
#  'treasure': <gensim.models.keyedvectors.Vocab at 0x2610b870828>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x2610b870898>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x2610b8708d0>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x2610b870940>,
#  'folsom': <gensim.models.keyedvectors.Vocab at 0x2610b870978>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x2610b8709b0>,
#  'peregrine': <gensim.models.keyedvectors.Vocab at 0x2610b8709e8>,
#  'falcon': <gensim.models.keyedvectors.Vocab at 0x2610b870a90>,
#  'diorama': <gensim.models.keyedvectors.Vocab at 0x2610b870ac8>,
#  'guidebook': <gensim.models.keyedvectors.Vocab at 0x2610b870f98>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x2610b870fd0>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x2610b870ef0>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x2610b870080>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x2610b8700b8>,
#  'consciousness': <gensim.models.keyedvectors.Vocab at 0x2610b8700f0>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x2610b870160>,
#  'courses': <gensim.models.keyedvectors.Vocab at 0x2610b870198>,
#  'taught': <gensim.models.keyedvectors.Vocab at 0x2610b8701d0>,
#  'columbia': <gensim.models.keyedvectors.Vocab at 0x2610b870208>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x2610b870240>,
#  'articles': <gensim.models.keyedvectors.Vocab at 0x2610b870278>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x2610b8702b0>,
#  'monthly': <gensim.models.keyedvectors.Vocab at 0x2610b8702e8>,
#  'column': <gensim.models.keyedvectors.Vocab at 0x2610b870320>,
#  'frequent': <gensim.models.keyedvectors.Vocab at 0x2610b870390>,
#  'interviews': <gensim.models.keyedvectors.Vocab at 0x2610b8703c8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x2610b870438>,
#  'magazines': <gensim.models.keyedvectors.Vocab at 0x2610b870588>,
#  'newspapers': <gensim.models.keyedvectors.Vocab at 0x2610b870630>,
#  'broadcast': <gensim.models.keyedvectors.Vocab at 0x2610b870668>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x2610b870b38>,
#  'visited': <gensim.models.keyedvectors.Vocab at 0x2610b870ba8>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x2610b8704a8>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x2610b870c18>,
#  'newly': <gensim.models.keyedvectors.Vocab at 0x2610b870c50>,
#  'renovated': <gensim.models.keyedvectors.Vocab at 0x2610b870cc0>,
#  'hall': <gensim.models.keyedvectors.Vocab at 0x2610b870cf8>,
#  'peoples': <gensim.models.keyedvectors.Vocab at 0x2610b870d30>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x2610b870d68>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x2610b870e10>,
#  'decades': <gensim.models.keyedvectors.Vocab at 0x2610b870e48>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x2610b4bf438>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x2610b4bfe80>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x2610b8868d0>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x2610b886940>,
#  'reopened': <gensim.models.keyedvectors.Vocab at 0x2610b886d30>,
#  'pleased': <gensim.models.keyedvectors.Vocab at 0x2610b886518>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x2610b886908>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x2610b886da0>,
#  'incorporates': <gensim.models.keyedvectors.Vocab at 0x2610b886dd8>,
#  'exhibition': <gensim.models.keyedvectors.Vocab at 0x2610b886e80>,
#  'continuous': <gensim.models.keyedvectors.Vocab at 0x2610b886eb8>,
#  'videotapes': <gensim.models.keyedvectors.Vocab at 0x2610b886ef0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x2610b886f28>,
#  'photographs': <gensim.models.keyedvectors.Vocab at 0x2610b886f60>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x2610b886fd0>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x2610b886c50>,
#  'quotes': <gensim.models.keyedvectors.Vocab at 0x2610b886400>,
#  'notes': <gensim.models.keyedvectors.Vocab at 0x2610b886470>,
#  'lectures': <gensim.models.keyedvectors.Vocab at 0x2610b8864e0>,
#  'collected': <gensim.models.keyedvectors.Vocab at 0x2610b886588>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x2610b8865c0>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x2610b8865f8>,
#  'insights': <gensim.models.keyedvectors.Vocab at 0x2610b886630>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x2610b886668>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x2610b8864a8>,
#  'fieldwork': <gensim.models.keyedvectors.Vocab at 0x2610b8860b8>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x2610b886cf8>,
#  'historical': <gensim.models.keyedvectors.Vocab at 0x2610b886080>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x2610b8866a0>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x2610b8869b0>,
#  'presidential': <gensim.models.keyedvectors.Vocab at 0x2610b886d68>,
#  'medal': <gensim.models.keyedvectors.Vocab at 0x2610b8860f0>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x2610b886128>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x2610b886240>,
#  'posthumously': <gensim.models.keyedvectors.Vocab at 0x2610b8862b0>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x2610b886320>,
#  'jimmy': <gensim.models.keyedvectors.Vocab at 0x2610b886978>,
#  'carter': <gensim.models.keyedvectors.Vocab at 0x2610b8869e8>,
#  'signature': <gensim.models.keyedvectors.Vocab at 0x2610b886a20>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x2610b886a58>,
#  'cape': <gensim.models.keyedvectors.Vocab at 0x2610b886ac8>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x2610b886b00>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x2610b886ba8>,
#  'reads': <gensim.models.keyedvectors.Vocab at 0x2610b886be0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x2610b886c18>,
#  'regularly': <gensim.models.keyedvectors.Vocab at 0x2610b886c88>,
#  'wore': <gensim.models.keyedvectors.Vocab at 0x2610b8866d8>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x2610b886780>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x2610b8867f0>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x2610b886860>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x2610b886898>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x2610b5df4e0>,
#  'thumbstick': <gensim.models.keyedvectors.Vocab at 0x2610b5df940>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x2610b5df748>,
#  'items': <gensim.models.keyedvectors.Vocab at 0x2610b5dfe10>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x2610b5dfdd8>,
#  'sight': <gensim.models.keyedvectors.Vocab at 0x2610b5df198>,
#  'dr': <gensim.models.keyedvectors.Vocab at 0x2610b5df160>,
#  'traveled': <gensim.models.keyedvectors.Vocab at 0x2610b6a7908>,
#  'numerous': <gensim.models.keyedvectors.Vocab at 0x2610b510550>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x2610b8f6080>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x2610b8f60b8>,
#  'recognized': <gensim.models.keyedvectors.Vocab at 0x2610b8f60f0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x2610b8f6128>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x2610b8f6198>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x2610b8f61d0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x2610b8f6208>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x2610b8f6278>,
#  'fitting': <gensim.models.keyedvectors.Vocab at 0x2610b8f62e8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x2610b8f6ba8>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x2610b8f63c8>,
#  'artifact': <gensim.models.keyedvectors.Vocab at 0x2610b8f6400>,
#  'december': <gensim.models.keyedvectors.Vocab at 0x2610b8f6438>,
#  'lecture': <gensim.models.keyedvectors.Vocab at 0x2610b8f6390>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x2610b8f64e0>,
#  'cosmic': <gensim.models.keyedvectors.Vocab at 0x2610b8f6358>,
#  'habitat': <gensim.models.keyedvectors.Vocab at 0x2610b8f6470>,
#  'distinguished': <gensim.models.keyedvectors.Vocab at 0x2610b8f6518>,
#  'authors': <gensim.models.keyedvectors.Vocab at 0x2610b8f6550>,
#  'astronomy': <gensim.models.keyedvectors.Vocab at 0x2610b8f65c0>,
#  'astronomer': <gensim.models.keyedvectors.Vocab at 0x2610b8f65f8>,
#  'royal': <gensim.models.keyedvectors.Vocab at 0x2610b8f6668>,
#  'martin': <gensim.models.keyedvectors.Vocab at 0x2610b8f66a0>,
#  'rees': <gensim.models.keyedvectors.Vocab at 0x2610b8f66d8>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x2610b8f6710>,
#  'cambridge': <gensim.models.keyedvectors.Vocab at 0x2610b8f67b8>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x2610b8f67f0>,
#  'theater': <gensim.models.keyedvectors.Vocab at 0x2610b8f6860>,
#  'hayden': <gensim.models.keyedvectors.Vocab at 0x2610b8f6898>,
#  'planetarium': <gensim.models.keyedvectors.Vocab at 0x2610b8f6908>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x2610b8f6978>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x2610b8f69b0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x2610b8f69e8>,
#  'genome': <gensim.models.keyedvectors.Vocab at 0x2610b8f6a20>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x2610b8f6a58>,
#  'ancestry': <gensim.models.keyedvectors.Vocab at 0x2610b8f6a90>,
#  'moderated': <gensim.models.keyedvectors.Vocab at 0x2610b8f6ac8>,
#  'nicholas': <gensim.models.keyedvectors.Vocab at 0x2610b8f6b00>,
#  'wade': <gensim.models.keyedvectors.Vocab at 0x2610b8f6b38>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x2610b8f6b70>,
#  'biologist': <gensim.models.keyedvectors.Vocab at 0x2610b8f6be0>,
#  'andrew': <gensim.models.keyedvectors.Vocab at 0x2610b8f6c18>,
#  'clark': <gensim.models.keyedvectors.Vocab at 0x2610b8f6c50>,
#  'pennsylvania': <gensim.models.keyedvectors.Vocab at 0x2610b8f6c88>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x2610b8f6cf8>,
#  'douglas': <gensim.models.keyedvectors.Vocab at 0x2610b8f6d68>,
#  'wallace': <gensim.models.keyedvectors.Vocab at 0x2610b8f6da0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x2610b8f6dd8>,
#  'molecular': <gensim.models.keyedvectors.Vocab at 0x2610b8f6e10>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x2610b8f6e48>,
#  'emory': <gensim.models.keyedvectors.Vocab at 0x2610b8f6e80>,
#  'evolutionary': <gensim.models.keyedvectors.Vocab at 0x2610b8f6eb8>,
#  'joseph': <gensim.models.keyedvectors.Vocab at 0x2610b8f6ef0>,
#  'graves': <gensim.models.keyedvectors.Vocab at 0x2610b8f6f28>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x2610b8f6f60>,
#  'arizona': <gensim.models.keyedvectors.Vocab at 0x2610b8f6f98>,
#  'kaufmann': <gensim.models.keyedvectors.Vocab at 0x2610b8f6fd0>,
#  'conjunction': <gensim.models.keyedvectors.Vocab at 0x2610b8f6320>,
#  'genomic': <gensim.models.keyedvectors.Vocab at 0x2610b8f6048>,
#  'revolution': <gensim.models.keyedvectors.Vocab at 0x2610b7c0390>,
#  'january': <gensim.models.keyedvectors.Vocab at 0x2610b7c0c88>,
#  'gallery': <gensim.models.keyedvectors.Vocab at 0x2610b7c0b70>,
#  'workshops': <gensim.models.keyedvectors.Vocab at 0x2610b7c0470>,
#  'genetics': <gensim.models.keyedvectors.Vocab at 0x2610b7c0710>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x2610b7c0780>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x2610b7c06d8>,
#  'session': <gensim.models.keyedvectors.Vocab at 0x2610b7c0f28>,
#  'roundtable': <gensim.models.keyedvectors.Vocab at 0x2610b850828>,
#  'presentation': <gensim.models.keyedvectors.Vocab at 0x2610b850eb8>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x2610b8509b0>,
#  'crossing': <gensim.models.keyedvectors.Vocab at 0x2610b850b38>,
#  'cultural': <gensim.models.keyedvectors.Vocab at 0x2610b850c18>,
#  'appropriation': <gensim.models.keyedvectors.Vocab at 0x2610b850c88>,
#  'artistic': <gensim.models.keyedvectors.Vocab at 0x2610b850da0>,
#  'arts': <gensim.models.keyedvectors.Vocab at 0x2610b850cc0>,
#  'literature': <gensim.models.keyedvectors.Vocab at 0x2610b850dd8>,
#  'indigenous': <gensim.models.keyedvectors.Vocab at 0x2610b850320>,
#  'latina': <gensim.models.keyedvectors.Vocab at 0x2610b850198>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x2610b850ba8>,
#  'identities': <gensim.models.keyedvectors.Vocab at 0x2610b850e48>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x2610b850208>,
#  'borders': <gensim.models.keyedvectors.Vocab at 0x2610b850470>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x2610b8504a8>,
#  'helena': <gensim.models.keyedvectors.Vocab at 0x2610b850518>,
#  'maria': <gensim.models.keyedvectors.Vocab at 0x2610b850550>,
#  'cornell': <gensim.models.keyedvectors.Vocab at 0x2610b8505c0>,
#  'artist': <gensim.models.keyedvectors.Vocab at 0x2610b850630>,
#  'participants': <gensim.models.keyedvectors.Vocab at 0x2610b8506a0>,
#  'dominguez': <gensim.models.keyedvectors.Vocab at 0x2610b850748>,
#  'carol': <gensim.models.keyedvectors.Vocab at 0x2610b7da978>,
#  'kinder': <gensim.models.keyedvectors.Vocab at 0x2610b7da6a0>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x2610b7da2b0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x2610b7da9b0>,
#  'virgin': <gensim.models.keyedvectors.Vocab at 0x2610b7daa90>,
#  'guadalupe': <gensim.models.keyedvectors.Vocab at 0x2610b7daac8>,
#  'artists': <gensim.models.keyedvectors.Vocab at 0x2610b7dabe0>,
#  'henry': <gensim.models.keyedvectors.Vocab at 0x2610b7dac18>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x2610b7dac50>,
#  'settlement': <gensim.models.keyedvectors.Vocab at 0x2610b7dac88>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x2610b7dacc0>,
#  'shuttle': <gensim.models.keyedvectors.Vocab at 0x2610b7dada0>,
#  'amnh': <gensim.models.keyedvectors.Vocab at 0x2610b7dadd8>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x2610b7dae10>,
#  'www': <gensim.models.keyedvectors.Vocab at 0x2610b7daeb8>,
#  'org': <gensim.models.keyedvectors.Vocab at 0x2610b7da438>,
#  'programs': <gensim.models.keyedvectors.Vocab at 0x2610b7da2e8>,
#  'hubble': <gensim.models.keyedvectors.Vocab at 0x2610b7da358>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x2610b7da390>,
#  'frontiers': <gensim.models.keyedvectors.Vocab at 0x2610b7da320>,
#  'astrophysics': <gensim.models.keyedvectors.Vocab at 0x2610b7da4e0>,
#  'james': <gensim.models.keyedvectors.Vocab at 0x2610b7da550>,
#  'massachusetts': <gensim.models.keyedvectors.Vocab at 0x2610b7da9e8>,
#  'amherst': <gensim.models.keyedvectors.Vocab at 0x2610b7da898>,
#  'upcoming': <gensim.models.keyedvectors.Vocab at 0x2610b7dae80>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x2610b7da780>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x2610b7da860>,
#  'celestial': <gensim.models.keyedvectors.Vocab at 0x2610b444198>,
#  'highlights': <gensim.models.keyedvectors.Vocab at 0x2610b5cd400>,
#  'lecturer': <gensim.models.keyedvectors.Vocab at 0x2610b5d9ba8>,
#  'amateur': <gensim.models.keyedvectors.Vocab at 0x2617518cf60>,
#  'hank': <gensim.models.keyedvectors.Vocab at 0x2610b8e5080>,
#  'bartol': <gensim.models.keyedvectors.Vocab at 0x2610b8e50b8>,
#  'kwanzaa': <gensim.models.keyedvectors.Vocab at 0x2610b8e5208>,
#  'celebration': <gensim.models.keyedvectors.Vocab at 0x2610b8e5240>,
#  'performances': <gensim.models.keyedvectors.Vocab at 0x2610b8e5278>,
#  'marketplace': <gensim.models.keyedvectors.Vocab at 0x2610b8e52b0>,
#  'african': <gensim.models.keyedvectors.Vocab at 0x2610b8e52e8>,
#  'holiday': <gensim.models.keyedvectors.Vocab at 0x2610b8e5358>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x2610b8e53c8>,
#  'schedule': <gensim.models.keyedvectors.Vocab at 0x2610b8e5400>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x2610b8e5438>,
#  'riddle': <gensim.models.keyedvectors.Vocab at 0x2610b8e5470>,
#  'compass': <gensim.models.keyedvectors.Vocab at 0x2610b8e54a8>,
#  'mathematician': <gensim.models.keyedvectors.Vocab at 0x2610b8e54e0>,
#  'amir': <gensim.models.keyedvectors.Vocab at 0x2610b8e5550>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x2610b8e5588>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x2610b8e55c0>,
#  'arab': <gensim.models.keyedvectors.Vocab at 0x2610b8e55f8>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x2610b8e5630>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x2610b8e5668>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x2610b8e56a0>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x2610b8e56d8>,
#  'films': <gensim.models.keyedvectors.Vocab at 0x2610b8e5710>,
#  'talks': <gensim.models.keyedvectors.Vocab at 0x2610b8e5748>,
#  'discussions': <gensim.models.keyedvectors.Vocab at 0x2610b8e5780>,
#  'readings': <gensim.models.keyedvectors.Vocab at 0x2610b8e5e80>,
#  'leonhardt': <gensim.models.keyedvectors.Vocab at 0x2610b8e57b8>,
#  'frederick': <gensim.models.keyedvectors.Vocab at 0x2610b8e57f0>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x2610b8e5ef0>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x2610b8e5f28>,
#  'charles': <gensim.models.keyedvectors.Vocab at 0x2610b8e5e10>,
#  'liu': <gensim.models.keyedvectors.Vocab at 0x2610b8e5f98>,
#  'demonstration': <gensim.models.keyedvectors.Vocab at 0x2610b8e5f60>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x2610b8e5dd8>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x2610b8e5eb8>,
#  'instruments': <gensim.models.keyedvectors.Vocab at 0x2610b8e5fd0>,
#  'neil': <gensim.models.keyedvectors.Vocab at 0x2610b8e5048>,
#  'clarke': <gensim.models.keyedvectors.Vocab at 0x2610b8e5128>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x2610b8e5b38>,
#  'evolution': <gensim.models.keyedvectors.Vocab at 0x2610b8e51d0>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x2610b8e5860>,
#  'marine': <gensim.models.keyedvectors.Vocab at 0x2610b8e5898>,
#  'richard': <gensim.models.keyedvectors.Vocab at 0x2610b8e5908>,
#  'ellis': <gensim.models.keyedvectors.Vocab at 0x2610b8e5940>,
#  'division': <gensim.models.keyedvectors.Vocab at 0x2610b8e5978>,
#  'paleontology': <gensim.models.keyedvectors.Vocab at 0x2610b8e59b0>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x2610b8e59e8>,
#  'origami': <gensim.models.keyedvectors.Vocab at 0x2610b8e5a58>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x2610b8e5a90>,
#  'decorated': <gensim.models.keyedvectors.Vocab at 0x2610b8e5ac8>,
#  'folded': <gensim.models.keyedvectors.Vocab at 0x2610b8e5b00>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x2610b8e5b70>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x2610b8e5ba8>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x2610b8e5be0>,
#  'theodore': <gensim.models.keyedvectors.Vocab at 0x2610b8e5c18>,
#  'roosevelt': <gensim.models.keyedvectors.Vocab at 0x2610b8e5c50>,
#  'memorial': <gensim.models.keyedvectors.Vocab at 0x2610b8e5cc0>,
#  'teachers': <gensim.models.keyedvectors.Vocab at 0x2610b8e5cf8>,
#  'resource': <gensim.models.keyedvectors.Vocab at 0x2610b8e5d68>,
#  'musings': <gensim.models.keyedvectors.Vocab at 0x2610b8e5da0>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x2610b79dda0>,
#  'newsletter': <gensim.models.keyedvectors.Vocab at 0x2610b79def0>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x2610b79d1d0>,
#  'educators': <gensim.models.keyedvectors.Vocab at 0x2610b79d630>,
#  'toolong': <gensim.models.keyedvectors.Vocab at 0x2610b79d940>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x2610b79d518>,
#  'walls': <gensim.models.keyedvectors.Vocab at 0x2610b79dac8>,
#  'telephone': <gensim.models.keyedvectors.Vocab at 0x2610b79db70>,
#  'sciences': <gensim.models.keyedvectors.Vocab at 0x2610b79d198>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x2610b79d5f8>,
#  'nonprofit': <gensim.models.keyedvectors.Vocab at 0x2610b79d320>,
#  'serving': <gensim.models.keyedvectors.Vocab at 0x2610b79dc50>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x2610b79d7b8>,
#  'toll': <gensim.models.keyedvectors.Vocab at 0x2617b93e6d8>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x2610b627080>,
#  'adults': <gensim.models.keyedvectors.Vocab at 0x2610b627cc0>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x2610b441a90>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x2610b8ee2b0>,
#  'beginning': <gensim.models.keyedvectors.Vocab at 0x2610b8ee198>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x2610b8eef98>,
#  'telescope': <gensim.models.keyedvectors.Vocab at 0x2610b8ee048>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x2610b8ee0f0>,
#  'constellations': <gensim.models.keyedvectors.Vocab at 0x2610b8ee6d8>,
#  'legends': <gensim.models.keyedvectors.Vocab at 0x2610b8eed30>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x2610b8ee080>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x2610b8ee0b8>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x2610b8ee128>,
#  'descriptions': <gensim.models.keyedvectors.Vocab at 0x2610b8ee160>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x2610b8ee2e8>,
#  'biodiversity': <gensim.models.keyedvectors.Vocab at 0x2610b8ee320>,
#  'conservation': <gensim.models.keyedvectors.Vocab at 0x2610b8ee400>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x2610b8ee390>,
#  'located': <gensim.models.keyedvectors.Vocab at 0x2610b8ee278>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x2610b8ee240>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x2610b8ee438>,
#  'listings': <gensim.models.keyedvectors.Vocab at 0x2610b8ee4a8>,
#  'exhibitions': <gensim.models.keyedvectors.Vocab at 0x2610b8ee518>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x2610b8ee550>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x2610b8ee588>,
#  'tickets': <gensim.models.keyedvectors.Vocab at 0x2610b8ee5c0>,
#  'retail': <gensim.models.keyedvectors.Vocab at 0x2610b8ee5f8>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x2610b8ee630>,
#  'memberships': <gensim.models.keyedvectors.Vocab at 0x2610b8ee668>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x2610b8ee710>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x2610b8ee748>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x2610b8ee780>,
#  'nancy': <gensim.models.keyedvectors.Vocab at 0x2610b8ee7b8>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x2610b8ee7f0>,
#  'gender': <gensim.models.keyedvectors.Vocab at 0x2610b8ee828>,
#  'studies': <gensim.models.keyedvectors.Vocab at 0x2610b8ee898>,
#  'associate': <gensim.models.keyedvectors.Vocab at 0x2610b8ee8d0>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x2610b8ee908>,
#  'california': <gensim.models.keyedvectors.Vocab at 0x2610b8ee978>,
#  'forthcoming': <gensim.models.keyedvectors.Vocab at 0x2610b8eea20>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x2610b8eea90>,
#  'females': <gensim.models.keyedvectors.Vocab at 0x2610b8eeac8>,
#  'findings': <gensim.models.keyedvectors.Vocab at 0x2610b8eeb38>,
#  'readers': <gensim.models.keyedvectors.Vocab at 0x2610b8eeba8>,
#  'cosmo': <gensim.models.keyedvectors.Vocab at 0x2610b8eebe0>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x2610b8eec50>,
#  'behaviour': <gensim.models.keyedvectors.Vocab at 0x2610b8eec88>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x2610b8eef60>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x2610b8eeb00>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x2610b8eecf8>,
#  'pair': <gensim.models.keyedvectors.Vocab at 0x2610b8eee48>,
#  'bonding': <gensim.models.keyedvectors.Vocab at 0x2610b8ee860>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x2610b8eec18>,
#  'swans': <gensim.models.keyedvectors.Vocab at 0x2610b8eed68>,
#  'monogamous': <gensim.models.keyedvectors.Vocab at 0x2610b8eeda0>,
#  'monkeys': <gensim.models.keyedvectors.Vocab at 0x2610b8eedd8>,
#  'competency': <gensim.models.keyedvectors.Vocab at 0x2610b8eee10>,
#  'fatherhood': <gensim.models.keyedvectors.Vocab at 0x2610b8eecc0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x2610b8ee1d0>,
#  'desirable': <gensim.models.keyedvectors.Vocab at 0x2610b8ee208>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x2610b8ee358>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x2610b8eee80>,
#  'courting': <gensim.models.keyedvectors.Vocab at 0x2610b8eeeb8>,
#  'males': <gensim.models.keyedvectors.Vocab at 0x2610b8eeef0>,
#  'paternal': <gensim.models.keyedvectors.Vocab at 0x2610b8c3198>,
#  'skills': <gensim.models.keyedvectors.Vocab at 0x2610b8c3358>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x2610b8c33c8>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x2610b8c3400>,
#  'snatch': <gensim.models.keyedvectors.Vocab at 0x2610b8c3438>,
#  'worms': <gensim.models.keyedvectors.Vocab at 0x2610b8c3470>,
#  'pretend': <gensim.models.keyedvectors.Vocab at 0x2610b8c34a8>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x2610b8c34e0>,
#  'desired': <gensim.models.keyedvectors.Vocab at 0x2610b8c3518>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x2610b8c3550>,
#  'selecting': <gensim.models.keyedvectors.Vocab at 0x2610b8c35f8>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x2610b8c3630>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x2610b8c3668>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x2610b8c36d8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x2610b8c3710>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x2610b8c3748>,
#  'homo': <gensim.models.keyedvectors.Vocab at 0x2610b8c3780>,
#  'sapiens': <gensim.models.keyedvectors.Vocab at 0x2610b8c37b8>,
#  'hardly': <gensim.models.keyedvectors.Vocab at 0x2610b8c37f0>,
#  'rates': <gensim.models.keyedvectors.Vocab at 0x2610b8c3828>,
#  'textbook': <gensim.models.keyedvectors.Vocab at 0x2610b8c3860>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x2610b8c3898>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x2610b8c3048>,
#  'psychologist': <gensim.models.keyedvectors.Vocab at 0x2610b8c3908>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x2610b8c3940>,
#  'buss': <gensim.models.keyedvectors.Vocab at 0x2610b8c3978>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x2610b8c39b0>,
#  'examining': <gensim.models.keyedvectors.Vocab at 0x2610b8c39e8>,
#  'attributes': <gensim.models.keyedvectors.Vocab at 0x2610b8c3a20>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x2610b8c3a58>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x2610b8c3ac8>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x2610b8c3c18>,
#  'canvassed': <gensim.models.keyedvectors.Vocab at 0x2610b8c3c50>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x2610b8c3cc0>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x2610b8c3cf8>,
#  'thirty': <gensim.models.keyedvectors.Vocab at 0x2610b8c3d30>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x2610b8c3d68>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x2610b8c3da0>,
#  'cultures': <gensim.models.keyedvectors.Vocab at 0x2610b8c3dd8>,
#  'races': <gensim.models.keyedvectors.Vocab at 0x2610b8c3e48>,
#  'religions': <gensim.models.keyedvectors.Vocab at 0x2610b8c3e80>,
#  'ethnicities': <gensim.models.keyedvectors.Vocab at 0x2610b8c3ef0>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x2610b8c3f28>,
#  'urban': <gensim.models.keyedvectors.Vocab at 0x2610b8c3f98>,
#  'rural': <gensim.models.keyedvectors.Vocab at 0x2610b8c3fd0>,
#  'settings': <gensim.models.keyedvectors.Vocab at 0x2610b8c30b8>,
#  'western': <gensim.models.keyedvectors.Vocab at 0x2610b8c3b00>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x2610b8c3eb8>,
#  'capitalist': <gensim.models.keyedvectors.Vocab at 0x2610b8c3588>,
#  'socialist': <gensim.models.keyedvectors.Vocab at 0x2610b8c3160>,
#  'economies': <gensim.models.keyedvectors.Vocab at 0x2610b8c30f0>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x2610b8c3128>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x2610b8c31d0>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x2610b8c3208>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x2610b8c3240>,
#  'prospects': <gensim.models.keyedvectors.Vocab at 0x2610b8c3278>,
#  'priority': <gensim.models.keyedvectors.Vocab at 0x2610b8c32b0>,
#  'interpreted': <gensim.models.keyedvectors.Vocab at 0x2610b8c3b38>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x2610b8c3ba8>,
#  'universally': <gensim.models.keyedvectors.Vocab at 0x2610b8c3be0>,
#  'mates': <gensim.models.keyedvectors.Vocab at 0x2610b8c32e8>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x2610b8c3320>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x2610b5f0d30>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x2610b5f0358>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x2610b7c38d0>,
#  'generated': <gensim.models.keyedvectors.Vocab at 0x2610b7c3b00>,
#  'sorts': <gensim.models.keyedvectors.Vocab at 0x2610b7c3860>,
#  'unsettling': <gensim.models.keyedvectors.Vocab at 0x2610b7c3e48>,
#  'accusations': <gensim.models.keyedvectors.Vocab at 0x2610b7c3c18>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x2610b7c3048>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x2610b7c32e8>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x2610b7c3470>,
#  'reproduce': <gensim.models.keyedvectors.Vocab at 0x2610b7c3080>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x2610b7c36a0>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x2610b7c37b8>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x2610b7c3710>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x2610b7c3780>,
#  'offspring': <gensim.models.keyedvectors.Vocab at 0x2610b7c3fd0>,
#  'olive': <gensim.models.keyedvectors.Vocab at 0x2610b548be0>,
#  'baboon': <gensim.models.keyedvectors.Vocab at 0x2610b632710>,
#  'prize': <gensim.models.keyedvectors.Vocab at 0x2610b5d8668>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x2610b5d8e48>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x2610b73f470>,
#  'foul': <gensim.models.keyedvectors.Vocab at 0x2610b73f9b0>,
#  'mood': <gensim.models.keyedvectors.Vocab at 0x2610b73fc18>,
#  'directs': <gensim.models.keyedvectors.Vocab at 0x2610b75ec88>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x2610b75e2b0>,
#  'aggression': <gensim.models.keyedvectors.Vocab at 0x2610b75ecc0>,
#  'toward': <gensim.models.keyedvectors.Vocab at 0x2610b75eba8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x2610b75e5f8>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x2610b75ebe0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x2610b75eef0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x2610b75efd0>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x2610b669dd8>,
#  'assistance': <gensim.models.keyedvectors.Vocab at 0x2610b6690f0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x2610b669ef0>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x2610b669240>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x2610b669d30>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x2610b6693c8>,
#  'integrated': <gensim.models.keyedvectors.Vocab at 0x2610b669710>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x2610b6699b0>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x2610b51eeb8>,
#  'arrangement': <gensim.models.keyedvectors.Vocab at 0x2610b5a1fd0>,
#  'golden': <gensim.models.keyedvectors.Vocab at 0x2610b5a1128>,
#  'hamsters': <gensim.models.keyedvectors.Vocab at 0x2610b5a1048>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x2610b5a1908>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x2610b5a12b0>,
#  'booted': <gensim.models.keyedvectors.Vocab at 0x2610b8c9c88>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x2610b8c9390>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x2610b8c93c8>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x2610b8c9400>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x2610b8c9438>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x2610b8c94a8>,
#  'sociobiologists': <gensim.models.keyedvectors.Vocab at 0x2610b8c94e0>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x2610b8c9588>,
#  'harem': <gensim.models.keyedvectors.Vocab at 0x2610b8c95c0>,
#  'primatologist': <gensim.models.keyedvectors.Vocab at 0x2610b8c95f8>,
#  'alison': <gensim.models.keyedvectors.Vocab at 0x2610b8c9630>,
#  'jolly': <gensim.models.keyedvectors.Vocab at 0x2610b8c9668>,
#  'suggests': <gensim.models.keyedvectors.Vocab at 0x2610b8c96a0>,
# ...
#  'theirs': <gensim.models.keyedvectors.Vocab at 0x2610b8c9a90>,
#  'peacocks': <gensim.models.keyedvectors.Vocab at 0x2610b8c9b00>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x2610b8c9b38>,
#  'gorgeous': <gensim.models.keyedvectors.Vocab at 0x2610b8c9b70>,
#  'tail': <gensim.models.keyedvectors.Vocab at 0x2610b8c9ba8>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x2610b8c9c18>,
#  'lions': <gensim.models.keyedvectors.Vocab at 0x2610b8c9c50>,
#  'elaborate': <gensim.models.keyedvectors.Vocab at 0x2610b8c9fd0>,
#  'manes': <gensim.models.keyedvectors.Vocab at 0x2610b8c9048>,
#  'elk': <gensim.models.keyedvectors.Vocab at 0x2610b8c9ef0>,
#  'ornate': <gensim.models.keyedvectors.Vocab at 0x2610b8c9550>,
#  'antlers': <gensim.models.keyedvectors.Vocab at 0x2610b8c90f0>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x2610b8c9080>,
#  'merely': <gensim.models.keyedvectors.Vocab at 0x2610b8c90b8>,
#  'ornamental': <gensim.models.keyedvectors.Vocab at 0x2610b8c9128>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x2610b8c9198>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x2610b8c91d0>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x2610b8c9240>,
#  'attraction': <gensim.models.keyedvectors.Vocab at 0x2610b8c9278>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x2610b8c92e8>,
#  'vexed': <gensim.models.keyedvectors.Vocab at 0x2610b8c9320>,
#  'biologists': <gensim.models.keyedvectors.Vocab at 0x2610b8c9cc0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x2610b8c9cf8>,
#  'ornaments': <gensim.models.keyedvectors.Vocab at 0x2610b8c9d30>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x2610b8c9d68>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x2610b8c9da0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x2610b8c9358>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x2610b8c9dd8>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x2610b8c9e10>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x2610b8c9e80>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x2610b8c9eb8>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x2610b8c9f28>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x2610b8c9f60>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x2610b8c9f98>,
#  'statistician': <gensim.models.keyedvectors.Vocab at 0x2610b5f7470>,
#  'geneticist': <gensim.models.keyedvectors.Vocab at 0x2610b6640f0>,
#  'ronald': <gensim.models.keyedvectors.Vocab at 0x2610b664940>,
#  'fisher': <gensim.models.keyedvectors.Vocab at 0x2610b664ac8>,
#  'ornamentation': <gensim.models.keyedvectors.Vocab at 0x2610b664b00>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x2610b6642e8>,
#  'attracted': <gensim.models.keyedvectors.Vocab at 0x2610b6648d0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x2610b664198>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x2610b664be0>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x2610b644518>,
#  'expenditure': <gensim.models.keyedvectors.Vocab at 0x2610b56d4a8>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x2610b56d160>,
#  'maintain': <gensim.models.keyedvectors.Vocab at 0x2610b9cf470>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x2610b9cf9b0>,
#  'tag': <gensim.models.keyedvectors.Vocab at 0x2610b9cf278>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x2610b9cfe80>,
#  'survival': <gensim.models.keyedvectors.Vocab at 0x2610b9cfeb8>,
#  'darwinian': <gensim.models.keyedvectors.Vocab at 0x2610b9cfef0>,
#  'fitness': <gensim.models.keyedvectors.Vocab at 0x2610b9cff28>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x2610b9cf160>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x2610b9cff98>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x2610b9cf358>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x2610b9cf390>,
#  'calories': <gensim.models.keyedvectors.Vocab at 0x2610b9cfe48>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x2610b9cf4e0>,
#  'biggest': <gensim.models.keyedvectors.Vocab at 0x2610b9cf588>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x2610b9cf710>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x2610b9cf748>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x2610b9cf780>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x2610b9cf860>,
#  'sensible': <gensim.models.keyedvectors.Vocab at 0x2610b9cfa58>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x2610b9cfa90>,
#  'immune': <gensim.models.keyedvectors.Vocab at 0x2610b9cfb70>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x2610b9cfe10>,
#  'tuned': <gensim.models.keyedvectors.Vocab at 0x2610b6426a0>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x2610b57c6d8>,
#  'fallen': <gensim.models.keyedvectors.Vocab at 0x2610b57c4a8>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x2610b57c7f0>,
#  'striking': <gensim.models.keyedvectors.Vocab at 0x2610b7a95f8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x2610b7a9630>,
#  'emerged': <gensim.models.keyedvectors.Vocab at 0x2610b7a9390>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x2610b7a96d8>,
#  'brooks': <gensim.models.keyedvectors.Vocab at 0x2610b7a9f60>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x2610b7a9c50>,
#  'endler': <gensim.models.keyedvectors.Vocab at 0x2610b7a9588>,
#  'cook': <gensim.models.keyedvectors.Vocab at 0x2610b5047f0>,
#  'australia': <gensim.models.keyedvectors.Vocab at 0x2610b7d0f60>,
#  'attractiveness': <gensim.models.keyedvectors.Vocab at 0x2610b7d0128>,
#  'guppies': <gensim.models.keyedvectors.Vocab at 0x2610b7d0c18>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x2610b7d0e48>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x2610b7d0470>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x2610b7d0d30>,
#  'patterns': <gensim.models.keyedvectors.Vocab at 0x2610b7d0eb8>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x2610b7d0208>,
#  'attractive': <gensim.models.keyedvectors.Vocab at 0x2610b7d02b0>,
#  'sired': <gensim.models.keyedvectors.Vocab at 0x2610b7d0320>,
#  'sons': <gensim.models.keyedvectors.Vocab at 0x2610b7d0390>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x2610b7d03c8>,
#  'patterning': <gensim.models.keyedvectors.Vocab at 0x2610b7d0400>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x2610b7d0518>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x2610b7d0630>,
#  'heritable': <gensim.models.keyedvectors.Vocab at 0x2610b7d06d8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x2610b7d0be0>,
#  'coded': <gensim.models.keyedvectors.Vocab at 0x2610b7d0710>,
#  'cluster': <gensim.models.keyedvectors.Vocab at 0x2610b7d07b8>,
#  'chromosome': <gensim.models.keyedvectors.Vocab at 0x2610b7d0828>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x2610b7d0668>,
#  'july': <gensim.models.keyedvectors.Vocab at 0x2610b7d0b70>,
#  'significantly': <gensim.models.keyedvectors.Vocab at 0x2610b7d0898>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x2610b7d08d0>,
#  'survive': <gensim.models.keyedvectors.Vocab at 0x2610b7d0940>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x2610b7d0978>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x2610b7d0a90>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x2610b7d0ac8>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x2610b7d0c50>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x2610b570668>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x2610b5704e0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x2610b570240>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x2610b5706a0>,
#  'flashy': <gensim.models.keyedvectors.Vocab at 0x2610b570c50>,
#  'conspicuous': <gensim.models.keyedvectors.Vocab at 0x2610b570e48>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x2610b570dd8>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x2610b570550>,
#  'maturity': <gensim.models.keyedvectors.Vocab at 0x2610b5701d0>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x2610b570400>,
#  'coloration': <gensim.models.keyedvectors.Vocab at 0x2610b696f28>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x2610b696ba8>,
#  'stands': <gensim.models.keyedvectors.Vocab at 0x2610b696780>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x2610b696b70>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x2610b696240>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x2610b8b4ac8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x2610b8b47f0>,
#  'fads': <gensim.models.keyedvectors.Vocab at 0x2610b8b4860>,
#  'jacob': <gensim.models.keyedvectors.Vocab at 0x2610b8b4898>,
#  'arne': <gensim.models.keyedvectors.Vocab at 0x2610b8b48d0>,
#  'lundberg': <gensim.models.keyedvectors.Vocab at 0x2610b8b4d68>,
#  'uppsala': <gensim.models.keyedvectors.Vocab at 0x2610b8b4828>,
#  'sweden': <gensim.models.keyedvectors.Vocab at 0x2610b8b4908>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x2610b8b49b0>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x2610b8b49e8>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x2610b8b4a20>,
#  'grouse': <gensim.models.keyedvectors.Vocab at 0x2610b8b4a58>,
#  'chemistry': <gensim.models.keyedvectors.Vocab at 0x2610b8b4160>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x2610b8b4198>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x2610b8b41d0>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x2610b8b4208>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x2610b8b4278>,
#  'scientific': <gensim.models.keyedvectors.Vocab at 0x2610b8b42b0>,
#  'artifice': <gensim.models.keyedvectors.Vocab at 0x2610b8b42e8>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x2610b8b4320>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x2610b8b4358>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x2610b8b4390>,
#  'surround': <gensim.models.keyedvectors.Vocab at 0x2610b8b4438>,
#  'indifferent': <gensim.models.keyedvectors.Vocab at 0x2610b8b44e0>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x2610b8b4550>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x2610b8b45c0>,
#  'kinda': <gensim.models.keyedvectors.Vocab at 0x2610b8b4630>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x2610b8b44a8>,
#  'bandwagon': <gensim.models.keyedvectors.Vocab at 0x2610b8b4400>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x2610b8b40b8>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x2610b8b4b00>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x2610b8b4c88>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x2610b8b4710>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x2610b8b4da0>,
#  'neon': <gensim.models.keyedvectors.Vocab at 0x2610b8b4dd8>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x2610b8b4e10>,
#  'commodity': <gensim.models.keyedvectors.Vocab at 0x2610b8b4fd0>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x2610b8b4e48>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x2610b8b4e80>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x2610b8b4eb8>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x2610b8b4ef0>,
#  'rage': <gensim.models.keyedvectors.Vocab at 0x2610b8b4f28>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x2610b8b4f60>,
#  'maximize': <gensim.models.keyedvectors.Vocab at 0x2610bd1f860>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x2610bd1f390>,
#  'copies': <gensim.models.keyedvectors.Vocab at 0x2610bd1f048>,
#  'circular': <gensim.models.keyedvectors.Vocab at 0x2610bd1fac8>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x2610bd1ff28>,
#  'trait': <gensim.models.keyedvectors.Vocab at 0x2610bd1fda0>,
#  'becomes': <gensim.models.keyedvectors.Vocab at 0x2610b55d3c8>,
#  'carries': <gensim.models.keyedvectors.Vocab at 0x2610b55d6d8>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x2610b55d470>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x2610b82ff28>,
#  'possibility': <gensim.models.keyedvectors.Vocab at 0x2610b82fd30>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x2610b82fbe0>,
#  'translate': <gensim.models.keyedvectors.Vocab at 0x2610b82ff60>,
#  'meaningful': <gensim.models.keyedvectors.Vocab at 0x2610b82f9b0>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x2610b82fc88>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x2610b82f400>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x2610b82f198>,
#  'afford': <gensim.models.keyedvectors.Vocab at 0x2610b82f240>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x2610b82f278>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x2610b82f2e8>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x2610b82f358>,
#  'feathers': <gensim.models.keyedvectors.Vocab at 0x2610b82f390>,
#  'marlene': <gensim.models.keyedvectors.Vocab at 0x2610b82f470>,
#  'biology': <gensim.models.keyedvectors.Vocab at 0x2610b82f4a8>,
#  'formalized': <gensim.models.keyedvectors.Vocab at 0x2610b82fa58>,
#  'notion': <gensim.models.keyedvectors.Vocab at 0x2610b82f3c8>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x2610b82f710>,
#  'signaled': <gensim.models.keyedvectors.Vocab at 0x2610b82f748>,
#  'parasites': <gensim.models.keyedvectors.Vocab at 0x2610b82f7b8>,
#  'charming': <gensim.models.keyedvectors.Vocab at 0x2610b82f7f0>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x2610b82f828>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x2610b82f898>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x2610b82fac8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x2610b82fb00>,
#  'appealing': <gensim.models.keyedvectors.Vocab at 0x2610b82fb38>,
#  'decreases': <gensim.models.keyedvectors.Vocab at 0x2610b82fb70>,
#  'likelihood': <gensim.models.keyedvectors.Vocab at 0x2610b82fba8>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x2610b82f908>,
#  'wind': <gensim.models.keyedvectors.Vocab at 0x2610b82f940>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x2610b82f978>,
#  'sexually': <gensim.models.keyedvectors.Vocab at 0x2610b82f668>,
#  'reproducing': <gensim.models.keyedvectors.Vocab at 0x2610b82fcf8>,
#  'organisms': <gensim.models.keyedvectors.Vocab at 0x2610b82fd68>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x2610b82fe10>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x2610b82fe80>,
#  'transmitted': <gensim.models.keyedvectors.Vocab at 0x2610b82feb8>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x2610b8cdd30>,
#  'evolutionarily': <gensim.models.keyedvectors.Vocab at 0x2610b8cd0b8>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x2610b8cd0f0>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x2610b8cd128>,
#  'theme': <gensim.models.keyedvectors.Vocab at 0x2610b8cd160>,
#  'signals': <gensim.models.keyedvectors.Vocab at 0x2610b8cd1d0>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x2610b8cd208>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x2610b8cd240>,
#  'generation': <gensim.models.keyedvectors.Vocab at 0x2610b8cd278>,
#  'zahavi': <gensim.models.keyedvectors.Vocab at 0x2610b8cd2b0>,
#  'tel': <gensim.models.keyedvectors.Vocab at 0x2610b8cd2e8>,
#  'aviv': <gensim.models.keyedvectors.Vocab at 0x2610b8cd320>,
#  'israel': <gensim.models.keyedvectors.Vocab at 0x2610b8cd358>,
#  'posits': <gensim.models.keyedvectors.Vocab at 0x2610b8cd390>,
#  'evolved': <gensim.models.keyedvectors.Vocab at 0x2610b8cd400>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x2610b8cd438>,
#  'differentiate': <gensim.models.keyedvectors.Vocab at 0x2610b8cd4a8>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x2610b8cd4e0>,
#  'reflects': <gensim.models.keyedvectors.Vocab at 0x2610b8cd518>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x2610b8cd588>,
#  'acquired': <gensim.models.keyedvectors.Vocab at 0x2610b8cd5c0>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x2610b8cd5f8>,
#  'theoretically': <gensim.models.keyedvectors.Vocab at 0x2610b8cd630>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x2610b8cd668>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x2610b8cd6a0>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x2610b8cd6d8>,
#  'isolate': <gensim.models.keyedvectors.Vocab at 0x2610b8cd748>,
#  'gene': <gensim.models.keyedvectors.Vocab at 0x2610b8cd780>,
#  'responsible': <gensim.models.keyedvectors.Vocab at 0x2610b8cd7b8>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x2610b8cd7f0>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x2610b8cd828>,
#  'inherited': <gensim.models.keyedvectors.Vocab at 0x2610b8cd860>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x2610b8cd898>,
#  ...}

# %% [markdown]
# # 4. Save or Load model

# %%
# model.save("D:\\Models\\Doc2Vec(Sci_related).bin")
model = gensim.models.Doc2Vec.load("D:\\Models\\Doc2Vec(Sci_related).bin")
# Out:
# 2017-11-04 22:06:04,007 : INFO : loading Doc2Vec object from D:\Models\Doc2Vec(Sci_related).bin
# 2017-11-04 22:06:04,430 : INFO : loading wv recursively from D:\Models\Doc2Vec(Sci_related).bin.wv.* with mmap=None
# 2017-11-04 22:06:04,432 : INFO : loading syn0 from D:\Models\Doc2Vec(Sci_related).bin.wv.syn0.npy with mmap=None
# 2017-11-04 22:06:04,480 : INFO : setting ignored attribute syn0norm to None
# 2017-11-04 22:06:04,482 : INFO : loading docvecs recursively from D:\Models\Doc2Vec(Sci_related).bin.docvecs.* with mmap=None
# 2017-11-04 22:06:04,484 : INFO : loading syn1neg from D:\Models\Doc2Vec(Sci_related).bin.syn1neg.npy with mmap=None
# 2017-11-04 22:06:04,541 : INFO : setting ignored attribute cum_table to None
# 2017-11-04 22:06:04,542 : INFO : loaded D:\Models\Doc2Vec(Sci_related).bin

# %% [markdown]
# # 5. Look-up for similar documents

# %%
model.similar_by_word("internet")
# Out:
# 2017-11-04 22:06:04,760 : INFO : precomputing L2-norms of word weight vectors
# [('web', 0.4793151617050171),
#  ('facebook', 0.42751970887184143),
#  ('broadband', 0.3999687731266022),
#  ('network', 0.36445242166519165),
#  ('openid', 0.3539382219314575),
#  ('mail', 0.33882203698158264),
#  ('wireless', 0.3299103081226349),
#  ('blogs', 0.3297681212425232),
#  ('edi', 0.32874196767807007),
#  ('phishing', 0.3247973918914795)]

# %%
model.similar_by_word("data")
# Out:
# [('information', 0.4409201145172119),
#  ('statistics', 0.3989573121070862),
#  ('records', 0.36948490142822266),
#  ('samples', 0.36515748500823975),
#  ('observations', 0.3583360016345978),
#  ('archives', 0.3361548185348511),
#  ('measurements', 0.33312302827835083),
#  ('readings', 0.3325759768486023),
#  ('documents', 0.3289825916290283),
#  ('timings', 0.3274507522583008)]

# %%
model.similar_by_word("developers")
# Out:
# [('programmers', 0.5002354383468628),
#  ('users', 0.4927016496658325),
#  ('vendors', 0.46623820066452026),
#  ('designers', 0.42613762617111206),
#  ('stutterers', 0.41394639015197754),
#  ('ecologists', 0.4031423330307007),
#  ('managers', 0.398607075214386),
#  ('companies', 0.38800886273384094),
#  ('manufacturers', 0.38262853026390076),
#  ('advocates', 0.3826046884059906)]

# %%
vector = model.infer_vector("""data science""".split())
model.docvecs.most_similar([vector]) # similar docs & accuracy
# Out:
# [(' Fever Flow', 0.3851379156112671),
#  (' Solar System Mysteries', 0.3793867230415344),
#  (' Miniplanet sports a megapeak', 0.37395384907722473),
#  (' Studying Biodiversity: Is a New Paradigm Really Needed? ',
#   0.3729775547981262),
#  (' Planets common as stars in galaxy', 0.372067391872406),
#  (' Planck studies the microwave galaxy', 0.3694920241832733),
#  (' Data Recovery', 0.3680240511894226),
#  (' BENCHED SCIENCE.', 0.3646535873413086),
#  (' Exoplanets make pictorial debut', 0.3609537184238434),
#  (' When Science Turns Suspect The Office of Research Integrity--a.k.a., the Fraud Squad--is on the case.',
#   0.3602791726589203)]

# %%
similar_docs = model.docvecs.most_similar([vector])
file_names = [i[0] for i in similar_docs] # slice the first elements
results = []
        
for name in file_names:
    text = open("D:\\COCA & GloWbE\\COCA\\Pre-processed Text\\Science-related Texts\\" + name, 'r')
    results.append(text.read())
    text.close()
        
i = 0

for text in results:
    print("Document", i+1, ":", file_names[i], "\t accuracy:", similar_docs[i][1], "\n", (text[0:500]), "\n" ) 
    i += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-124-703e4e7bbfe0> in <module>()
#       4
#       5 for name in file_names:
# ----> 6     text = open("D:\\COCA & GloWbE\\COCA\\Pre-processed Text\\Science-related Texts\\" + name, 'r')
#       7     results.append(text.read())
#       8     text.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\COCA & GloWbE\\COCA\\Pre-processed Text\\Science-related Texts\\ A new language will improve online applications Cloud Programming'
