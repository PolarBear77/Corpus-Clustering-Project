# %% [markdown]
# # Workplace

# %%
import gensim
model = gensim.models.Word2Vec.load(r"C:\nlp\word2vec_1.bin")
model.wv.vocab
# Out:
# c:\nlp\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.
# {'section_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba7390>,
#  'museum_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba7438>,
#  'centenary_JJ': <gensim.models.keyedvectors.Vocab at 0x1b251ba7470>,
#  'birth_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba74a8>,
#  'margaret_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba74e0>,
#  'mead_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba7550>,
#  'remember_VBN': <gensim.models.keyedvectors.Vocab at 0x1b251ba7588>,
#  'world_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba75c0>,
#  'influential_JJ': <gensim.models.keyedvectors.Vocab at 0x1b251ba75f8>,
#  'anthropologist_NN': <gensim.models.keyedvectors.Vocab at 0x1b251ba7630>,
#  'arrive_VBD': <gensim.models.keyedvectors.Vocab at 0x1b251ba7668>,
# ...

# %%
vocab
# Out:
# ['section_NN',
#  'museum_NN',
#  'centenary_JJ',
#  'birth_NN',
#  'margaret_NN',
#  'mead_NN',
#  'remember_VBN',
#  'world_NN',
#  'influential_JJ',
#  'anthropologist_NN',
#  'arrive_VBD',
#  'american_JJ',
#  'natural_JJ',
#  'history_NN',
#  'complete_VBN',
#  'first_JJ',
#  'significant_JJ',
#  'ethnographic_JJ',
#  'research_NN',
#  'samoa_NN',
#  'appoint_VBN',
#  'assistant_JJ',
#  'curator_NN',
#  'department_NN',
#  'anthropology_NN',
#  'year_NNS',
#  'old_JJ',
#  'give_VBN',
#  'temporary_JJ',
#  'office_NN',
#  'attic_NN',
#  'room_NN',
#  'west_NN',
#  'tower_NN',
#  'out-of-the-way_JJ',
#  'view_NNS',
#  'rooftop_NNS',
#  'new_JJ',
#  'york_JJ',
#  'city_NN',
#  'stairway_NNS',
#  'ideal_JJ',
#  'say_VBD',
#  'creep_VBG',
#  'stairway_NN',
#  'someone_NN',
#  'avoid_VBN',
#  'elderly_JJ',
#  'labor_VBG',
#  'stay_VBD',
#  'rest_NN',
#  'life_NN',
#  'arrive_VBG',
#  'interview_VBN',
#  'position_NN',
#  'assistant_NN',
#  'undergraduate_JJ',
#  'major_JJ',
# ...

# %%
vocab = model.wv.vocab

# %%
"disabled_VBD" in vocab
# Out:
# False

# %%
for word  in vocab:
    if word.startswith("disable"):
        print(word)
# Out:
# disable_VBN
# disable_VBD
# disable_VB
# disabled_JJ
# disable_VBG
# disable_VBP
# disable_JJ
# disable_VBZ

# %%
model.wv.similar_by_word("disable_VBD") # note that by giving the adjective tag JJ, we can distinguish this word from its verb usage
# Out:
# [('webroot_NN', 0.8622482419013977),
#  ('avast_JJ', 0.8594812154769897),
#  ('eliminator_NN', 0.8518333435058594),
#  ('malware_JJ', 0.8504296541213989),
#  ('nod32_NN', 0.8502002358436584),
#  ('g-data_NN', 0.8471348285675049),
#  ('on-access_JJ', 0.842896044254303),
#  ('scandisk_NN', 0.8408646583557129),
#  ('bldc_JJ', 0.8387866020202637),
#  ('disinfect_VBG', 0.832033634185791)]

# %%
len(model.wv.vocab)
# Out:
# 89008

# %%
from sklearn.manifold import TSNE
import re
import matplotlib.pyplot as plt
import pandas as pd

vocab = list(model.wv.vocab) # get all words
# vectors  = model[vocab] # get all word vectors

vocab = vocab[0:5000]
vectors = model[vocab]

print("Clustering", len(vocab), "words")

tsne = TSNE(n_components=2, init = 'pca', random_state=7)
X_tsne = tsne.fit_transform(vectors)

df = pd.concat([pd.DataFrame(X_tsne), pd.Series(vocab)], axis = 1)
df.columns = ['x', 'y', 'word']

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for i, txt in enumerate(df['word']):
    ax.annotate(txt, (df['x'].iloc[i], df['y'].iloc[i]))
# Out:
# Clustering 5000 words

# %%
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-dfbc3e821e92> in <module>()
# ----> 1 fig(fig_size = (20, 20))
#
# TypeError: 'Figure' object is not callable

# %%
ax.set_xlim(auto=True)
ax.set_ylim(auto=True)

fig.set_size_inches((20,20))
fig

# %%
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print ("Current size:", fig_size)

# Set figure width to 12 and height to 9
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [6.0, 4.0]

# %%
plt.show()

# %%
fig.
